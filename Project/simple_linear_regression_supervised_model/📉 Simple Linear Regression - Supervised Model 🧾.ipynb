# %% [markdown]
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED;font-size:220%; text-align:center; border-radius: 15px 55px;">📉 Simple Linear Regression - Supervised Model 🧾</p>

# %% [markdown]
# <img src=https://miro.medium.com/max/1400/1*_xszvgfP2xIQz7krzbJMOA.png width="700" height="200">

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 0%;" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100">0%</div>
# </div>

# %% [markdown]
# <h6><span class="label label-danger">Attention</span> You can access the entire study through the following links. Good luck with your work. </h6>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> 📉 Simple Linear Regression - Supervised Model 🧾 </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/machine_learning/tree/main/Project/simple_linear_regression_supervised_model"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/huseyincenik/simple-linear-regression-supervised-model"><b>My Kaggle Account</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>

# %% [markdown]
# <a id="toc"></a>
# <div style="border-radius: 10px;
#             border: black solid;
#             background-color: lightblue;
#             font-size: 100%;
#             text-align: left;
#             box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
# <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: white; background-color: red;"><center> ✍✍ Content ✍✍</center></h2>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#1">Dataset Explanation</a></li>
#     <li><a href="#2">Importing Libraries Needed in This Notebook</a></li>
#     <li><a href="#3">Reading & Understanding Data</a></li>
#     <li><a href="#4">Create new independent variable (feature)</a></li>
#     <li><a href="#5">Which feature is more suitable for linear regression?</a></li>
#     <li><a href="#6">Plotting the relationship between independent variable and dependent variable</a></li>
#     <li><a href="#7">Correlation between independent variable and dependent variable </a></li>
#     <li><a href="#8">Coefficient of determination (R2) </a></li>
#     <li><a href="#9">Linear Regression ( total_spend and sales ) </a></li>
#     <li><a href="#10">Splitting the dataset into X(independent variables) and y (dependent variable) </a></li>
#     <li><a href="#11">Determination of coefficients (slope and intercept) </a></li>
#     <li><a href="#12">Why do we use the least squares error method to find the regression line that best fits the data? </a></li>
#     <li><a href="#13">Prediction with simple linear regression </a></li>
#     <li><a href="#14">Linear Regression ( TV and Sales ) </a></li>
#     <li><a href="#15">Determination of coefficients (slope and intercept) </a></li>
#   </ul>
# </div>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#the_end">THE END </a></li>
#   </ul>
# </div>
# </div>

# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Dataset Explanation ✨</p>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="border-radius: 10px; border: 1px solid black; background-color:#3498DB ; font-size: 100%; text-align: left; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); padding: 10px; margin-bottom: 20px;">
#     <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">⚡️ Dataset Description ⚡️</h2>
#     <p>
#      <strong style="color: white;">Data Fields:</strong>
#       <ul>
#             <li><span style="color: white;">TV:</span> TV advertising expenditures (in dollars)</li>
#             <li><span style="color: white;">radio:</span> Radio advertising expenditures (in dollars)</li>
#             <li><span style="color: white;">newspaper:</span> Newspaper advertising expenditures (in dollars)</li>
#             <li><span style="color: white;">sales:</span> Sales (number of units of the product sold)</li>
#       </ul>
#     </p>
# </div>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="2"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Importing Libraries Needed in This Notebook ✨</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,6) # Set default figure size
# %matplotlib inline

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="3"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Reading & Understanding Data ✨</p>

# %%
df0 = pd.read_csv("Advertising.csv")
df = df0.copy()
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# <a id="part_1_reading"></a>
# - **<span style="color:#3498DB;">Independent Variable</span>** (also known as **<span style="color:#3498DB;">Feature</span>**, **<span style="color:#3498DB;">Estimator</span>**, **<span style="color:#3498DB;">Attribute</span>**, **<span style="color:#3498DB;">Input</span>**, **<span style="color:#3498DB;">Explanatory Variable</span>**):
#   - The variables that are manipulated or analyzed in a statistical model. They are the input values used to predict the dependent variable.
#
# - **<span style="color:#3498DB;">Dependent Variable</span>** (also known as **<span style="color:#3498DB;">Target</span>**, **<span style="color:#3498DB;">Label</span>**, **<span style="color:#3498DB;">Output</span>**, **<span style="color:#3498DB;">Response Variable</span>**):
#   - The variable that is being predicted or explained in a statistical model. It is the output value that you want to understand or predict.
#
# - **<span style="color:#3498DB;">Rows</span>** (also known as **<span style="color:#3498DB;">Observation</span>**, **<span style="color:#3498DB;">Sample</span>**):
#   - Individual data points or entries in a dataset. Each row typically represents a unique instance or observation.
#
# - **<span style="color:#3498DB;">Features</span>**:
#   - The set of independent variables used in a machine learning model. In this context, the features are {TV, radio, newspaper}.
#
# - **<span style="color:#3498DB;">Target</span>**:
#   - The dependent variable that a machine learning model is trying to predict. In this context, the target is "sales".

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Please take note of the statistical measures for numeric features:</p>
#     <ul>
#         <li><span style="color: white;">Mean:</span> This represents the average value of the numeric feature.</li>
#         <li><span style="color: white;">Std:</span> The standard deviation, which quantifies the spread or variability within the data.</li>
#         <li><span style="color: white;">Min:</span> The minimum observed value within the dataset.</li>
#         <li><span style="color: white;">50%:</span> Refers to the median value, which denotes the middle point when the data is sorted.</li>
#         <li><span style="color: white;">Max:</span> The maximum observed value within the dataset.</li>
#     </ul>
#     <p>These statistical measures can provide valuable insights into the data's distribution and help identify potential outliers.</p>
# </div>

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Given that the standard deviation is smaller than the mean, it can be concluded that there are no outlier values.</p>
# </div>

# %%
# decriptive statistics in case of 1 outlier
print("mean :", np.mean([100, 110, 120, 400]))
print("std  :", np.std([100, 110, 120, 400]))
# Out:
# mean : 182.5
# std  : 125.77261228105267

# %%
# decriptive statistics in case of a larger outlier
# notice std got closer to the mean
print("mean :", np.mean([100, 110, 120, 700]))
print("std  :", np.std([100, 110, 120, 700]))
# Out:
# mean : 257.5
# std  : 255.57533136044253

# %%
# decriptive statistics in case of even a larger outlier
# std got larger than the mean
print("mean :", np.mean([100, 110, 120, 900]))
print("std  :", np.std([100, 110, 120, 900]))
# Out:
# mean : 307.5
# std  : 342.153109002388

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">The histogram of a numerical feature can be examined to assess the distribution of the variable. While the variable's distribution may not necessarily impact model performance, it can provide valuable insights into the variable's characteristics.</p>
# </div>

# %%
sns.histplot(df.TV, bins=50, kde=True);

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">A boxplot provides information about the quartiles (25%, median, 75%) of a variable and can highlight potential outliers (data points outside of the whiskers).</p>
#     <p>In machine learning, unlike traditional statistics, the presence of outliers doesn't necessarily indicate a problem unless there was a systematic issue in the data collection process. The primary concern is whether there are insufficiently represented observation points.</p>
# </div>

# %%
sns.boxplot(df.TV)
# Out:
# <Axes: >

# %% [markdown]
# <a id="4"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Create new independent variable (feature) ✨</p>

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Feature engineering encompasses techniques for creating new variables based on existing ones.</p>
# </div>

# %%
df["total_spend"] = df["TV"] + df["radio"] + df["newspaper"]

# %%
df
# Out:
#         TV  radio  newspaper  sales  total_spend
# 0    230.1   37.8       69.2   22.1        337.1
# 1     44.5   39.3       45.1   10.4        128.9
# 2     17.2   45.9       69.3    9.3        132.4
# 3    151.5   41.3       58.5   18.5        251.3
# 4    180.8   10.8       58.4   12.9        250.0
# ..     ...    ...        ...    ...          ...
# 195   38.2    3.7       13.8    7.6         55.7
# 196   94.2    4.9        8.1    9.7        107.2
# 197  177.0    9.3        6.4   12.8        192.7
# 198  283.6   42.0       66.2   25.5        391.8
# 199  232.1    8.6        8.7   13.4        249.4
#
# [200 rows x 5 columns]

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Reorder the columns so that the target variable (sales) is positioned at the end. It becomes second nature to prioritize locating the target variable.</p>
# </div>

# %%
df = df.iloc[:,[0,1,2,4,3]]
df.head()
# Out:
#       TV  radio  newspaper  total_spend  sales
# 0  230.1   37.8       69.2        337.1   22.1
# 1   44.5   39.3       45.1        128.9   10.4
# 2   17.2   45.9       69.3        132.4    9.3
# 3  151.5   41.3       58.5        251.3   18.5
# 4  180.8   10.8       58.4        250.0   12.9

# %% [markdown]
# <a id="5"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Which feature is more suitable for linear regression? ✨</p>

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">The assumption is made that there is a linear relationship between the independent and dependent variable(s). As long as this assumption holds true, the data is considered suitable for linear regression.</p>
# </div>

# %%
df["sales"].corr(df["TV"])
# Out:
# 0.7822244248616061

# %%
my_dict = {"temperature": [30, 31, 32, 33, 34, 35],
           "ice_cream_sale": [50, 60, 65, 70, 75, 80]}
df1 = pd.DataFrame(my_dict)
df1
# Out:
#    temperature  ice_cream_sale
# 0           30              50
# 1           31              60
# 2           32              65
# 3           33              70
# 4           34              75
# 5           35              80

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Correlation informs us about the relationships between features. However, it does not quantify the exact impact of an increase or decrease in one variable on another.</p>
#     <p>Regression, on the other hand, addresses the question: "How much change can be expected in one variable when another variable is changed by one unit?"</p>
# </div>

# %%
df1.temperature.corr(df1.ice_cream_sale)
# Out:
# 0.989743318610787

# %%
my_dict = {"temperature": [30, 31, 32, 33, 34, 35],
           "ice_cream_sale": [50, 51, 53, 54, 55, 56]}
df2 = pd.DataFrame(my_dict)
df2
# Out:
#    temperature  ice_cream_sale
# 0           30              50
# 1           31              51
# 2           32              53
# 3           33              54
# 4           34              55
# 5           35              56

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">In the first dataset, the regression coefficient is 5, and the correlation is 0.9821.</p>
#     <p>In the second dataset, the regression coefficient is 1, and the correlation is 0.9921.</p>
#     <p>This demonstrates that correlation alone does not provide information about how much a unit of change in one variable impacts the other, whereas regression analysis does.</p>
# </div>

# %%
df2.temperature.corr(df2.ice_cream_sale)
# Out:
# 0.9921609337929049

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Determine which features exhibit strong correlations with the target variable. Features with high correlations are typically more valuable for inclusion in a linear regression model.</p>
# </div>

# %%
for i in df.drop(columns ="sales"):
    print(f"corr between sales and {i:<12}:  {df.sales.corr(df[i])}")
# Out:
# corr between sales and TV          :  0.7822244248616061
# corr between sales and radio       :  0.5762225745710551
# corr between sales and newspaper   :  0.22829902637616528
# corr between sales and total_spend :  0.8677123027017427

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">A pairplot is a useful tool for visualizing potential correlations between all features.</p>
# </div>

# %%
sns.pairplot(df, kind="reg");

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 50%;" aria-valuenow="50" aria-valuemin="50" aria-valuemax="100">50%</div>
# </div>

# %%
df.corr()
# Out:
#                    TV     radio  newspaper  total_spend     sales
# TV           1.000000  0.054809   0.056648     0.945330  0.782224
# radio        0.054809  1.000000   0.354104     0.293211  0.576223
# newspaper    0.056648  0.354104   1.000000     0.343059  0.228299
# total_spend  0.945330  0.293211   0.343059     1.000000  0.867712
# sales        0.782224  0.576223   0.228299     0.867712  1.000000

# %%
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap='coolwarm');

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">There exists a strong relationship between TV and total_spend, as well as between sales and total_spend.</p>
# </div>

# %%
df = df[["total_spend", "sales"]]
df
# Out:
#      total_spend  sales
# 0          337.1   22.1
# 1          128.9   10.4
# 2          132.4    9.3
# 3          251.3   18.5
# 4          250.0   12.9
# ..           ...    ...
# 195         55.7    7.6
# 196        107.2    9.7
# 197        192.7   12.8
# 198        391.8   25.5
# 199        249.4   13.4
#
# [200 rows x 2 columns]

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Considering that the feature `total_spend` exhibits the highest correlation with our target and represents a composite of all other independent features, it will be used as the sole predictor variable.</p>
# </div>

# %% [markdown]
# <a id="6"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Plotting the relationship between independent variable and dependent variable ✨</p>

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Correlations can also be visualized using scatterplots.</p>
# </div>

# %%
sns.scatterplot(x="total_spend", y="sales", data=df);

# %% [markdown]
# <a id="7"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Correlation between independent variable and dependent variable ✨</p>

# %%
corr = df["sales"].corr(df["total_spend"])
corr
# Out:
# 0.8677123027017427

# %%
df["total_spend"].corr(df["sales"])

# Correlation is completely symmetrical.
# Out:
# 0.8677123027017427

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="8"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Coefficient of determination (R2) ✨</p>

# %%
R2_score = corr**2  # for simple linear regression
R2_score
# Out:
# 0.5841198362476764

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">The R2 score indicates how much of the variation in the target column can be explained by the independent features at hand.</p>
#     <p>Statistically, R2 scores typically range from [0, 1], while in the context of Scikit-learn, the range is [-∞, 1].</p>
#     <p>Seventy-five percent of the dataset's variance can be explained.</p>
# </div>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;"> Example:</p>
#     <p>A house (2 + 1) price ----> 50,000 USD </p>
#     <p>B house (3 + 1) price ----> 60,000 USD</p>
#     <p>If 3,000 USD of the variation in house price is attributable to the number of rooms in the houses, what is the Coefficient of Determination (R2) for the number of rooms?</p>
#     <p>R2 Score for the number of rooms in the houses:</p>
#     <p>r2_score = 3000 / (60000 - 50000)</p>
#     <p>r2_score = 0.3</p>
# </div>

# %% [markdown]
# <a id="9"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Linear Regression ( total_spend and sales )✨</p>

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">The `regplot` function from `seaborn` can be used to fit a regression line to this data and visualize it, as it's only 2-D.</p>
# </div>

# %%
sns.regplot(x="total_spend", y="sales", data=df, ci=None);

# %% [markdown]
# <a id="10"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Splitting the dataset into X(independent variables) and y (dependent variable) ✨</p>

# %%
# y_pred = b1X + b0

# %%
X = df["total_spend"]
y = df["sales"]

# %% [markdown]
# <a id="11"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Determination of coefficients (slope and intercept) ✨</p>

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">The `polyfit` function from numpy can be used to calculate the linear regression coefficients. This step is redundant and is solely for educational purposes. There are more efficient methods for accomplishing this automatically, which we will explore in the upcoming lectures.</p>
#     <p>Polyfit stands for polynomial fit. A polynomial with a degree of 1 corresponds to a linear fit. Keep that in mind.</p>
# </div>

# %%
np.polyfit(X, y, deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
slope, intercept = np.polyfit(X, y, deg=1)

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">The slope represents the coefficient of our independent feature.</p>
#     <p>The intercept denotes the y-value when x=0.</p>
# </div>

# %%
print("slope    :", slope)
print("intercept:", intercept)
# Out:
# slope    : 0.048687879319048145
# intercept: 4.2430282160363255

# %% [markdown]
# <a id="12"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Why do we use the least squares error method to find the regression line that best fits the data? ✨</p>

# %%
# y_pred = 0.04868787931904817*X + 4.243028216036326

# %%
b1, b0 = np.polyfit(X, y, deg=1)

# b1 = slope, b0= intercept

# %%
print("b1 :", b1)
print("b0 :", b0)
# Out:
# b1 : 0.048687879319048145
# b0 : 4.2430282160363255

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
X
# Out:
# 0      337.1
# 1      128.9
# 2      132.4
# 3      251.3
# 4      250.0
#        ...
# 195     55.7
# 196    107.2
# 197    192.7
# 198    391.8
# 199    249.4
# Name: total_spend, Length: 200, dtype: float64

# %%
y_pred = b1*X + b0

# %%
values = {"actual": y, "predicted": y_pred, "residual":y-y_pred, "LSE": (y-y_pred)**2, "ABS":abs(y-y_pred)}
df_2 = pd.DataFrame(values)
df_2
# Out:
#      actual  predicted  residual        LSE       ABS
# 0      22.1  20.655712  1.444288   2.085967  1.444288
# 1      10.4  10.518896 -0.118896   0.014136  0.118896
# 2       9.3  10.689303 -1.389303   1.930164  1.389303
# 3      18.5  16.478292  2.021708   4.087302  2.021708
# 4      12.9  16.414998 -3.514998  12.355211  3.514998
# ..      ...        ...       ...        ...       ...
# 195     7.6   6.954943  0.645057   0.416098  0.645057
# 196     9.7   9.462369  0.237631   0.056469  0.237631
# 197    12.8  13.625183 -0.825183   0.680926  0.825183
# 198    25.5  23.318939  2.181061   4.757026  2.181061
# 199    13.4  16.385785 -2.985785   8.914914  2.985785
#
# [200 rows x 5 columns]

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">LSE stands for least squared errors, while ABS stands for absolute errors.</p>
#     <p>It's important to remember that LSE involves squaring the residuals, which means it penalizes high errors, whereas ABS does not apply this squared penalty.</p>
#     <p>Residuals represent the errors in the prediction.</p>
#     <p>Which metric to use will depend on your specific use case. If your dataset contains many outliers, LSE can be a useful choice.</p>
# </div>

# %%
df_2.residual.sum().round()
# Out:
# 0.0

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">In linear regression, the sum of residuals will always be (almost, considering floating-point precision) equal to 0, but this holds true only for the training set.</p>
# </div>

# %% [markdown]
# <a id="13"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Prediction with simple linear regression ✨</p>

# %%
potential_spend = np.linspace(0, 500, 100)
potential_spend
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
#        303.03030303, 308.08080808, 313.13131313, 318.18181818,
#        323.23232323, 328.28282828, 333.33333333, 338.38383838,
#        343.43434343, 348.48484848, 353.53535354, 358.58585859,
#        363.63636364, 368.68686869, 373.73737374, 378.78787879,
#        383.83838384, 388.88888889, 393.93939394, 398.98989899,
#        404.04040404, 409.09090909, 414.14141414, 419.19191919,
#        424.24242424, 429.29292929, 434.34343434, 439.39393939,
#        444.44444444, 449.49494949, 454.54545455, 459.5959596 ,
#        464.64646465, 469.6969697 , 474.74747475, 479.7979798 ,
#        484.84848485, 489.8989899 , 494.94949495, 500.        ])

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">Generate a dummy set of observations to perform inference (predictions) on. These data points are evenly spaced along a linear range between 0 and 500.</p>
# </div>

# %%
predicted_sales_lin = b1* potential_spend + b0
predicted_sales_lin
# Out:
# array([ 7.03259355,  7.27267759,  7.51276163,  7.75284568,  7.99292972,
#         8.23301376,  8.4730978 ,  8.71318185,  8.95326589,  9.19334993,
#         9.43343398,  9.67351802,  9.91360206, 10.1536861 , 10.39377015,
#        10.63385419, 10.87393823, 11.11402227, 11.35410632, 11.59419036,
#        11.8342744 , 12.07435844, 12.31444249, 12.55452653, 12.79461057,
#        13.03469461, 13.27477866, 13.5148627 , 13.75494674, 13.99503078,
#        14.23511483, 14.47519887, 14.71528291, 14.95536695, 15.195451  ,
#        15.43553504, 15.67561908, 15.91570312, 16.15578717, 16.39587121,
#        16.63595525, 16.8760393 , 17.11612334, 17.35620738, 17.59629142,
#        17.83637547, 18.07645951, 18.31654355, 18.55662759, 18.79671164,
#        19.03679568, 19.27687972, 19.51696376, 19.75704781, 19.99713185,
#        20.23721589, 20.47729993, 20.71738398, 20.95746802, 21.19755206,
#        21.4376361 , 21.67772015, 21.91780419, 22.15788823, 22.39797227,
#        22.63805632, 22.87814036, 23.1182244 , 23.35830845, 23.59839249,
#        23.83847653, 24.07856057, 24.31864462, 24.55872866, 24.7988127 ,
#        25.03889674, 25.27898079, 25.51906483, 25.75914887, 25.99923291,
#        26.23931696, 26.479401  , 26.71948504, 26.95956908, 27.19965313,
#        27.43973717, 27.67982121, 27.91990525, 28.1599893 , 28.40007334,
#        28.64015738, 28.88024142, 29.12032547, 29.36040951, 29.60049355,
#        29.8405776 , 30.08066164, 30.32074568, 30.56082972, 30.80091377])

# %% [markdown]
# <a id="14"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Linear Regression ( TV and Sales ) ✨</p>

# %%
df_tv = df0.copy()
df_tv.head()
# Out:
#      TV  radio  newspaper  sales
# 1  44.5   39.3       45.1   10.4
# 2  17.2   45.9       69.3    9.3
# 5   8.7   48.9       75.0    7.2
# 6  57.5   32.8       23.5   11.8
# 8   8.6    2.1        1.0    4.8

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
corr = df_tv.TV.corr(df_tv["sales"])
corr
# Out:
# 0.7642773294084264

# %%
R2_score = corr**2  # for simple linear regression
R2_score
# Out:
# 0.5841198362476764

# %%
sns.regplot(x="TV", y="sales", data=df_tv, ci=None);

# We can use `regplot` from `seaborn` to fit a regression line to this data and visualise it as it's only 2-D.

# %% [markdown]
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title">Info</button>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); color: white;">
#     <p style="font-weight: bold;">To fit a regression line to this two-dimensional data and visualize it, we can utilize the `regplot` function from `seaborn`.</p>
#     <p style="font-weight: bold;">The model can explain 61% of the data.</p>
# </div>

# %%
X = df_tv["TV"]
y = df_tv["sales"]

# %%
slope , intercept = np.polyfit(X, y , deg = 1)
b1, b0 = np.polyfit(X, y, deg=1)
print("Slope : ", b1, "\nintercept : ", b0)
# b1 = slope, b0= intercept
# Out:
# Slope :  0.06234564024507545
# intercept :  6.13956314273111

# %%
X
# Out:
# 1      44.5
# 2      17.2
# 5       8.7
# 6      57.5
# 8       8.6
#        ...
# 190    39.5
# 191    75.5
# 192    17.2
# 195    38.2
# 196    94.2
# Name: TV, Length: 80, dtype: float64

# %%
y_pred = b1*X + b0

# %%
values = {"actual" : y, "predicted" : y_pred, "residual" : y - y_pred, "LSE" : (y - y_pred)**2 , "ABS" : abs(y - y_pred)}
df_values = pd.DataFrame(values)
df_values
# Out:
#      actual  predicted  residual       LSE       ABS
# 1      10.4   8.913944  1.486056  2.208362  1.486056
# 2       9.3   7.211908  2.088092  4.360128  2.088092
# 5       7.2   6.681970  0.518030  0.268355  0.518030
# 6      11.8   9.724437  2.075563  4.307960  2.075563
# 8       4.8   6.675736 -1.875736  3.518384  1.875736
# ..      ...        ...       ...       ...       ...
# 190    10.8   8.602216  2.197784  4.830255  2.197784
# 191     9.9  10.846659 -0.946659  0.896163  0.946659
# 192     5.9   7.211908 -1.311908  1.721103  1.311908
# 195     7.6   8.521167 -0.921167  0.848548  0.921167
# 196     9.7  12.012522 -2.312522  5.347760  2.312522
#
# [80 rows x 5 columns]

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 100%;" aria-valuenow="100" aria-valuemin="100" aria-valuemax="100">100%</div>
# </div>

# %% [markdown]
# <a id="the_end"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ THE END ✨</p>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>You can access the entire study through the following links. Good luck with your work. </h6>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> 📉 Simple Linear Regression - Supervised Model 🧾 </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/machine_learning/tree/main/Project/simple_linear_regression_supervised_model"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/huseyincenik/simple-linear-regression-supervised-model"><b>My Kaggle Account</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>
