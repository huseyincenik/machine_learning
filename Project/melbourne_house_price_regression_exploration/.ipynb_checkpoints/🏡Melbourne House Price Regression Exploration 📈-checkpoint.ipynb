# %% [markdown]
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED;font-size:220%; text-align:center; border-radius: 15px 55px;">🏡Melbourne House Price Regression Exploration 📈</p>

# %% [markdown]
# ![melşbourne.png](https://i.guim.co.uk/img/media/d5e5e495385b34db43a0d0e4b2920cf5184c370d/2814_1777_4354_2614/master/4354.jpg?width=1000&dpr=1&s=none)

# %% [markdown]
# # 🏡Melbourne House Price Regression Exploration 📈
#
# This project delves into an in-depth analysis of Melbourne's housing market using a dataset available on Kaggle. The dataset comprises various attributes of Melbourne's houses, with their corresponding prices. The project is divided into five key phases, each playing a vital role in extracting valuable insights from the dataset and creating predictive models for housing prices.
#
# The dataset can be found on Kaggle at the following link: [Melbourne Housing Market Dataset](https://www.kaggle.com/datasets/anthonypino/melbourne-housing-market/data).

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 0%;" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100">0%</div>
# </div>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> 🏡Melbourne House Price Regression Exploration 📈
#  </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/machine_learning/tree/main/Project/melbourne_house_price_regression_exploration"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/huseyincenik/melbourne-house-price-regression-exploration"><b>Kaggle Notebook Link</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>

# %% [markdown]
# <a id="toc"></a>
# <div style="border-radius: 10px;
#             border: black solid;
#             background-color: lightblue;
#             font-size: 100%;
#             text-align: left;
#             box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
# <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: white; background-color: red;"><center> ✍✍ Content ✍✍</center></h2>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#part_1">PART - 1 ( DATA CLEANING )</a></li>
#     <li><a href="#part_2">PART - 2 ( HANDLING WITH MISSING VALUES )</a></li>
#     <li><a href="#part_3">PART - 3 ( HANDLING WITH OUTLIERS )</a></li>
#     <li><a href="#part_4">PART - 4 ( FEATURE ENGINEERING )</a></li>
#     <li><a href="#part_5">PART - 5 (  ML PREDICTION )</a></li>
#     </ul>
# </div>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#part_5_final_model">FINAL MODEL</a></li>
#     <li><a href="#summary">SUMMARY</a></li>
#     <li><a href="#the_end">THE END </a></li>
#   </ul>
# </div>
# </div>

# %% [markdown]
# <a id="part_1"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 1 ( Data Cleaning ) ✨</p>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_dataset" role="tab" aria-controls="profile">
#     Dataset Explanation
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_importing" role="tab" aria-controls="messages">
#     Importing Libraries Needed in This Notebook
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_def" role="tab" aria-controls="settings">
#     User Defined Functions (DEFs)
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_reading" role="tab" aria-controls="settings">
#     Reading & Understanding Data
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
# </div>

# %% [markdown]
# <a id="part_1_dataset"></a>
# <div style="border-radius: 10px; border: 1px solid black; background-color:#3498DB ; font-size: 100%; text-align: left; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); padding: 10px; margin-bottom: 20px;">
#     <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">⚡️ Dataset Explanation ⚡️</h2>
#     <p>
#      <strong style="color: white;">Data Fields:</strong>
#       <ul>
#         <li><span style="color: white;">Suburb:</span> Suburb</li>
#         <li><span style="color: white;">Address:</span> Address</li>
#         <li><span style="color: white;">Rooms:</span> Number of rooms</li>
#         <li><span style="color: white;">Price:</span> Price in Australian dollars</li>
#         <li><span style="color: white;">Method:</span> S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclosed; N/A - price or highest bid not available.</li>
#         <li><span style="color: white;">Type:</span> br - bedroom(s); h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.</li>
#         <li><span style="color: white;">SellerG:</span> Real Estate Agent</li>
#         <li><span style="color: white;">Date:</span> Date sold</li>
#         <li><span style="color: white;">Distance:</span> Distance from CBD in Kilometres</li>
#         <li><span style="color: white;">Regionname:</span> General Region (West, North West, North, North east …etc)</li>
#         <li><span style="color: white;">Propertycount:</span> Number of properties that exist in the suburb.</li>
#         <li><span style="color: white;">Bedroom2:</span> Scraped # of Bedrooms (from different source)</li>
#         <li><span style="color: white;">Bathroom:</span> Number of Bathrooms</li>
#         <li><span style="color: white;">Car:</span> Number of carspots</li>
#         <li><span style="color: white;">Landsize:</span> Land Size in Metres</li>
#         <li><span style="color: white;">BuildingArea:</span> Building Size in Metres</li>
#         <li><span style="color: white;">YearBuilt:</span> Year the house was built</li>
#         <li><span style="color: white;">CouncilArea:</span> Governing council for the area</li>
#         <li><span style="color: white;">Lattitude:</span> Self explanitory</li>
#         <li><span style="color: white;">Longtitude:</span> Self explanitory</li>
#       </ul>
#     </p>
# </div>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="part_1_importing"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Importing Libraries Needed in This Notebook ✨</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skimpy import clean_columns
import scipy.stats as stats

# !pip install termcolor
import colorama
from colorama import Fore, Style  # makes strings colored
from termcolor import colored
from termcolor import cprint

# ml algorithm
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, validation_curve
from yellowbrick.model_selection import ValidationCurve
from yellowbrick.regressor import PredictionError
from yellowbrick.features import RadViz
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_validate
from sklearn.linear_model import ElasticNet
from yellowbrick.model_selection import FeatureImportances
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.impute import KNNImputer
from statsmodels.stats.outliers_influence import variance_inflation_factor


from scipy.stats import skew


import warnings
warnings.filterwarnings('ignore')
# plt.rcParams["figure.figsize"] = (7,4)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.max_rows', 1000)

# %%
# version control
import pandas
import numpy
import matplotlib
import seaborn
import sklearn

print("Pandas Version: ", pandas.__version__)
print("NumPy Version: ", numpy.__version__)
print("Matplotlib Version: ", matplotlib.__version__)
print("Seaborn Version: ", seaborn.__version__)
print("Scikit-Learn Version: ", sklearn.__version__)
# Out:
# Pandas Version:  1.5.3
# NumPy Version:  1.23.5
# Matplotlib Version:  3.7.0
# Seaborn Version:  0.12.2
# Scikit-Learn Version:  1.3.1

# %%
# pip install skimpy

# %% [markdown]
# <a id="part_1_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ User Defined Functions (DEFs) ✨</p>

# %% [markdown]
# <a href="#part_1" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 1</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
## Some Useful User-Defined-Functions

###############################################################################

def missing_values(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values[missing_values['Missing_Number']>0]
###############################################################################
def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          colored('*'*100, 'red', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')

#     df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
#     print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
#           colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Descriptive Statistics \n", attrs=['bold']), df.describe().round(2),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='') # Gives a statstical breakdown of the data.
#     print(colored("Descriptive Statistics (Categorical Columns) \n", attrs=['bold']), df.describe(include=object).T,'\n',
#           colored('*'*100, 'red', attrs=['bold']), sep='') # Gives a statstical breakdown of the data.

###############################################################################
def first_look(df, col):
    """
    Prints basic information about a column in a Pandas DataFrame.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame to analyze.
    col : str
        The name of the column to analyze.

    Returns:
    --------
    None.

    Prints:
    -------
    column name    : str
        The name of the column being analyzed.
    per_of_nulls   : float
        The percentage of null values in the column.
    num_of_nulls   : int
        The number of null values in the column.
    num_of_uniques : int
        The number of unique values in the column.
    shape_of_df    : tuple
        The shape of the DataFrame.
    The unique values in the column and their frequency of occurrence.
    """
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum() * 100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].astype(str).nunique())
    print("shape_of_df    : ", df.shape)
    print("--------------------------------")
    print(df[col].value_counts(dropna=False))
###############################################################################


def duplicate_values(df):
    print(colored("Duplicate check...", attrs=['bold']), sep='')
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored(" Duplicates were dropped!"),'\n',
              colored('*'*100, 'red', attrs=['bold']), sep='')
    else:
        print(colored("There are no duplicates"),'\n',
              colored('*'*100, 'red', attrs=['bold']), sep='')

###############################################################################

# %%
def visualize_data(df, column, plot_type='histogram', iqr_multiplier=1.5, **kwargs):
    """
    Visualizes a column from a DataFrame using the specified plot type.

    Parameters:
        df (DataFrame): The DataFrame containing the data.
        column (str): The name of the column to visualize.
        plot_type (str): The type of plot to create ('histogram', 'box', 'qq', 'bar', 'pie', 'all').
        iqr_multiplier (float): The multiplier for determining whisker length in box plots (default is 1.5).
        **kwargs: Additional keyword arguments for customizing the plot.

    Returns:
        None
    """
    data = df[column]

    if plot_type == 'all':
        plot_types = ['histogram', 'box', 'qq']
        for plot_type in plot_types:
            visualize_data(df, column, plot_type=plot_type, iqr_multiplier=iqr_multiplier, **kwargs)
    else:
        if plot_type == 'histogram':
            plt.figure(figsize=(10, 6))
            sns.histplot(data, kde=True, **kwargs)
            
            skewness = data.skew()
            kurtosis = data.kurtosis()
            mean = data.mean()
            median = data.median()
            mode = data.mode().iloc[0]
            # Başlığı ve değerleri düzenleyelim
            title = f'Histogram of {column}\n\n'
            title += f'Skewness: {skewness:.2f}, '  
            title += f'Kurtosis: {kurtosis:.2f}\n'  
            title += f'Mean: {mean:.2f}, ' 
            title += f'Median: {median:.2f}, '
            title += f'Mode: {mode:.2f}' 
            plt.title(title, fontweight='bold') 
            plt.xlabel(column)
            plt.ylabel('Frequency')
            plt.show()
        elif plot_type == 'box':
            
            mean = np.mean(data)
            median = np.median(data)
            q1 = np.percentile(data, 25)
            q3 = np.percentile(data, 75)
            iqr = q3 - q1
            upper_whisker = q3 + iqr_multiplier * iqr
            lower_whisker = q1 - iqr_multiplier * iqr
            min_whisker = np.min(data[data >= lower_whisker])
            max_whisker = np.max(data[data <= upper_whisker])
           
            num_below_min_whisker = np.sum(data < lower_whisker)
            num_above_max_whisker = np.sum(data > upper_whisker)
            plt.figure(figsize=(10, 6))
            sns.boxplot(y=data, **kwargs)
            plt.title(f'Box Plot of {column}\n\nMean: {mean:.2f}, Median: {median:.2f}, Min Whisker: {min_whisker:.2f}, Max Whisker: {max_whisker:.2f}\nIQR Multiplier: {iqr_multiplier}\n\nNumber of Extreme Values in Below Min Whisker: {num_below_min_whisker}\n Number of Extreme Values in Above Max Whisker: {num_above_max_whisker}', fontweight="bold")
            plt.ylabel(column)
            plt.show()
        elif plot_type == 'qq':
     
            plt.figure(figsize=(10, 6))
            stats.probplot(data, dist="norm", plot=plt)
            plt.title(f'Q-Q Plot of {column}\nNormality Check',  fontweight='bold')
            plt.xlabel('Theoretical Quantiles')
            plt.ylabel('Sample Quantiles')
            plt.show()
        elif plot_type == 'bar':
            value_counts = data.value_counts()
            x = value_counts.index
            y = value_counts.values
            total_height = sum(y)  
            percentages = [(count / total_height) * 100 for count in y] 
            fig, ax = plt.subplots(figsize=(10, 6))
            bars = ax.barh(x, percentages, **kwargs)  # Horizontal bar chart
            plt.title(f'Bar Chart of {column}', fontweight='bold')
            plt.xlabel('Percentage')
            plt.ylabel(column)
            for bar, percentage in zip(bars, percentages):
                width = bar.get_width()
                ax.annotate(f'{percentage:.2f}%', xy=(width, bar.get_y() + bar.get_height() / 2),
                            xytext=(3, 0), textcoords='offset points', va='center')
            plt.show()
        elif plot_type == 'pie':
            value_counts = data.value_counts()
            labels = value_counts.index
            sizes = value_counts.values
            plt.figure(figsize=(8, 8))
            plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, **kwargs)
            plt.title(f'Pie Chart of {column}', fontweight='bold')
            plt.axis('equal')
            plt.show()

# %%
def scatter_or_joint_plot(data, x_col, y_col, title=None, x_label=None, y_label=None, kind='scatter', **kwargs):
    """
    Draws a scatter plot or joint plot on the given DataFrame.

    Parameters:
        data (DataFrame): The DataFrame containing the data.
        x_col (str): The column name for the x-axis.
        y_col (str): The column name for the y-axis.
        title (str, optional): The title of the plot. Defaults to None (uses column names).
        x_label (str, optional): The label for the x-axis. Defaults to None (uses column name).
        y_label (str, optional): The label for the y-axis. Defaults to None (uses column name).
        kind (str, optional): The type of the plot ('scatter' or 'joint'). Defaults to 'scatter'.
        **kwargs: Additional parameters for the scatter or joint plot.

    Returns:
        None
    """
    if title is None:
        title = f'Plot of {x_col} vs {y_col}'
    if x_label is None:
        x_label = x_col
    if y_label is None:
        y_label = y_col

    plt.figure(figsize=(10, 6))
    corr_coefficient = np.corrcoef(data[x_col], data[y_col])[0, 1]

    if kind == 'scatter':
        sns.scatterplot(data=data, x=x_col, y=y_col, **kwargs)
        title_with_corr = f'{title} (Scatter)\n\nCorrelation: {corr_coefficient:.2f}'
        plt.title(title_with_corr, fontweight='bold')
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        plt.grid(True)
    elif kind == 'joint':
        g = sns.jointplot(x=x_col, y=y_col, data=data, **kwargs)
        g.fig.suptitle(f'{title}', fontweight='bold', y=1.02)
        g.ax_joint.set_xlabel(x_label)
        g.ax_joint.set_ylabel(y_label)
        g.ax_marg_x.set_title(f'Correlation: {corr_coefficient:.2f}', fontweight='bold')
        plt.subplots_adjust(top=0.9)

    plt.show()

# scatter_or_joint_plot(df, 'Compressive Strength (28-day)(Mpa)', 'Cement', kind='scatter')
# scatter_or_joint_plot(df, 'Compressive Strength (28-day)(Mpa)', 'Cement', kind='joint')

# %% [markdown]
# <a id="part_1_reading"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Reading & Understanding Data ✨</p>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df0 = pd.read_csv("Melbourne_housing_FULL.csv")
df_full = df0.copy()
df_full.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df_full = clean_columns(df_full)
# Out:
# 21 column names have been cleaned

# %%
df_full = df_full[[i for i in df_full.columns if i != 'price'] + ['price']]

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">As the column to be predicted is "Price," it was placed at the end of the dataset.</p>
# </div>

# %%
first_looking(df_full)
duplicate_values(df_full)
# Out:
# Shape:(34857, 21)
# ****************************************************************************************************
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   suburb         34857 non-null  object
#  1   address        34857 non-null  object
#  2   rooms          34857 non-null  int64
#  3   type           34857 non-null  object
#  4   method         34857 non-null  object
#  5   seller_g       34857 non-null  object
#  6   date           34857 non-null  object
#  7   distance       34856 non-null  float64
#  8   postcode       34856 non-null  float64
#  9   bedroom_2      26640 non-null  float64
#  10  bathroom       26631 non-null  float64
#  11  car            26129 non-null  float64
#  12  landsize       23047 non-null  float64
#  13  building_area  13742 non-null  float64
# ...

# %%
# Checking Mixed Type of Data:
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''

    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df_full)
# Out:
# Column council_area has mixed object types.
# Column regionname has mixed object types.

# %%
# # import warnings

# # Filtreleme yapmadan önce tüm uyarıları yakalayın
# warnings.filterwarnings("ignore")
# from dataprep.datasets import load_dataset
# from dataprep.eda import create_report
# create_report(df_full).show_browser()

# %%
# pip install dataprep

# %%
df_full.council_area.value_counts(dropna = False)
# Out:
# Boroondara City Council           3675
# Darebin City Council              2851
# Moreland City Council             2122
# Glen Eira City Council            2006
# Melbourne City Council            1952
# Banyule City Council              1861
# Moonee Valley City Council        1791
# Bayside City Council              1764
# Brimbank City Council             1593
# Monash City Council               1466
# Stonnington City Council          1460
# Maribyrnong City Council          1451
# Port Phillip City Council         1280
# Hume City Council                 1214
# Yarra City Council                1186
# Manningham City Council           1045
# Hobsons Bay City Council           942
# Kingston City Council              871
# Whittlesea City Council            828
# Wyndham City Council               624
# Whitehorse City Council            618
# Maroondah City Council             506
# Knox City Council                  371
# Greater Dandenong City Council     314
# ...

# %%
for i in df_full.columns[:]:
    print("*" * 30)
    print("Column Name: ", i)
    print()
    print("Number of NaN values in the column: ", df_full[i].isnull().sum())
    print()
    print("What percentage of the column consists of NaN values?", (df_full[i].isnull().sum() / len(df_full)) * 100)
    print()
    print("Value counts for the column:\n", df_full[i].value_counts(dropna=False))
# Out:
# ******************************
# Column Name:  suburb
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  Reservoir          844
# Bentleigh East     583
# Richmond           552
# Glen Iris          491
# Preston            485
#                   ...
# Belgrave             1
# Cranbourne East      1
# Yarra Glen           1
# Olinda               1
# Menzies Creek        1
# Name: suburb, Length: 351, dtype: int64
# ******************************
# Column Name:  address
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  5 Charles St        6
# 25 William St       4
# 57 Bay Rd           3
# 14 Arthur St        3
# 16 Clyde St         3
#                    ..
# 2/2 Nicholls Rd     1
# 17 Fraser St        1
# 11a Bewdley St      1
# 6/13 Ulupna Rd      1
# 3 Tarrengower St    1
# ...

# %% [markdown]
# <a id="part_2"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 2 ( Handling With Missing Values ) ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_2_def" role="tab" aria-controls="profile">
#     User Defined Functions (DEFs)
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_2_operation" role="tab" aria-controls="messages">
#     Operations on some columns
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_price" role="tab" aria-controls="settings">
#     Column Name : price
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_building_area" role="tab" aria-controls="settings">
#     Column Name : building_area
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_year_built" role="tab" aria-controls="settings">
#     Column Name : year_built
#     <span class="badge badge-primary badge-pill">5</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_land_size" role="tab" aria-controls="settings">
#     Column Name : land_size
#     <span class="badge badge-primary badge-pill">6</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_car" role="tab" aria-controls="settings">
#     Column Name : car
#     <span class="badge badge-primary badge-pill">7</span>
#   </a>
#  <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_bathroom" role="tab" aria-controls="settings">
#     Column Name : bathroom
#     <span class="badge badge-primary badge-pill">8</span>
#   </a>
#
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_bedroom_2" role="tab" aria-controls="settings">
#     Column Name : bedroom_2
#     <span class="badge badge-primary badge-pill">9</span>
#   </a>
#  <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_propertycount" role="tab" aria-controls="settings">
#     Column Name : propertycount
#     <span class="badge badge-primary badge-pill">10</span>
#   </a>
#
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_regionname" role="tab" aria-controls="settings">
#     Column Name : regionname
#     <span class="badge badge-primary badge-pill">11</span>
#   </a>
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_council_area" role="tab" aria-controls="settings">
#     Column Name : council_area
#     <span class="badge badge-primary badge-pill">12</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_distance" role="tab" aria-controls="settings">
#     Column Name : distance
#     <span class="badge badge-primary badge-pill">13</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_overview_missing" role="tab" aria-controls="settings">
#     General Overwiew to Missing Values
#     <span class="badge badge-primary badge-pill">14</span>
#   </a>
# </div>

# %% [markdown]
# <a id="part_2_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ User Defined Functions (DEFs) ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
def fill_most_freq(df, group_col, col_name):
    """
    Fills missing values in a column of a Pandas DataFrame `df` with the most frequent value 
    in each group defined by a grouping column.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col (str): The name of the grouping column.
    col_name (str): The name of the column to fill missing values in.

    Returns:
    None.

    Prints:
    - The name of the column that was filled.
    - The percentage of null values in the column after filling.
    - The number of null values in the column after filling.
    - The number of unique values in the column after filling.
    - The value counts for each unique value in the column after filling, including null values, sorted by index.
    """    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %%
def fill_mode(df, group_col1, group_col2, col_name):
    """
    Fills missing values in a column of a Pandas DataFrame `df` based on the values in two other columns.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col1 (str): The name of the first grouping column.
    group_col2 (str): The name of the second grouping column.
    col_name (str): The name of the column to fill missing values in.

    Returns:
    None.

    Prints:
    - The name of the column that was filled.
    - The percentage of null values in the column after filling.
    - The number of null values in the column after filling.
    - The number of unique values in the column after filling.
    - The value counts for each unique value in the column after filling, including null values.
    """    
    group1_modes = df.groupby(group_col1)[col_name].transform(lambda x: x.mode().iat[0] if not x.mode().empty else None)
    group2_modes = df.groupby([group_col1, group_col2])[col_name].transform(lambda x: x.mode().iat[0] if not x.mode().empty else None)
    global_mode = df[col_name].mode().iat[0] if not df[col_name].mode().empty else None


    for index, row in df.iterrows():
        if pd.notna(row[col_name]):
            continue
        group1_val = row[group_col1]
        group2_val = row[group_col2]
        if pd.notna(group2_modes[index]):
            df.at[index, col_name] = group2_modes[index]
        elif pd.notna(group1_modes[index]):
            df.at[index, col_name] = group1_modes[index]
        else:
            df.at[index, col_name] = global_mode

            
    print("column name    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum() * 100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna=False))

# fill_mode(df, 'group_col1', 'group_col2', 'col_name')

# %%
def fill_prop(df, group_col, col_name):
    """
    Fills missing values in a column of a Pandas DataFrame `df` using forward and backward fill based on a grouping column.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col (str): The name of the grouping column.
    col_name (str): The name of the column to fill missing values in.

    Returns:
    None.

    Prints:
    - The name of the column that was filled.
    - The percentage of null values in the column after filling.
    - The number of null values in the column after filling.
    - The number of unique values in the column after filling.
    - The value counts for each unique value in the column after filling, including null values, sorted by index.
    """    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %%
def fill(df, group_col1, group_col2, col_name, method):
    """
    Fills missing values in a column of a Pandas DataFrame `df` based on double-stage grouping and a specified filling method.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col1 (str): The name of the first grouping column.
    group_col2 (str): The name of the second grouping column.
    col_name (str): The name of the column to fill missing values in.
    method (str): The filling method to use. Can be "mode", "mean", "median", "ffill", or "bfill".

    Returns:
    None.

    Prints:
    None.
    """
    
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

    elif method == "mean":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df[col_name].mean(), inplace = True)
        
    elif method == "median":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df[col_name].median(), inplace = True)
        
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a href="#top" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>

# %% [markdown]
# <p><strong style="color:blue;">Some columns</strong>, as seen below, have missing values. The <em style="color:blue;">missing_values</em> function displays the number of missing values in each column.</p>
#
# <p>The columns <em style="color:red;">building_area, year_built, landsize, car, bathroom, bedroom_2, longtitude, lattitude, price, regionname, council_area, propertycount, postcode, distance</em> contain missing values in the data set.</p>
#
# <p>When dealing with missing values, it is essential to address them effectively to ensure accurate analysis and modeling.</p>

# %%
missing_values(df_full)
# Out:
#                Missing_Number  Missing_Percent
# building_area           21115        60.577806
# year_built              19306        55.387882
# landsize                11810        33.882258
# car                      8728        25.040165
# bathroom                 8226        23.599954
# bedroom_2                8217        23.574134
# longtitude               7976        22.882717
# lattitude                7976        22.882717
# price                    7609        21.829814
# council_area                3         0.008607
# regionname                  3         0.008607
# propertycount               3         0.008607
# postcode                    1         0.002869
# distance                    1         0.002869

# %% [markdown]
# <a id="part_2_operation"></a>
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title" >Operations on some columns</button>

# %% [markdown]
# <a id="part_2_price"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> price </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b style="color:red">Operation:</b> The NaN values in the <span style="color:red; font-weight: bold">"Price"</span> column were filled with the median values grouped by <span style="color:red; font-weight: bold">"Rooms"</span> and <span style="color:red; font-weight: bold">"Type"</span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "price")
# Out:
# column name    :  price
# --------------------------------
# per_of_nulls   :  % 21.83
# num_of_nulls   :  7609
# num_of_uniques :  2872
# shape_of_df    :  (34856, 21)
# --------------------------------
# NaN          7609
# 600000.0      235
# 1100000.0     235
# 650000.0      219
# 800000.0      217
#              ...
# 1452000.0       1
# 2555000.0       1
# 949500.0        1
# 426500.0        1
# 1605500.0       1
# Name: price, Length: 2872, dtype: int64

# %%
df_full.corrwith(df_full['price'])
# Out:
# rooms            0.465238
# distance        -0.211384
# postcode         0.044950
# bedroom_2        0.430275
# bathroom         0.429878
# car              0.201803
# landsize         0.032748
# building_area    0.100754
# year_built      -0.333306
# lattitude       -0.215607
# longtitude       0.197874
# propertycount   -0.059017
# price            1.000000
# dtype: float64

# %%
df_full.type.value_counts()
# Out:
# h    23980
# u     7297
# t     3579
# Name: type, dtype: int64

# %%
fill(df_full, "rooms", "type", "price", "median")
# Out:
# COLUMN NAME    :  price
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2872
# --------------------------------
# 85000.0       1
# 112000.0      1
# 121000.0      1
# 131000.0      1
# 145000.0      2
#              ..
# 7000000.0     1
# 7650000.0     1
# 8000000.0     1
# 9000000.0     1
# 11200000.0    1
# Name: price, Length: 2872, dtype: int64

# %%
visualize_data(df_full, "price")

# %% [markdown]
# <a id="part_2_building_area"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> building_area </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"> <b>"Building Area"</b> </span> column were filled with the median values grouped by <span style="color:red"> <b>"Rooms"</b> </span> and <span style="color:red"> <b>"Price"</b> </span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "building_area")
# Out:
# column name    :  building_area
# --------------------------------
# per_of_nulls   :  % 60.58
# num_of_nulls   :  21115
# num_of_uniques :  741
# shape_of_df    :  (34856, 21)
# --------------------------------
# NaN       21115
# 120.00      185
# 100.00      161
# 110.00      159
# 130.00      153
#           ...
# 53.30         1
# 270.18        1
# 167.13        1
# 443.00        1
# 649.00        1
# Name: building_area, Length: 741, dtype: int64

# %%
df_full.corrwith(df_full['building_area'])
# Out:
# rooms            0.156231
# distance         0.076295
# postcode         0.042436
# bedroom_2        0.154159
# bathroom         0.147554
# car              0.104371
# landsize         0.354532
# building_area    1.000000
# year_built       0.067758
# lattitude        0.017158
# longtitude      -0.002160
# propertycount   -0.024516
# price            0.112277
# dtype: float64

# %%
help(fill)
# Out:
# Help on function fill in module __main__:
#
# fill(df, group_col1, group_col2, col_name, method)
#     Fills missing values in a column of a Pandas DataFrame `df` based on double-stage grouping and a specified filling method.
#
#     Parameters:
#     df (pandas.DataFrame): The DataFrame to operate on.
#     group_col1 (str): The name of the first grouping column.
#     group_col2 (str): The name of the second grouping column.
#     col_name (str): The name of the column to fill missing values in.
#     method (str): The filling method to use. Can be "mode", "mean", "median", "ffill", or "bfill".
#
#     Returns:
#     None.
#
#     Prints:
#     None.

# %%
fill(df_full, "rooms", "price", "building_area", "median")
# Out:
# COLUMN NAME    :  building_area
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  934
# --------------------------------
# 0.00        87
# 0.01         1
# 1.00        15
# 2.00        20
# 3.00        25
#             ..
# 3647.00      1
# 4645.00      1
# 6178.00      1
# 6791.00      1
# 44515.00     1
# Name: building_area, Length: 934, dtype: int64

# %% [markdown]
# <a id="part_2_year_built"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> year_built </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"> <b>"Year Built"</b> </span> column were filled with the mode values grouped by <span style="color:red"> <b>"Suburb"</b> </span> and <span style="color:red"> <b>"Distance"</b> </span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "year_built")
# Out:
# column name    :  year_built
# --------------------------------
# per_of_nulls   :  % 55.39
# num_of_nulls   :  19306
# num_of_uniques :  161
# shape_of_df    :  (34856, 21)
# --------------------------------
# NaN       19306
# 1970.0     1490
# 1960.0     1260
# 1950.0     1089
# 1980.0      726
#           ...
# 1876.0        1
# 2106.0        1
# 1897.0        1
# 1830.0        1
# 1879.0        1
# Name: year_built, Length: 161, dtype: int64

# %%
df_full.corrwith(df_full['year_built']).sort_values()
# Out:
# price           -0.290216
# longtitude      -0.022261
# rooms           -0.012743
# bedroom_2       -0.002017
# propertycount    0.022456
# building_area    0.038489
# landsize         0.044484
# postcode         0.089800
# lattitude        0.091606
# car              0.128688
# bathroom         0.167869
# distance         0.323035
# year_built       1.000000
# dtype: float64

# %%
df_full.year_built.value_counts().sort_index().to_dict()
# Out:
# {1196.0: 1,
#  1800.0: 1,
#  1820.0: 1,
#  1830.0: 1,
#  1850.0: 4,
#  1854.0: 2,
#  1855.0: 1,
#  1856.0: 1,
#  1857.0: 2,
#  1860.0: 11,
#  1862.0: 1,
#  1863.0: 3,
#  1868.0: 1,
#  1869.0: 1,
#  1870.0: 6,
#  1871.0: 1,
#  1872.0: 2,
#  1875.0: 4,
#  1876.0: 1,
#  1877.0: 3,
#  1879.0: 1,
#  1880.0: 171,
#  1881.0: 2,
#  1883.0: 1,
#  1884.0: 1,
#  1885.0: 12,
#  1886.0: 7,
#  1887.0: 5,
#  1888.0: 15,
#  1889.0: 4,
#  1890.0: 444,
#  1891.0: 3,
#  1892.0: 3,
#  1893.0: 3,
#  1894.0: 2,
#  1895.0: 10,
#  1896.0: 1,
#  1897.0: 1,
#  1898.0: 3,
#  1899.0: 2,
#  1900.0: 606,
#  1901.0: 2,
#  1902.0: 3,
#  1903.0: 3,
#  1904.0: 4,
#  1905.0: 41,
#  1906.0: 6,
#  1907.0: 6,
#  1908.0: 5,
#  1909.0: 2,
#  1910.0: 460,
#  1911.0: 3,
#  1912.0: 10,
#  1913.0: 5,
#  1914.0: 4,
#  1915.0: 126,
#  1916.0: 6,
#  1917.0: 6,
#  1918.0: 6,
#  1919.0: 6,
#  1920.0: 545,
#  1921.0: 2,
#  1922.0: 7,
#  1923.0: 8,
#  1924.0: 5,
#  1925.0: 169,
#  1926.0: 17,
#  1927.0: 15,
#  1928.0: 24,
# ...

# %%
help(fill_mode)
# Out:
# Help on function fill_mode in module __main__:
#
# fill_mode(df, group_col1, group_col2, col_name)
#     Fills missing values in a column of a Pandas DataFrame `df` based on the values in two other columns.
#
#     Parameters:
#     df (pandas.DataFrame): The DataFrame to operate on.
#     group_col1 (str): The name of the first grouping column.
#     group_col2 (str): The name of the second grouping column.
#     col_name (str): The name of the column to fill missing values in.
#
#     Returns:
#     None.
#
#     Prints:
#     - The name of the column that was filled.
#     - The percentage of null values in the column after filling.
#     - The number of null values in the column after filling.
#     - The number of unique values in the column after filling.
#     - The value counts for each unique value in the column after filling, including null values.

# %%
fill_mode(df_full,"suburb",  "distance", "year_built")
# Out:
# column name    :  year_built
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  160
# --------------------------------
# 1970.0    5808
# 1950.0    5184
# 1960.0    4090
# 1900.0    2110
# 1980.0    1846
#           ...
# 1884.0       1
# 1868.0       1
# 2106.0       1
# 1897.0       1
# 1879.0       1
# Name: year_built, Length: 160, dtype: int64

# %%
help(visualize_data)
# Out:
# Help on function visualize_data in module __main__:
#
# visualize_data(df, column, plot_type='histogram', iqr_multiplier=1.5, **kwargs)
#     Visualizes a column from a DataFrame using the specified plot type.
#
#     Parameters:
#         df (DataFrame): The DataFrame containing the data.
#         column (str): The name of the column to visualize.
#         plot_type (str): The type of plot to create ('histogram', 'box', 'qq', 'bar', 'pie', 'all').
#         iqr_multiplier (float): The multiplier for determining whisker length in box plots (default is 1.5).
#         **kwargs: Additional keyword arguments for customizing the plot.
#
#     Returns:
#         None

# %%
visualize_data(df_full, "year_built", plot_type = "histogram")

# %% [markdown]
# <a id="part_2_land_size"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> land_size </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"> <b>"Land Size"</b> </span> column were filled with the median values grouped by <span style="color:red"> <b>"Rooms"</b> </span> and <span style="color:red"> <b>"Building Area"</b> </span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "landsize")
# Out:
# column name    :  landsize
# --------------------------------
# per_of_nulls   :  % 33.88
# num_of_nulls   :  11810
# num_of_uniques :  1685
# shape_of_df    :  (34856, 21)
# --------------------------------
# NaN       11810
# 0.0        2437
# 650.0       204
# 697.0       123
# 585.0        97
#           ...
# 1026.0        1
# 1174.0        1
# 1803.0        1
# 2347.0        1
# 1163.0        1
# Name: landsize, Length: 1685, dtype: int64

# %%
df_full.corrwith(df_full['landsize']).sort_values()
# Out:
# propertycount   -0.018197
# longtitude      -0.002579
# year_built       0.006843
# lattitude        0.025317
# price            0.034631
# bathroom         0.036341
# bedroom_2        0.037019
# rooms            0.037402
# car              0.037830
# postcode         0.040665
# distance         0.060864
# building_area    0.089862
# landsize         1.000000
# dtype: float64

# %%
df_full.columns
# Out:
# Index(['suburb', 'address', 'rooms', 'type', 'method', 'seller_g', 'date',
#        'distance', 'postcode', 'bedroom_2', 'bathroom', 'car', 'landsize',
#        'building_area', 'year_built', 'council_area', 'lattitude',
#        'longtitude', 'regionname', 'propertycount', 'price'],
#       dtype='object')

# %%
fill(df_full, "rooms", "building_area", "landsize", "median")
# Out:
# COLUMN NAME    :  landsize
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1857
# --------------------------------
# 0.0         3743
# 1.0            3
# 2.0            1
# 3.0            2
# 5.0            1
#             ...
# 76000.0        1
# 80000.0        1
# 89030.0        1
# 146699.0       1
# 433014.0       1
# Name: landsize, Length: 1857, dtype: int64

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Rooms (Number of Rooms): The number of rooms in houses is often associated with land size. Larger houses tend to have more rooms.</p>
#     <p style="font-weight: bold; color: white;">Building Area: There may be a relationship between the building area of houses and land size. Houses with a larger building area may tend to have larger land.</p>
# </div>

# %% [markdown]
# <a id="part_2_car"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> car </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"><b>"Car"</b></span> column were filled with the median values grouped by <span style="color:red"><b>"Building Area"</b></span> and <span style="color:red"><b>"Land Size"</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "car")
# Out:
# column name    :  car
# --------------------------------
# per_of_nulls   :  % 25.04
# num_of_nulls   :  8728
# num_of_uniques :  16
# shape_of_df    :  (34856, 21)
# --------------------------------
# 2.0     12213
# 1.0      9164
# NaN      8728
# 0.0      1631
# 3.0      1606
# 4.0      1161
# 5.0       151
# 6.0       140
# 7.0        25
# 8.0        23
# 10.0        6
# 9.0         3
# 11.0        2
# 26.0        1
# 18.0        1
# 12.0        1
# Name: car, dtype: int64

# %%
df_full.corrwith(df_full['car']).sort_values()
# Out:
# propertycount   -0.009611
# lattitude       -0.009018
# landsize         0.038526
# longtitude       0.047200
# postcode         0.067885
# building_area    0.105915
# year_built       0.135638
# price            0.209209
# distance         0.241831
# bathroom         0.307520
# bedroom_2        0.388492
# rooms            0.393880
# car              1.000000
# dtype: float64

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Building Area: The building area of houses represents the size of the indoor space, which can impact the number of parking spaces.</p>
#     <p style="font-weight: bold; color: white;">Landsize: The land size of houses can affect the number of parking spaces, as houses with larger land sizes may have more parking spaces.</p>
# </div>

# %%
fill(df_full,"building_area", "landsize",  "car", "median")
# Out:
# COLUMN NAME    :  car
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  19
# --------------------------------
# 0.0      1670
# 0.5        20
# 1.0     12610
# 1.5       220
# 2.0     17029
# 2.5        68
# 3.0      1675
# 3.5        15
# 4.0      1185
# 5.0       158
# 6.0       142
# 7.0        25
# 8.0        25
# 9.0         3
# 10.0        6
# 11.0        2
# 12.0        1
# 18.0        1
# 26.0        1
# Name: car, dtype: int64

# %%
df_full.car = df_full.car.round()
df_full.car
# Out:
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 34852    3.0
# 34853    1.0
# 34854    2.0
# 34855    2.0
# 34856    0.0
# Name: car, Length: 34856, dtype: float64

# %% [markdown]
# <a id="part_2_bathroom"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> bathroom </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"><b>"Bathroom"</b></span> column were filled with the median values grouped by <span style="color:red"><b>"Rooms"</b></span> and <span style="color:red"><b>"Price"</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "bathroom")
# Out:
# column name    :  bathroom
# --------------------------------
# per_of_nulls   :  % 23.6
# num_of_nulls   :  8226
# num_of_uniques :  12
# shape_of_df    :  (34856, 21)
# --------------------------------
# 1.0     12969
# 2.0     11064
# NaN      8226
# 3.0      2180
# 4.0       269
# 5.0        77
# 0.0        46
# 6.0        16
# 7.0         4
# 8.0         3
# 12.0        1
# 9.0         1
# Name: bathroom, dtype: int64

# %%
df_full.corrwith(df_full['bathroom']).sort_values()
# Out:
# lattitude       -0.059174
# propertycount   -0.032847
# landsize         0.037845
# longtitude       0.106444
# postcode         0.120079
# distance         0.126168
# year_built       0.159742
# building_area    0.161632
# car              0.307621
# price            0.416734
# rooms            0.611875
# bedroom_2        0.614940
# bathroom         1.000000
# dtype: float64

# %%
fill(df_full,"rooms", "price",  "bathroom", "median")
# Out:
# COLUMN NAME    :  bathroom
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  15
# --------------------------------
# 0.0        46
# 0.5         2
# 1.0     18209
# 1.5       299
# 2.0     13437
# 2.5        55
# 3.0      2428
# 3.5         2
# 4.0       273
# 5.0        80
# 6.0        16
# 7.0         4
# 8.0         3
# 9.0         1
# 12.0        1
# Name: bathroom, dtype: int64

# %%
df_full.bathroom = df_full.bathroom.round()
df_full.bathroom
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        2.0
#         ...
# 34852    1.0
# 34853    2.0
# 34854    1.0
# 34855    1.0
# 34856    1.0
# Name: bathroom, Length: 34856, dtype: float64

# %% [markdown]
# <a id="part_2_bedroom_2"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> bedroom_2 </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"><b>"Bedroom_2"</b></span> column were filled with the median values grouped by <span style="color:red"><b>"Rooms"</b></span> and <span style="color:red"><b>"Bathroom"</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "bedroom_2")
# Out:
# column name    :  bedroom_2
# --------------------------------
# per_of_nulls   :  % 23.57
# num_of_nulls   :  8217
# num_of_uniques :  16
# shape_of_df    :  (34856, 21)
# --------------------------------
# 3.0     11880
# NaN      8217
# 4.0      6348
# 2.0      5777
# 5.0      1427
# 1.0       966
# 6.0       168
# 7.0        30
# 0.0        17
# 8.0        13
# 9.0         5
# 10.0        4
# 30.0        1
# 20.0        1
# 16.0        1
# 12.0        1
# Name: bedroom_2, dtype: int64

# %%
df_full.corrwith(df_full['bedroom_2']).sort_values()
# Out:
# propertycount   -0.053453
# lattitude        0.003447
# landsize         0.040865
# year_built       0.064765
# postcode         0.089292
# longtitude       0.106172
# building_area    0.187194
# distance         0.269528
# car              0.389442
# price            0.448241
# bathroom         0.615032
# rooms            0.946755
# bedroom_2        1.000000
# dtype: float64

# %%
fill(df_full,"rooms", "bathroom",  "bedroom_2", "median")
# Out:
# COLUMN NAME    :  bedroom_2
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  16
# --------------------------------
# 0.0        17
# 1.0      1491
# 2.0      8466
# 3.0     15124
# 4.0      7810
# 5.0      1688
# 6.0       194
# 7.0        32
# 8.0        16
# 9.0         5
# 9.5         3
# 10.0        4
# 12.0        3
# 16.0        1
# 20.0        1
# 30.0        1
# Name: bedroom_2, dtype: int64

# %%
df_full.bedroom_2 = df_full.bedroom_2.round()
df_full.bedroom_2
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        3.0
#         ...
# 34852    4.0
# 34853    2.0
# 34854    2.0
# 34855    3.0
# 34856    2.0
# Name: bedroom_2, Length: 34856, dtype: float64

# %% [markdown]
# <a id="part_2_propertycount"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> propertycount </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"><b>"Propertycount"</b></span> column were filled with the mode values grouped by <span style="color:red"><b>"Suburb"</b></span> and <span style="color:red"><b>"Postcode"</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "propertycount")
# Out:
# column name    :  propertycount
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  3
# num_of_uniques :  343
# shape_of_df    :  (34856, 21)
# --------------------------------
# 21650.0    844
# 8870.0     722
# 10969.0    583
# 14949.0    552
# 10412.0    491
#           ...
# 129.0        1
# 1588.0       1
# 5462.0       1
# 1160.0       1
# 342.0        1
# Name: propertycount, Length: 343, dtype: int64

# %%
df_full.corrwith(df_full['propertycount']).sort_values()
# Out:
# rooms           -0.071678
# bedroom_2       -0.071280
# price           -0.057018
# bathroom        -0.044337
# building_area   -0.024928
# car             -0.022805
# distance        -0.018130
# landsize        -0.017929
# lattitude        0.011108
# longtitude       0.016357
# postcode         0.017111
# year_built       0.017762
# propertycount    1.000000
# dtype: float64

# %%
help(fill_mode)
# Out:
# Help on function fill_mode in module __main__:
#
# fill_mode(df, group_col1, group_col2, col_name)
#     Fills missing values in a column of a Pandas DataFrame `df` based on the values in two other columns.
#
#     Parameters:
#     df (pandas.DataFrame): The DataFrame to operate on.
#     group_col1 (str): The name of the first grouping column.
#     group_col2 (str): The name of the second grouping column.
#     col_name (str): The name of the column to fill missing values in.
#
#     Returns:
#     None.
#
#     Prints:
#     - The name of the column that was filled.
#     - The percentage of null values in the column after filling.
#     - The number of null values in the column after filling.
#     - The number of unique values in the column after filling.
#     - The value counts for each unique value in the column after filling, including null values.

# %%
fill_mode(df_full, "suburb", "postcode", "propertycount")
# Out:
# column name    :  propertycount
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  342
# --------------------------------
# 21650.0    845
# 8870.0     722
# 10969.0    583
# 14949.0    552
# 10412.0    491
#           ...
# 129.0        1
# 1588.0       1
# 5462.0       1
# 1160.0       1
# 342.0        1
# Name: propertycount, Length: 342, dtype: int64

# %% [markdown]
# <a id="part_2_regionname"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> regionname </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"><b>"Regionname"</b></span> column were filled with the mode values grouped by <span style="color:red"><b>"Suburb"</b></span> and <span style="color:red"><b>"Postcode"</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "regionname")
# Out:
# column name    :  regionname
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  3
# num_of_uniques :  9
# shape_of_df    :  (34856, 21)
# --------------------------------
# Southern Metropolitan         11836
# Northern Metropolitan          9557
# Western Metropolitan           6799
# Eastern Metropolitan           4376
# South-Eastern Metropolitan     1739
# Eastern Victoria                228
# Northern Victoria               203
# Western Victoria                115
# NaN                               3
# Name: regionname, dtype: int64

# %%
fill_mode(df_full, "suburb", "postcode", "regionname")
# Out:
# column name    :  regionname
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  8
# --------------------------------
# Southern Metropolitan         11838
# Northern Metropolitan          9557
# Western Metropolitan           6800
# Eastern Metropolitan           4376
# South-Eastern Metropolitan     1739
# Eastern Victoria                228
# Northern Victoria               203
# Western Victoria                115
# Name: regionname, dtype: int64

# %%
df_full.columns
# Out:
# Index(['suburb', 'address', 'rooms', 'type', 'method', 'seller_g', 'date',
#        'distance', 'postcode', 'bedroom_2', 'bathroom', 'car', 'landsize',
#        'building_area', 'year_built', 'council_area', 'lattitude',
#        'longtitude', 'regionname', 'propertycount', 'price'],
#       dtype='object')

# %% [markdown]
# <a id="part_2_council_area"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> council_area </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the <span style="color:red"><b>"CouncilArea"</b></span> column were filled with the mode values grouped by <span style="color:red"><b>"Suburb"</b></span> and <span style="color:red"><b>"Postcode"</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "council_area")
# Out:
# column name    :  council_area
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  3
# num_of_uniques :  34
# shape_of_df    :  (34856, 21)
# --------------------------------
# Boroondara City Council           3675
# Darebin City Council              2851
# Moreland City Council             2122
# Glen Eira City Council            2006
# Melbourne City Council            1952
# Banyule City Council              1861
# Moonee Valley City Council        1791
# Bayside City Council              1764
# Brimbank City Council             1593
# Monash City Council               1466
# Stonnington City Council          1460
# Maribyrnong City Council          1451
# Port Phillip City Council         1280
# Hume City Council                 1214
# Yarra City Council                1186
# Manningham City Council           1045
# Hobsons Bay City Council           942
# Kingston City Council              871
# Whittlesea City Council            828
# ...

# %%
fill_mode(df_full, "suburb", "postcode", "council_area")
# Out:
# column name    :  council_area
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  33
# --------------------------------
# Boroondara City Council           3677
# Darebin City Council              2851
# Moreland City Council             2122
# Glen Eira City Council            2006
# Melbourne City Council            1952
# Banyule City Council              1861
# Moonee Valley City Council        1791
# Bayside City Council              1764
# Brimbank City Council             1593
# Monash City Council               1466
# Stonnington City Council          1460
# Maribyrnong City Council          1452
# Port Phillip City Council         1280
# Hume City Council                 1214
# Yarra City Council                1186
# Manningham City Council           1045
# Hobsons Bay City Council           942
# Kingston City Council              871
# Whittlesea City Council            828
# Wyndham City Council               624
# ...

# %% [markdown]
# <a id="part_2_distance"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> distance </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> The NaN values in the columns were  <span style="color:red"><b>filled </b></span> using a group-by operation based on <b>year_built</b>, and <b>post_code</b>, with the median values.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "distance")
# Out:
# column name    :  distance
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  1
# num_of_uniques :  216
# shape_of_df    :  (34856, 21)
# --------------------------------
# 11.2    1420
# 13.8     681
# 9.2      665
# 7.8      662
# 10.5     660
#         ...
# NaN        1
# 31.4       1
# 22.9       1
# 30.6       1
# 32.6       1
# Name: distance, Length: 216, dtype: int64

# %%
df_full.corrwith(df_full['distance']).sort_values()
# Out:
# price           -0.157534
# lattitude       -0.100414
# propertycount   -0.018134
# landsize         0.055838
# building_area    0.074446
# bathroom         0.133486
# longtitude       0.200923
# car              0.237655
# rooms            0.271513
# bedroom_2        0.273106
# year_built       0.409030
# postcode         0.481567
# distance         1.000000
# dtype: float64

# %%
fill(df_full,"year_built", "postcode",  "distance", "median")
# Out:
# COLUMN NAME    :  distance
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  215
# --------------------------------
# 0.0     77
# 0.7     29
# 1.2     47
# 1.3     30
# 1.4      6
#         ..
# 45.2     2
# 45.9    33
# 47.3    20
# 47.4     7
# 48.1     6
# Name: distance, Length: 215, dtype: int64

# %% [markdown]
# <a id="part_2_no_basement"></a>
# <div class="alert alert-info" role="alert">
# <h1><span style="color:red"> General Overwiew to Missing Values </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b style="color: red;">Analysis:</b> As for the some columns mentioned above, they can be considered as part of <span style="color: red;"><b>data analysis practice</b></span>. As for the remaining columns, which are not used for predicting house prices, <span style="color: red;"><b>no specific actions were taken for handling missing values</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
missing_values(df_full)
# Out:
#             Missing_Number  Missing_Percent
# longtitude            7976        22.882717
# lattitude             7976        22.882717
# postcode                 1         0.002869

# %% [markdown]
# <a id="part_3"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 3 ( Handling With Outliers ) ✨</p>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_3_def" role="tab" aria-controls="profile">
#     User Defined Functions (DEFs)
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_3_price" role="tab" aria-controls="messages">
#     Column name : price
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_3_general_overview" role="tab" aria-controls="settings">
#     General Overview to Outlier Values
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
# </div>

# %%
df_full.reset_index(drop = True, inplace = True)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34856 entries, 0 to 34855
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   suburb         34856 non-null  object
#  1   address        34856 non-null  object
#  2   rooms          34856 non-null  int64
#  3   type           34856 non-null  object
#  4   method         34856 non-null  object
#  5   seller_g       34856 non-null  object
#  6   date           34856 non-null  object
#  7   distance       34856 non-null  float64
#  8   postcode       34855 non-null  float64
#  9   bedroom_2      34856 non-null  float64
#  10  bathroom       34856 non-null  float64
#  11  car            34856 non-null  float64
#  12  landsize       34856 non-null  float64
#  13  building_area  34856 non-null  float64
#  14  year_built     34856 non-null  float64
#  15  council_area   34856 non-null  object
#  16  lattitude      26880 non-null  float64
# ...

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ User Defined Functions (DEFs) ✨</p>

# %% [markdown]
# <a href="#part_3" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 3</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
def drop_outliers_zscore(df, feature, threshold=3):
    """
    Drops outliers from a Pandas DataFrame based on the z-score of a specific feature.
    
    Parameters:
    df (Pandas DataFrame): The input DataFrame.
    feature (str): The name of the feature to use for outlier detection.
    threshold (float, optional): The threshold value for the z-score. Defaults to 3.
    
    Returns:
    Pandas DataFrame: The DataFrame with the outliers removed.
    """
    # Print the number of rows before dropping outliers
    print(f"Number of rows before dropping outliers from {feature}:", len(df))
    
    # Calculate the z-scores for the feature
    z_scores = np.abs((df[feature] - df[feature].mean()) / df[feature].std())

    # Drop the rows with z-scores above the threshold
    df = df[z_scores < threshold]

    # Drop the rows with z-scores above the threshold
    df.reset_index(drop=True, inplace=True)
    
    # Print the number of rows after dropping outliers
    print(f"Number of rows after dropping outliers from {feature}:", len(df))
    
    return df # df.info()

# %%
# Let's first explore if there has been any problem with data types of Columns in the DataFrame

class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''    
    
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + " " + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df_full)
# Out:
#  NO PROBLEM  with the data types of Columns in the DataFrame.

# %% [markdown]
# <a id="part_2_operation"></a>
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title" >Operations on some columns</button>

# %% [markdown]
# <a id="part_3_price"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> price </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> When examining the <b>Price</b> feature in depth, it was observed that the highest value is <span style="color:red"><b>12,200,000.000</b></span>, and the lowest value is <span style="color:red"><b>85,000.000</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_look(df_full, "price")
# Out:
# column name    :  price
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2872
# shape_of_df    :  (34856, 21)
# --------------------------------
# 928000.0     2490
# 1210000.0    1939
# 590000.0      931
# 1560000.0     556
# 941000.0      552
#              ...
# 1503500.0       1
# 3475000.0       1
# 748500.0        1
# 1293000.0       1
# 1605500.0       1
# Name: price, Length: 2872, dtype: int64

# %%
display(df_full.price.describe())
# Out:
# count    3.485600e+04
# mean     1.035792e+06
# std      5.823047e+05
# min      8.500000e+04
# 25%      6.600000e+05
# 50%      9.280000e+05
# 75%      1.210000e+06
# max      1.120000e+07
# Name: price, dtype: float64

# %%
visualize_data(df_full, "price", plot_type = "all")

# %%
df_full.sort_values(by=["price"], ascending=False)["price"].head(20)
# Out:
# 25634    11200000.0
# 19582     9000000.0
# 12539     8000000.0
# 15696     7650000.0
# 28333     7000000.0
# 20923     6800000.0
# 30550     6600000.0
# 5937      6500000.0
# 25203     6500000.0
# 16002     6460000.0
# 27383     6400000.0
# 20683     6400000.0
# 24555     6370000.0
# 33497     6300000.0
# 10451     6250000.0
# 5867      6240000.0
# 26146     6125000.0
# 25503     6050000.0
# 33158     6000000.0
# 16047     5925000.0
# Name: price, dtype: float64

# %%
df_full[df_full["price"] == 11200000.0].T
# Out:
#                                25634
# suburb                      Brighton
# address                    6 Cole St
# rooms                              4
# type                               h
# method                            VB
# seller_g               hockingstuart
# date                      28/10/2017
# distance                        10.5
# postcode                      3186.0
# bedroom_2                        4.0
# bathroom                         3.0
# car                              2.0
# landsize                      1400.0
# building_area                  200.0
# year_built                    1930.0
# council_area    Bayside City Council
# lattitude                  -37.89335
# longtitude                 144.98643
# regionname     Southern Metropolitan
# propertycount                10579.0
# price                     11200000.0

# %%
# pick up the indeces of the lowest 20 observations to dive deep into examination

df_full.sort_values(by=["price"], ascending=False)["price"].head(20).index
# Out:
# Int64Index([25634, 19582, 12539, 15696, 28333, 20923, 30550,  5937, 25203,
#             16002, 27383, 20683, 24555, 33497, 10451,  5867, 26146, 25503,
#             33158, 16047],
#            dtype='int64')

# %%
# df_full.iloc[[25634, 19582, 12539, 15696, 28333, 20923, 30550,  5937, 25203,
#             16002, 27383, 20683, 24555, 33497, 10451,  5867, 26146, 25503,
#             33158, 16047]].T

# %%
df_full.sort_values(by=["price"], ascending=True)["price"].head(20)
# Out:
# 4378      85000.0
# 29668    112000.0
# 17528    121000.0
# 3063     131000.0
# 11859    145000.0
# 3290     145000.0
# 12947    160000.0
# 21011    170000.0
# 14380    170000.0
# 13895    185000.0
# 11848    185000.0
# 11861    190000.0
# 13970    200000.0
# 11602    200000.0
# 20887    208000.0
# 14470    210000.0
# 4443     210000.0
# 11588    210000.0
# 6688     210000.0
# 9505     211000.0
# Name: price, dtype: float64

# %%
# pick up the indeces of the lowest 20 observations to dive deep into examination

df_full.sort_values(by=["price"], ascending=True)["price"].head(20).index
# Out:
# Int64Index([ 4378, 29668, 17528,  3063, 11859,  3290, 12947, 21011, 14380,
#             13895, 11848, 11861, 13970, 11602, 20887, 14470,  4443, 11588,
#              6688,  9505],
#            dtype='int64')

# %%
# df_full.iloc[[ 4378, 29668, 17528,  3063, 11859,  3290, 12947, 21011, 14380,
#             13895, 11848, 11861, 13970, 11602, 20887, 14470,  4443, 11588,
#              6688,  9505]].T

# %% [markdown]
# <a id="part_3_general_overview"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> General Overview to Outlier Values </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> Outlier values in all columns were removed using the <span style="color:red"><b>Z-score</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
help(drop_outliers_zscore)
# Out:
# Help on function drop_outliers_zscore in module __main__:
#
# drop_outliers_zscore(df, feature, threshold=3)
#     Drops outliers from a Pandas DataFrame based on the z-score of a specific feature.
#
#     Parameters:
#     df (Pandas DataFrame): The input DataFrame.
#     feature (str): The name of the feature to use for outlier detection.
#     threshold (float, optional): The threshold value for the z-score. Defaults to 3.
#
#     Returns:
#     Pandas DataFrame: The DataFrame with the outliers removed.

# %%
def drop_outliers_zscore_for_all(df, threshold=3):

    excluded_columns = ["postcode", "lattitude", "longtitude"]
    temp_df = df.drop(excluded_columns, axis=1)
    

    numeric_columns = temp_df.select_dtypes(include=['number']).columns
    

    for column in numeric_columns:
        df = drop_outliers_zscore(df, column, threshold)

    return df

df_full = drop_outliers_zscore_for_all(df_full, threshold=3)
df_full.info()
# Out:
# Number of rows before dropping outliers from rooms: 34856
# Number of rows after dropping outliers from rooms: 34587
# Number of rows before dropping outliers from distance: 34587
# Number of rows after dropping outliers from distance: 33803
# Number of rows before dropping outliers from bedroom_2: 33803
# Number of rows after dropping outliers from bedroom_2: 33773
# Number of rows before dropping outliers from bathroom: 33773
# Number of rows after dropping outliers from bathroom: 33467
# Number of rows before dropping outliers from car: 33467
# Number of rows after dropping outliers from car: 33166
# Number of rows before dropping outliers from landsize: 33166
# Number of rows after dropping outliers from landsize: 33119
# Number of rows before dropping outliers from building_area: 33119
# Number of rows after dropping outliers from building_area: 32937
# Number of rows before dropping outliers from year_built: 32937
# Number of rows after dropping outliers from year_built: 32928
# ...

# %% [markdown]
# <a id="part_4"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Part - 4 ( Feature Engineering )✨</p>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_4_operation" role="tab" aria-controls="profile">
#     Operations on some columns
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_4_building_age" role="tab" aria-controls="messages">
#     Column name : building_age
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_4_total_room_bathroom" role="tab" aria-controls="settings">
#     Column name : total_room_bathroom
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_4_total_area" role="tab" aria-controls="settings">
#     Column name : total_area
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
# </div>

# %% [markdown]
# <a id="part_4_operation"></a>
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title" >Operations on some columns</button>

# %% [markdown]
# <a id="part_4_building_age"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> building_age</span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> A new feature named <span style="color:red"><b>"building_age"</b></span> was created by subtracting the construction year from 2023.
# </div>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_full["building_age"] = 2023 - df_full["year_built"]
df_full.drop("year_built", axis = 1 , inplace = True)

# %%
df_full.columns
# Out:
# Index(['suburb', 'address', 'rooms', 'type', 'method', 'seller_g', 'date',
#        'distance', 'postcode', 'bedroom_2', 'bathroom', 'car', 'landsize',
#        'building_area', 'council_area', 'lattitude', 'longtitude',
#        'regionname', 'propertycount', 'price', 'building_age'],
#       dtype='object')

# %% [markdown]
# <a id="part_4_total_room_bathroom"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> total_room_bathroom</span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> A new feature named <span style="color:red"><b>"total_room_bathroom"</b></span> was created by summing the "rooms" and "bathroom" columns.
# </div>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_full["total_room_bathroom"] = df_full["rooms"] + df_full["bathroom"]
df_full["total_room_bathroom"].value_counts()
# Out:
# 4.0    8509
# 3.0    7136
# 5.0    6678
# 6.0    5602
# 7.0    1533
# 2.0    1462
# 8.0     627
# 1.0       1
# Name: total_room_bathroom, dtype: int64

# %% [markdown]
# <a id="part_4_total_area"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> total_area</span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> A new feature named <span style="color:red"><b>"total_area"</b></span> was created by summing the "landsize" and "building_area" columns.
# </div>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_full['total_area'] = df_full['landsize'] + df_full['building_area']
df_full["total_area"].value_counts().sort_index()
# Out:
# 0.0       1
# 1.0       3
# 2.0       4
# 3.0       1
# 4.0       1
#          ..
# 7634.0    1
# 7705.0    1
# 7872.0    1
# 8226.5    1
# 8269.5    1
# Name: total_area, Length: 2878, dtype: int64

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31548 entries, 0 to 31547
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   suburb               31548 non-null  object
#  1   address              31548 non-null  object
#  2   rooms                31548 non-null  int64
#  3   type                 31548 non-null  object
#  4   method               31548 non-null  object
#  5   seller_g             31548 non-null  object
#  6   date                 31548 non-null  object
#  7   distance             31548 non-null  float64
#  8   postcode             31548 non-null  float64
#  9   bedroom_2            31548 non-null  float64
#  10  bathroom             31548 non-null  float64
#  11  car                  31548 non-null  float64
#  12  landsize             31548 non-null  float64
#  13  building_area        31548 non-null  float64
#  14  council_area         31548 non-null  object
# ...

# %% [markdown]
# <a id="part_5"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Part - 5 ( Machine Learning )✨</p>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_5_multicol" role="tab" aria-controls="profile">
#     Multicollinearity Control
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_5_vif" role="tab" aria-controls="messages">
#     VIF (Variance Inflation Factor) Score for Multicolliniearity
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_train_test" role="tab" aria-controls="settings">
#     Train | Test Split
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_5_make_column" role="tab" aria-controls="settings">
#     Converting Object Features into Numerical Features Using Make Column Transformer
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_scaling" role="tab" aria-controls="settings">
#     Scaling
#     <span class="badge badge-primary badge-pill">5</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_linear_reg" role="tab" aria-controls="settings">
#     Implement Linear Regression
#     <span class="badge badge-primary badge-pill">6</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_linear_cross" role="tab" aria-controls="settings">
#     Cross Validate
#     <span class="badge badge-primary badge-pill">7</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_pipeline_ridge" role="tab" aria-controls="settings">
#     Implement Ridge Regression - Pipeline
#     <span class="badge badge-primary badge-pill">8</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_ridge_cross" role="tab" aria-controls="settings">
#     Cross Validation
#     <span class="badge badge-primary badge-pill">9</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_ridge_best" role="tab" aria-controls="settings">
#     Finding best alpha for Ridge
#     <span class="badge badge-primary badge-pill">10</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_lasso_reg" role="tab" aria-controls="settings">
#     Implement Lasso Regression
#     <span class="badge badge-primary badge-pill">11</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_lasso_cross" role="tab" aria-controls="settings">
#     Cross Validation
#     <span class="badge badge-primary badge-pill">12</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_lasso_best" role="tab" aria-controls="settings">
#     Finding best alpha for Lasso
#     <span class="badge badge-primary badge-pill">13</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_elastic_reg" role="tab" aria-controls="settings">
#     Implement Elastic-Net
#     <span class="badge badge-primary badge-pill">14</span>
#   </a>
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_elastic_cross" role="tab" aria-controls="settings">
#     Cross Validation
#     <span class="badge badge-primary badge-pill">15</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_elastic_best" role="tab" aria-controls="settings">
#     Finding best alpha and l1_ratio for ElasticNet
#     <span class="badge badge-primary badge-pill">16</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_feature_importance" role="tab" aria-controls="settings">
#     Feature İmportance/selection
#     <span class="badge badge-primary badge-pill">17</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_decision_tree" role="tab" aria-controls="settings">
#     Decision Tree- Regression
#     <span class="badge badge-primary badge-pill">18</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_decision_pipeline" role="tab" aria-controls="settings">
#     Pipeline
#     <span class="badge badge-primary badge-pill">19</span>
#   </a>
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_decision_gridsearch" role="tab" aria-controls="settings">
#     GridSearch
#     <span class="badge badge-primary badge-pill">20</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_fea_importance" role="tab" aria-controls="settings">
#     Feature Importance
#     <span class="badge badge-primary badge-pill">21</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_compare" role="tab" aria-controls="settings">
#     Compare real and predicted result
#     <span class="badge badge-primary badge-pill">22</span>
#   </a>
#      <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_final_model" role="tab" aria-controls="settings">
#     Final Model
#     <span class="badge badge-primary badge-pill">23</span>
#   </a>
# </div>

# %%
duplicate_values(df_full)
# Out:
# Duplicate check...
# There are no duplicates
# ****************************************************************************************************

# %%
df_full.drop(["postcode", "lattitude", "longtitude", "address", "date"], axis = 1, inplace = True)

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> Some columns and duplicate values were dropped as they will not be used in machine learning.
# </div>

# %%
# from sklearn.impute import KNNImputer

def height_solver(df, how='likeZero'):
    
    if how == 'likeZero':
        zero_columns = df.columns[df.eq(0).any()]
        df[zero_columns] = df[zero_columns].replace(0, 0.0001)
        return df
    
    elif how == 'knnImputer':
        zero_columns = df.columns[df.eq(0).any()]
        df[zero_columns] = df[zero_columns].replace(0, np.nan)

        imputer = KNNImputer(n_neighbors=5)
        df[zero_columns] = imputer.fit_transform(df[zero_columns])
        return df

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b style="color:red;">Operation:</b> Zeros in the model were replaced with <span style="color:red;">0.0001</span> using a user-defined function, resulting in improved performance.
# </div>

# %%
height_solver(df_full, how = 'likeZero')
# Out:
#            suburb  rooms type method       seller_g  distance  bedroom_2  \
# 0      Abbotsford      2    h     SS         Jellis       2.5        2.0
# 1      Abbotsford      2    h      S         Biggin       2.5        2.0
# 2      Abbotsford      2    h      S         Biggin       2.5        2.0
# 3      Abbotsford      3    u     VB         Rounds       2.5        3.0
# 4      Abbotsford      3    h     SP         Biggin       2.5        3.0
# ...           ...    ...  ...    ...            ...       ...        ...
# 31543  Yarraville      4    h     PI            Jas       6.3        4.0
# 31544  Yarraville      2    h     SP        Sweeney       6.3        2.0
# 31545  Yarraville      2    t      S            Jas       6.3        2.0
# 31546  Yarraville      3    h     SP  hockingstuart       6.3        3.0
# 31547  Yarraville      2    h     PI             RW       6.3        2.0
#
#        bathroom     car  landsize  building_area              council_area  \
# ...

# %% [markdown]
# <a id="part_5_multicol"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Multicollinearity Control ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_full.select_dtypes(include ="number")
# Out:
#        rooms  distance  bedroom_2  bathroom     car  landsize  building_area  \
# 0          2       2.5        2.0       1.0  1.0000  126.0000           98.0
# 1          2       2.5        2.0       1.0  1.0000  202.0000           85.0
# 2          2       2.5        2.0       1.0  0.0001  156.0000           79.0
# 3          3       2.5        3.0       2.0  1.0000    0.0001          119.0
# 4          3       2.5        3.0       2.0  0.0001  134.0000          150.0
# ...      ...       ...        ...       ...     ...       ...            ...
# 31543      4       6.3        4.0       1.0  3.0000  593.0000          180.0
# 31544      2       6.3        2.0       2.0  1.0000   98.0000          104.0
# 31545      2       6.3        2.0       1.0  2.0000  220.0000          120.0
# 31546      3       6.3        3.0       1.0  2.0000  538.0000          121.0
# 31547      2       6.3        2.0       1.0  0.0001  250.0000          103.0
#
# ...

# %%
df_numeric = df_full.select_dtypes(include ="number")
plt.figure(figsize=(20,10))
sns.heatmap(df_numeric.corr(), annot =True , vmin = -1 , vmax = 1, cmap = "coolwarm")

# With the code select_dtypes(include ="number"), we can filter only the numeric features in the df.
# Out:
# <Axes: >

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">The highest correlation was observed between price and building area, while the lowest correlation was found with landsize.</p>
# </div>

# %%
df_numeric.corr()[(abs(df_numeric.corr())>= 0.9) & (abs(df_numeric.corr()) < 1)].any()
# Out:
# rooms                   True
# distance               False
# bedroom_2               True
# bathroom               False
# car                    False
# landsize                True
# building_area          False
# propertycount          False
# price                  False
# building_age           False
# total_room_bathroom     True
# total_area              True
# dtype: bool

# %%
df_numeric.corr()[(abs(df_numeric.corr())>= 0.9) & (abs(df_numeric.corr()) < 1)].any().any()

# Corr between +/-0.9 and +/-1. We can check multicollinearity for values with this snippet.
# Out:
# True

# %% [markdown]
# <a id="part_5_vif"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ VIF (Variance Inflation Factor) Score for Multicolliniearity ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# conda install -c anaconda statsmodels
# !pip install statsmodels

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X_vif = df_numeric.drop(columns='price')
X_vif.head()
# Out:
#    rooms  distance  bedroom_2  bathroom     car  landsize  building_area  \
# 0      2       2.5        2.0       1.0  1.0000  126.0000           98.0
# 1      2       2.5        2.0       1.0  1.0000  202.0000           85.0
# 2      2       2.5        2.0       1.0  0.0001  156.0000           79.0
# 3      3       2.5        3.0       2.0  1.0000    0.0001          119.0
# 4      3       2.5        3.0       2.0  0.0001  134.0000          150.0
#
#    propertycount  building_age  total_room_bathroom  total_area
# 0         4019.0         123.0                  3.0       224.0
# 1         4019.0         123.0                  3.0       287.0
# 2         4019.0         123.0                  3.0       235.0
# 3         4019.0         123.0                  5.0       119.0
# 4         4019.0         123.0                  5.0       284.0

# %%
df_vif = pd.DataFrame()
df_vif['features'] = X_vif.columns

# %%
df_vif
# Out:
#                features
# 0                 rooms
# 1              distance
# 2             bedroom_2
# 3              bathroom
# 4                   car
# 5              landsize
# 6         building_area
# 7         propertycount
# 8          building_age
# 9   total_room_bathroom
# 10           total_area

# %%
X_vif.head()
# Out:
#    rooms  distance  bedroom_2  bathroom     car  landsize  building_area  \
# 0      2       2.5        2.0       1.0  1.0000  126.0000           98.0
# 1      2       2.5        2.0       1.0  1.0000  202.0000           85.0
# 2      2       2.5        2.0       1.0  0.0001  156.0000           79.0
# 3      3       2.5        3.0       2.0  1.0000    0.0001          119.0
# 4      3       2.5        3.0       2.0  0.0001  134.0000          150.0
#
#    propertycount  building_age  total_room_bathroom  total_area
# 0         4019.0         123.0                  3.0       224.0
# 1         4019.0         123.0                  3.0       287.0
# 2         4019.0         123.0                  3.0       235.0
# 3         4019.0         123.0                  5.0       119.0
# 4         4019.0         123.0                  5.0       284.0

# %%
variance_inflation_factor(X_vif.values, 0)

# Returns the VIF score of the relationship between the rooms feature at the 0th index of the "X_vif" and other features.
# Out:
# 767484599074.7267

# %%
df_vif["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(len(X_vif.columns))]

# %%
df_vif

#check the VIF scores:
# 1   -> no correlation
# 1-5 -> ok
# >5  -> Alert! Be cautious and inspect more. Consider removing.
# >10 -> Severe multicolliniearity!!!

# The features rooms, bedroom_2, bathroom, building_area, year_built have a serious multicollinearity 
# problem with other features. In this context, it is necessary to use one of the regularization models for accurate 
# feature selection.
# Out:
#                features           VIF
# 0                 rooms  7.674846e+11
# 1              distance  5.318008e+00
# 2             bedroom_2  2.891907e+02
# 3              bathroom  2.146053e+11
# 4                   car  7.034280e+00
# 5              landsize  4.289143e+14
# 6         building_area  2.515977e+13
# 7         propertycount  3.967489e+00
# 8          building_age  3.992219e+00
# 9   total_room_bathroom  1.757159e+12
# 10           total_area  6.004800e+14

# %% [markdown]
# <a id="part_5_train_test"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Train | Test Split ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_full_new = df_full.copy()
X= df_full_new.drop(columns="price")
y= df_full_new.price

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,  random_state=42)

# %%
X_train.head()
# Out:
#                 suburb  rooms type method  seller_g  distance  bedroom_2  \
# 13462        St Albans      3    h     PI       YPA      14.0        3.0
# 14632         Ringwood      3    t     PI     Barry      19.9        3.0
# 123       Airport West      3    u      S  McDonald      13.5        3.0
# 1405    Bentleigh East      4    h     SN       Ray      13.9        4.0
# 25786  Blackburn North      4    h      S      Noel      13.4        4.0
#
#        bathroom  car  landsize  building_area                council_area  \
# 13462       1.0  2.0     563.0          171.0       Brimbank City Council
# 14632       2.0  2.0     249.0          141.5      Maroondah City Council
# 123         1.0  2.0     569.0          132.0  Moonee Valley City Council
# 1405        2.0  2.0     572.0          205.0      Glen Eira City Council
# 25786       2.0  2.0     641.5          251.0     Whitehorse City Council
#
#                   regionname  propertycount  building_age  \
# ...

# %%
# X_train[X_train["suburb"] == 187].sample()

# %%
# df_full.loc[14202]

# %%
X_test.head()
# Out:
#             suburb  rooms type method   seller_g  distance  bedroom_2  \
# 821         Balwyn      3    h     VB  Fletchers       9.7        3.0
# 22575   Aberfeldie      4    h     SP       Brad       7.5        4.0
# 6379   Mont Albert      2    u     SN       Ross      11.8        2.0
# 23855  Murrumbeena      3    h      S     Buxton      10.1        3.0
# 3752      Essendon      2    u      S     Nelson       8.0        2.0
#
#        bathroom  car  landsize  building_area                council_area  \
# 821         1.0  2.0  567.5000          135.0     Boroondara City Council
# 22575       2.0  2.0  797.0000           26.0  Moonee Valley City Council
# 6379        1.0  1.0    0.0001           76.0     Boroondara City Council
# 23855       1.0  2.0  733.0000          175.0      Glen Eira City Council
# 3752        1.0  1.0    0.0001           75.0  Moonee Valley City Council
#
#                   regionname  propertycount  building_age  \
# ...

# %% [markdown]
# <a id="part_5_make_column"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨Converting Object Features into Numerical Features Using Make Column Transformer ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_object = df_full_new.select_dtypes(include ="object")
for col in df_object:
    print(f"{col:<30}:", df_full[col].nunique())
# we see how many unique observations each feature consists of.
# Out:
# suburb                        : 300
# type                          : 3
# method                        : 9
# seller_g                      : 356
# council_area                  : 28
# regionname                    : 8

# %%
df_object.columns
# Out:
# Index(['suburb', 'type', 'method', 'seller_g', 'council_area', 'regionname'], dtype='object')

# %%
df_full.type.value_counts()
# Out:
# h    21105
# u     7022
# t     3421
# Name: type, dtype: int64

# %%
cat_onehot = ['type']
cat_ordinal_encoder = ['suburb', 'method', 'seller_g', 'council_area', 'regionname']

# %%
# from sklearn.compose import make_column_transformer
# from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
# from sklearn.preprocessing import FunctionTransformer


column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_onehot),
    (OrdinalEncoder(handle_unknown = "use_encoded_value", unknown_value = -1), cat_ordinal_encoder),  
    remainder='passthrough',
    verbose_feature_names_out=False
)

column_trans = column_trans.set_output(transform="pandas")

# %%
X_train_trans = column_trans.fit_transform(X_train)
X_test_trans = column_trans.transform(X_test)

# %%
X_train_trans.shape, X_test_trans.shape
# Out:
# ((22083, 19), (9465, 19))

# %%
X_train_trans
# Out:
#        type_h  type_t  type_u  suburb  method  seller_g  council_area  \
# 13462     1.0     0.0     0.0   246.0     0.0     310.0           3.0
# 14632     0.0     1.0     0.0   225.0     0.0      16.0          14.0
# 123       0.0     0.0     1.0     2.0     2.0     169.0          18.0
# 1405      1.0     0.0     0.0    28.0     4.0     236.0           6.0
# 25786     1.0     0.0     0.0    31.0     2.0     197.0          23.0
# ...       ...     ...     ...     ...     ...       ...           ...
# 29802     1.0     0.0     0.0   286.0     4.0     111.0          17.0
# 5390      0.0     0.0     1.0   156.0     2.0     191.0           3.0
# 860       1.0     0.0     0.0    20.0     5.0     132.0           2.0
# 15795     1.0     0.0     0.0   219.0     5.0     164.0          15.0
# 23654     0.0     0.0     1.0   137.0     2.0      19.0           2.0
#
#        regionname  rooms  distance  bedroom_2  bathroom     car  landsize  \
# ...

# %%
X_test_trans
# Out:
#        type_h  type_t  type_u  suburb  method  seller_g  council_area  \
# 821       1.0     0.0     0.0    20.0     7.0      88.0           2.0
# 22575     1.0     0.0     0.0     1.0     5.0      32.0          18.0
# 6379      0.0     0.0     1.0   189.0     4.0     250.0           2.0
# 23855     1.0     0.0     0.0   198.0     2.0      40.0           6.0
# 3752      0.0     0.0     1.0   110.0     2.0     191.0          18.0
# ...       ...     ...     ...     ...     ...       ...           ...
# 18204     0.0     0.0     1.0    97.0     5.0     170.0          12.0
# 31488     1.0     0.0     0.0   265.0     1.0     232.0          22.0
# 11818     0.0     1.0     0.0   127.0     2.0       4.0           2.0
# 14303     1.0     0.0     0.0    79.0     4.0      16.0           9.0
# 23352     0.0     0.0     1.0    47.0     2.0     236.0           0.0
#
#        regionname  rooms  distance  bedroom_2  bathroom  car  landsize  \
# ...

# %% [markdown]
# <a id="part_5_scaling"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Scaling ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
scaler = MinMaxScaler().set_output(transform="pandas")
scaler.fit(X_train_trans)
# dogru feature selection yapmak icin butun featurelari ayni araliga almamiz lazım
X_train_scaled = scaler.transform(X_train_trans)
X_test_scaled = scaler.transform(X_test_trans)


scaler = MinMaxScaler()

# dummies featurelara minmax , numericlere standartscaler uygulayip concat edebiliriz . 
# make_column_transform buna imkan veriyor  . concatsiz , numeric - standartscaler ; digerlerine minmax yapabiliyoruz .

# %%
X_train_scaled.head()
# Out:
#        type_h  type_t  type_u    suburb  method  seller_g  council_area  \
# 13462     1.0     0.0     0.0  0.828283    0.00  0.953846      0.111111
# 14632     0.0     1.0     0.0  0.757576    0.00  0.049231      0.518519
# 123       0.0     0.0     1.0  0.006734    0.25  0.520000      0.666667
# 1405      1.0     0.0     0.0  0.094276    0.50  0.726154      0.222222
# 25786     1.0     0.0     0.0  0.104377    0.25  0.606154      0.851852
#
#        regionname  rooms  distance  bedroom_2  bathroom       car  landsize  \
# 13462    0.857143   0.50  0.445858       0.50  0.333311  0.499987  0.072683
# 14632    0.000000   0.50  0.633757       0.50  0.666656  0.499987  0.032146
# 123      0.857143   0.50  0.429934       0.50  0.333311  0.499987  0.073457
# 1405     0.714286   0.75  0.442673       0.75  0.666656  0.499987  0.073845
# 25786    0.000000   0.75  0.426750       0.75  0.666656  0.499987  0.082817
#
#        building_area  propertycount  building_age  total_room_bathroom  \
# ...

# %%
X_test_scaled.head()
# Out:
#        type_h  type_t  type_u    suburb  method  seller_g  council_area  \
# 821       1.0     0.0     0.0  0.067340   0.875  0.270769      0.074074
# 22575     1.0     0.0     0.0  0.003367   0.625  0.098462      0.666667
# 6379      0.0     0.0     1.0  0.636364   0.500  0.769231      0.074074
# 23855     1.0     0.0     0.0  0.666667   0.250  0.123077      0.222222
# 3752      0.0     0.0     1.0  0.370370   0.250  0.587692      0.666667
#
#        regionname  rooms  distance  bedroom_2  bathroom       car  landsize  \
# 821      0.714286   0.50  0.308915       0.50  0.333311  0.499987  0.073264
# 22575    0.857143   0.75  0.238851       0.75  0.666656  0.499987  0.102892
# 6379     0.000000   0.25  0.375794       0.25  0.333311  0.249981  0.000000
# 23855    0.714286   0.50  0.321654       0.50  0.333311  0.499987  0.094629
# 3752     0.857143   0.25  0.254775       0.25  0.333311  0.249981  0.000000
#
#        building_area  propertycount  building_age  total_room_bathroom  \
# ...

# %% [markdown]
# <a id="part_5_linear_reg"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Implement Linear Regression ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
def train_val(model, X_train, y_train, X_test, y_test):
    
    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    
    scores = {"train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : mean_squared_error(y_train, y_train_pred, squared=False),
    "mape" :mean_absolute_percentage_error(y_train, y_train_pred)},
    
    "test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : mean_squared_error(y_test, y_pred, squared=False),
    "mape" :mean_absolute_percentage_error(y_test, y_pred)}}
    
    return pd.DataFrame(scores)

# %%
# from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
train_val(lm, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#              train          test
# R2    5.053978e-01  4.915271e-01
# mae   2.317793e+05  2.336414e+05
# mse   9.607277e+10  9.768792e+10
# rmse  3.099561e+05  3.125507e+05
# mape  2.521998e-01  2.565677e-01

# %%
pd.options.display.float_format = '{:.3f}'.format 

train_val(lm, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#                train            test
# R2             0.505           0.492
# mae       231779.275      233641.418
# mse  96072769015.334 97687922198.443
# rmse      309956.076      312550.671
# mape           0.252           0.257

# %% [markdown]
# <a id="part_5_linear_cross"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Cross Validate ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans),
              ("scaler", scaler), 
              ("Linear", LinearRegression())]

pipe_model = Pipeline(steps=operations)

scores = cross_validate(pipe_model, 
                        X_train, 
                        y_train,
                        scoring=['r2', 
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'], 
                        cv=10, 
                        return_train_score=True)

# %%
scores = pd.DataFrame(scores, index = range(1, 11))
scores
# Out:
#     fit_time  score_time  test_r2  train_r2  test_neg_mean_absolute_error  \
# 1      0.098       0.026    0.500     0.506                   -230294.124
# 2      0.106       0.021    0.514     0.504                   -235727.419
# 3      0.093       0.023    0.521     0.504                   -230637.747
# 4      0.101       0.021    0.494     0.507                   -237669.860
# 5      0.091       0.018    0.488     0.507                   -230048.553
# 6      0.076       0.027    0.493     0.507                   -231315.629
# 7      0.109       0.032    0.483     0.508                   -230809.776
# 8      0.089       0.020    0.505     0.505                   -231170.507
# 9      0.128       0.022    0.518     0.504                   -234218.481
# 10     0.124       0.038    0.524     0.503                   -227576.357
#
#     train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 1                     -231791.033             -95744793955.922
# ...

# %%
scores = pd.DataFrame(scores, index = range(1, 11))
scores.iloc[:,2:].mean()
# Out:
# test_r2                                               0.504
# train_r2                                              0.505
# test_neg_mean_absolute_error                    -231946.845
# train_neg_mean_absolute_error                   -231737.291
# test_neg_mean_squared_error                -96225621737.075
# train_neg_mean_squared_error               -96061024741.623
# test_neg_root_mean_squared_error                -310141.623
# train_neg_root_mean_squared_error               -309936.392
# test_neg_mean_absolute_percentage_error              -0.252
# train_neg_mean_absolute_percentage_error             -0.252
# dtype: float64

# %% [markdown]
# <a id="part_5_pipeline_ridge"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Pipeline ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
X = df_full_new.drop(columns = ["price"])
y = df_full_new.price

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#                 suburb  rooms type method  seller_g  distance  bedroom_2  \
# 13462        St Albans      3    h     PI       YPA    14.000      3.000
# 14632         Ringwood      3    t     PI     Barry    19.900      3.000
# 123       Airport West      3    u      S  McDonald    13.500      3.000
# 1405    Bentleigh East      4    h     SN       Ray    13.900      4.000
# 25786  Blackburn North      4    h      S      Noel    13.400      4.000
#
#        bathroom   car  landsize  building_area                council_area  \
# 13462     1.000 2.000   563.000        171.000       Brimbank City Council
# 14632     2.000 2.000   249.000        141.500      Maroondah City Council
# 123       1.000 2.000   569.000        132.000  Moonee Valley City Council
# 1405      2.000 2.000   572.000        205.000      Glen Eira City Council
# 25786     2.000 2.000   641.500        251.000     Whitehorse City Council
#
#                   regionname  propertycount  building_age  \
# ...

# %%
cat_onehot = ['type']
cat_ordinal_encoder = ['suburb', 'method', 'seller_g', 'council_area', 'regionname']

# %%
# from sklearn.compose import make_column_transformer
# from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
# from sklearn.preprocessing import FunctionTransformer


column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_onehot),
    (OrdinalEncoder(handle_unknown = "use_encoded_value", unknown_value = -1), cat_ordinal_encoder),  
    remainder='passthrough',
    verbose_feature_names_out=False
)

column_trans = column_trans.set_output(transform="pandas")

# %%
# from sklearn.linear_model import Ridge
# from sklearn.pipeline import Pipeline

 
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("Ridge", Ridge())]

ridge_model = Pipeline(steps=operations).set_output(transform="pandas")
# If we want the outputs of the given transform algorithms to be dataframes,
# you can add set_output(transform="pandas") to the end of the pipeline.

ridge_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
train_val(ridge_model, X_train, y_train, X_test, y_test)
# Out:
#                train            test
# R2             0.504           0.490
# mae       232063.364      234080.714
# mse  96270984274.116 97954394493.527
# rmse      310275.659      312976.668
# mape           0.253           0.258

# %% [markdown]
# <a id="part_5_ridge_cross"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Cross Validation ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans),
              ("scaler", scaler), 
              ("Ridge", Ridge())]

pipe_model = Pipeline(steps=operations)

scores = cross_validate(pipe_model, 
                        X_train, 
                        y_train,
                        scoring=['r2', 
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'], 
                        cv=10, 
                        return_train_score=True)

# %%
scores = pd.DataFrame(scores, index = range(1, 11))
scores
# Out:
#     fit_time  score_time  test_r2  train_r2  test_neg_mean_absolute_error  \
# 1      0.076       0.027    0.499     0.505                   -230573.585
# 2      0.096       0.021    0.513     0.503                   -236119.175
# 3      0.105       0.019    0.519     0.503                   -230953.896
# 4      0.078       0.039    0.493     0.506                   -238252.875
# 5      0.079       0.027    0.486     0.506                   -230353.743
# 6      0.075       0.023    0.493     0.506                   -231352.656
# 7      0.097       0.026    0.483     0.507                   -230389.276
# 8      0.101       0.025    0.504     0.504                   -231417.348
# 9      0.086       0.021    0.516     0.503                   -234773.078
# 10     0.094       0.023    0.523     0.502                   -228202.171
#
#     train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 1                     -232114.493             -95896010020.014
# ...

# %%
scores = pd.DataFrame(scores, index = range(1, 11))
scores.iloc[:,2:].mean()
# Out:
# test_r2                                               0.503
# train_r2                                              0.504
# test_neg_mean_absolute_error                    -232238.780
# train_neg_mean_absolute_error                   -232054.338
# test_neg_mean_squared_error                -96415978830.429
# train_neg_mean_squared_error               -96262254898.560
# test_neg_root_mean_squared_error                -310446.532
# train_neg_root_mean_squared_error               -310260.814
# test_neg_mean_absolute_percentage_error              -0.253
# train_neg_mean_absolute_percentage_error             -0.253
# dtype: float64

# %% [markdown]
# <a id="part_5_ridge_best"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Finding best alpha for Ridge ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# from sklearn.model_selection import GridSearchCV

# %%
alpha_space = np.linspace(-1, 100, 100)

# %%
operations = [("OneHot_Encoder", column_trans),
              ("scaler", scaler), 
              ("Ridge", Ridge())]

pipe_model = Pipeline(steps=operations)



param_grid = {'Ridge__alpha':alpha_space}  # # Parameter names should be used together with the model name defined
                                           # in the pipeline..

ridge_grid_model = GridSearchCV(estimator=pipe_model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10, 
                          n_jobs = -1, 
                          return_train_score=True)

# %%
pipe_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('OneHot_Encoder',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('onehotencoder',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse_output=False),
#                                     ['type']),
#                                    ('ordinalencoder',
#                                     OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                    unknown_value=-1),
#                                     ['suburb', 'method', 'seller_g',
#                                      'council_area', 'regionname'])],
#                      verbose_feature_names_out=False)),
#   ('scaler', MinMaxScaler()),
#   ('Ridge', Ridge())],
#  'verbose': False,
#  'OneHot_Encoder': ColumnTransformer(remainder='passthrough',
#                    transformers=[('onehotencoder',
# ...

# %%
ridge_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHot_Encoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['type']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['suburb',
# ...

# %%
ridge_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
pd.DataFrame(ridge_grid_model.cv_results_).loc[ridge_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score    -310446.533
# mean_train_score   -310260.862
# Name: 2, dtype: object

# %%
train_val(ridge_grid_model, X_train, y_train, X_test, y_test)
# Out:
#                train            test
# R2             0.504           0.490
# mae       232062.953      234080.181
# mse  96271008421.418 97954355433.023
# rmse      310275.697      312976.605
# mape           0.253           0.258

# %%
y_pred = ridge_grid_model.predict(X_test)
rm_R2 = r2_score(y_test, y_pred)
rm_mae = mean_absolute_error(y_test, y_pred)
rm_rmse = mean_squared_error(y_test, y_pred, squared=False)
rm_mape= mean_absolute_percentage_error(y_test, y_pred)

# %%
ridge_grid_model.best_estimator_["Ridge"].coef_
# Out:
# array([ 125943.06108664,    5297.02290312, -131240.08399304,
#        -113579.8980174 ,  -41532.19385932,  -41875.63141208,
#        -104836.96800079,   15717.76279524,  119292.11157827,
#        -639404.1883454 ,   37833.34088328,  182467.70647517,
#          63130.53829984,  118826.69369838,  968043.3483571 ,
#          48119.12449752,  349195.78821545,  146324.61479552,
#         166729.70809856])

# %%
ridge_grid_model.best_estimator_["OneHot_Encoder"].get_feature_names_out()
# Out:
# array(['type_h', 'type_t', 'type_u', 'suburb', 'method', 'seller_g',
#        'council_area', 'regionname', 'rooms', 'distance', 'bedroom_2',
#        'bathroom', 'car', 'landsize', 'building_area', 'propertycount',
#        'building_age', 'total_room_bathroom', 'total_area'], dtype=object)

# %%
pd.DataFrame(data= ridge_grid_model.best_estimator_["Ridge"].coef_, 
             index=ridge_grid_model.best_estimator_["OneHot_Encoder"].get_feature_names_out(), 
             columns=["Coef"]).sort_values("Coef")
# Out:
#                            Coef
# distance            -639404.188
# type_u              -131240.084
# suburb              -113579.898
# council_area        -104836.968
# seller_g             -41875.631
# method               -41532.194
# type_t                 5297.023
# regionname            15717.763
# bedroom_2             37833.341
# propertycount         48119.124
# car                   63130.538
# landsize             118826.694
# rooms                119292.112
# type_h               125943.061
# total_room_bathroom  146324.615
# total_area           166729.708
# bathroom             182467.706
# building_age         349195.788
# building_area        968043.348

# %% [markdown]
# <a id="part_5_lasso_reg"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Implement Lasso Regression ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# from sklearn.linear_model import Lasso

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("Lasso", Lasso())]

lasso_model = Pipeline(steps=operations)

lasso_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
train_val(lasso_model, X_train, y_train, X_test, y_test)
# Out:
#                train            test
# R2             0.504           0.490
# mae       232072.071      234092.537
# mse  96270687051.051 97955559367.504
# rmse      310275.180      312978.529
# mape           0.253           0.258

# %% [markdown]
# <a id="part_5_lasso_cross"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Cross Validation ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("Lasso", Lasso())]

pipe_model = Pipeline(steps=operations)
scores = cross_validate(pipe_model, 
                        X_train, 
                        y_train,
                        scoring=['r2', 
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'],
                        cv=10, 
                        return_train_score=True)

# %%
scores = pd.DataFrame(scores, index = range(1, 11))
scores.iloc[:,2:].mean()
# Out:
# test_r2                                               0.503
# train_r2                                              0.504
# test_neg_mean_absolute_error                    -232248.949
# train_neg_mean_absolute_error                   -232064.217
# test_neg_mean_squared_error                -96416294836.650
# train_neg_mean_squared_error               -96261889116.594
# test_neg_root_mean_squared_error                -310447.127
# train_neg_root_mean_squared_error               -310260.225
# test_neg_mean_absolute_percentage_error              -0.253
# train_neg_mean_absolute_percentage_error             -0.253
# dtype: float64

# %% [markdown]
# <a id="part_5_lasso_best"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Finding best alpha for Lasso ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("Lasso", Lasso())]

model = Pipeline(steps=operations)

param_grid = {'Lasso__alpha':alpha_space}# Parameter names should be used together with the model name defined in the pipeline.

lasso_grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1,
                          return_train_score=True)

# %%
lasso_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHot_Encoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['type']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['suburb',
# ...

# %%
lasso_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
pd.DataFrame(lasso_grid_model.cv_results_).loc[lasso_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score    -310446.871
# mean_train_score   -310260.705
# Name: 24, dtype: object

# %%
train_val(lasso_grid_model, X_train, y_train, X_test, y_test)
# Out:
#                train            test
# R2             0.504           0.490
# mae       232046.234      234064.816
# mse  96270988745.247 97954710152.351
# rmse      310275.666      312977.172
# mape           0.253           0.258

# %%
y_pred = lasso_grid_model.predict(X_test)
lasm_R2 = r2_score(y_test, y_pred)
lasm_mae = mean_absolute_error(y_test, y_pred)
lasm_rmse = mean_squared_error(y_test, y_pred, squared=False)
lasm_mape= mean_absolute_percentage_error(y_test, y_pred)

# %%
pd.DataFrame(data=lasso_grid_model.best_estimator_["Lasso"].coef_, 
             index=lasso_grid_model.best_estimator_["OneHot_Encoder"].get_feature_names_out(), 
             columns=["Coef"]).sort_values("Coef")
# Out:
#                            Coef
# distance            -639324.497
# type_u              -136146.319
# suburb              -113375.761
# council_area        -104686.722
# seller_g             -41619.134
# method               -41204.213
# type_t                  152.255
# regionname            15332.714
# total_room_bathroom   17881.574
# bedroom_2             35736.546
# propertycount         47518.280
# car                   62826.580
# type_h               121041.250
# total_area           123142.686
# landsize             155057.618
# rooms                192577.773
# bathroom             236611.460
# building_age         348766.222
# building_area        975824.686

# %% [markdown]
# <a id="part_5_elastic_reg"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Implement Elastic-Net ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# from sklearn.linear_model import ElasticNet

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("ElasticNet", ElasticNet())]

elastic_model = Pipeline(steps=operations)

elastic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
train_val(elastic_model, X_train, y_train, X_test, y_test)
# Out:
#                 train             test
# R2              0.241            0.238
# mae        290182.598       289313.448
# mse  147393180343.920 146372971351.098
# rmse       383918.195       382587.208
# mape            0.346            0.349

# %% [markdown]
# <a id="part_5_elastic_cross"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Cross Validation ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("ElasticNet", ElasticNet())]

model = Pipeline(steps=operations)

scores = cross_validate(model, 
                        X_train, 
                        y_train,
                        scoring=['r2', 
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'], 
                        cv=10, 
                        return_train_score=True)

# %%
scores = pd.DataFrame(scores, index = range(1, 11))
scores.iloc[:,2:].mean()
# Out:
# test_r2                                                0.241
# train_r2                                               0.242
# test_neg_mean_absolute_error                     -290115.175
# train_neg_mean_absolute_error                    -290069.688
# test_neg_mean_squared_error                -147361079551.000
# train_neg_mean_squared_error               -147309796016.356
# test_neg_root_mean_squared_error                 -383734.534
# train_neg_root_mean_squared_error                -383808.186
# test_neg_mean_absolute_percentage_error               -0.346
# train_neg_mean_absolute_percentage_error              -0.346
# dtype: float64

# %% [markdown]
# <a id="part_5_elastic_best"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Finding best alpha and l1_ratio for ElasticNet ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("ElasticNet", ElasticNet())]

model = Pipeline(steps=operations)

param_grid = {'ElasticNet__alpha':np.linspace(-1, 1, 15), #[0.001,0.01, 0.5, 1, 2,  3, 4],
              'ElasticNet__l1_ratio':[0.5, 0.7, 0.9, 0.95, 0.99, 1]} 

elastic_grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1,
                          return_train_score=True)

# %%
elastic_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHot_Encoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['type']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['suburb',
# ...

# %%
elastic_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
pd.DataFrame(elastic_grid_model.cv_results_).loc[elastic_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score    -310447.127
# mean_train_score   -310260.225
# Name: 89, dtype: object

# %%
train_val(elastic_grid_model, X_train, y_train, X_test, y_test)
# Out:
#                train            test
# R2             0.504           0.490
# mae       232072.071      234092.537
# mse  96270687051.051 97955559367.504
# rmse      310275.180      312978.529
# mape           0.253           0.258

# %%
y_pred = elastic_grid_model.predict(X_test)
em_R2 = r2_score(y_test, y_pred)
em_mae = mean_absolute_error(y_test, y_pred)
em_rmse = mean_squared_error(y_test, y_pred, squared=False)
em_mape= mean_absolute_percentage_error(y_test, y_pred)

# %% [markdown]
# <a id="part_5_feature_importance"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Feature Importance/selection ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_feat_imp =pd.DataFrame(
                         data=lasso_grid_model.best_estimator_["Lasso"].coef_, 
                         index=lasso_grid_model.best_estimator_["OneHot_Encoder"].get_feature_names_out(), 
                         columns=["Coef"]
                         ).sort_values("Coef")## Feature İmportance/selection

# %%
df_feat_imp
# Out:
#                            Coef
# distance            -639324.497
# type_u              -136146.319
# suburb              -113375.761
# council_area        -104686.722
# seller_g             -41619.134
# method               -41204.213
# type_t                  152.255
# regionname            15332.714
# total_room_bathroom   17881.574
# bedroom_2             35736.546
# propertycount         47518.280
# car                   62826.580
# type_h               121041.250
# total_area           123142.686
# landsize             155057.618
# rooms                192577.773
# bathroom             236611.460
# building_age         348766.222
# building_area        975824.686

# %%
plt.figure(figsize=(10,14))
sns.barplot(data= df_feat_imp, 
            x=df_feat_imp.Coef, 
            y=df_feat_imp.index);

# %% [markdown]
# <a href="#part_info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">The two most important features with a positive impact are building area, while distance has a negative impact.</p>
# </div>

# %%
lasso_grid_model.best_estimator_["Lasso"]
# Out:
# Lasso(alpha=23.484848484848484)

# %%
# from yellowbrick.model_selection import FeatureImportances
# from yellowbrick.features import RadViz

model = lasso_grid_model.best_estimator_["Lasso"] # Lasso(alpha=0.001)

viz = FeatureImportances(model, 
                         labels=lasso_grid_model.best_estimator_["OneHot_Encoder"].get_feature_names_out())

visualizer = RadViz(size=(720, 3000))
viz.fit(X_train, y_train)
viz.show();

# %% [markdown]
# <a id="part_5_decision_tree"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Decision Tree- Regression ✨</p>

# %% [markdown]
# ![decision_tree.png](https://static.javatpoint.com/tutorial/machine-learning/images/decision-tree-classification-algorithm.png)

# %% [markdown]
# <a id="part_5_decision_pipeline"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Pipeline ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# from sklearn.pipeline import Pipeline
# from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("DT_model", DecisionTreeRegressor(random_state=42))]

decision_model = Pipeline(steps=operations)

decision_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
train_val(decision_model, X_train, y_train, X_test, y_test)
# Out:
#              train             test
# R2           0.999            0.465
# mae        702.022       201390.187
# mse  159121152.248 102795223631.467
# rmse     12614.323       320616.942
# mape         0.001            0.204

# %%
# from sklearn.model_selection import cross_validate

operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("DT_model", DecisionTreeRegressor(random_state=42))]
model = Pipeline(steps=operations)

scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'],
                        cv =10,
                        return_train_score=True)

df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]

# There is over fitting
# Out:
# test_r2                                                0.455
# train_r2                                               0.999
# test_neg_mean_absolute_error                     -206350.252
# train_neg_mean_absolute_error                       -641.991
# test_neg_mean_squared_error                -105707586853.533
# train_neg_mean_squared_error                  -145778806.121
# test_neg_root_mean_squared_error                 -325012.555
# train_neg_root_mean_squared_error                 -12001.427
# test_neg_mean_absolute_percentage_error               -0.208
# train_neg_mean_absolute_percentage_error              -0.001
# dtype: float64

# %%
# from yellowbrick.regressor import PredictionError
# from yellowbrick.features import RadViz

visualizer = RadViz(size=(720, 600))

model = decision_model
visualizer = PredictionError(model)
visualizer.fit(X_train, y_train) # Fit the training data to the visualizer
visualizer.score(X_test, y_test) # Evaluate the model on the test data
visualizer.show();

# We found that prices greater than 10 worsened the forecasts.

# %% [markdown]
# <a id="part_5_decision_gridsearch"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ GridSearch ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# from sklearn.model_selection import GridSearchCV, validation_curve
# from yellowbrick.model_selection import ValidationCurve

# %%
param_grid = {"DT_model__criterion": ["squared_error", "friedman_mse", "absolute_error", "poisson"],
              "DT_model__ccp_alpha": [.04, .043, .05],
              "DT_model__max_depth": [None, range(2, 15, 1)]}

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("scaler", scaler), 
              ("DT_model", DecisionTreeRegressor(random_state=42))]

pipe_model = Pipeline(steps=operations)
grid_model = GridSearchCV(estimator=pipe_model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs=-1,
                          return_train_score=True)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHot_Encoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['type']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['suburb',
# ...

# %%
grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
pd.DataFrame(grid_model.cv_results_).loc[grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# # overfitting problem is solved
# Out:
# mean_test_score    -324827.423
# mean_train_score    -12001.427
# Name: 2, dtype: object

# %%
train_val(grid_model, X_train, y_train, X_test, y_test)

# # We have seen that the test data scores and the validation set scores from the CV are consistent.
# Out:
#              train             test
# R2           0.999            0.465
# mae        702.022       201390.187
# mse  159121152.248 102795223627.030
# rmse     12614.323       320616.942
# mape         0.001            0.204

# %%
from sklearn.model_selection import cross_validate, cross_val_score

operations = [("OneHot_Encoder", column_trans),
              ("scaler", scaler),
              ("DT_model", DecisionTreeRegressor(ccp_alpha=0.04,
                                                 criterion='friedman_mse',
                                                 random_state=42, 
                                                 max_depth =8 ))]

model = Pipeline(steps=operations)


scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'],
                        cv = 10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index=range(1,11))
df_scores.iloc[:,2:]

# We can make a CV to see all metrics.
# When we look at all iterations in the CV, we can see that some scores are very different.
# This is expected for very small data.
# Out:
#     test_r2  train_r2  test_neg_mean_absolute_error  \
# 1     0.599     0.668                   -190780.294
# 2     0.647     0.686                   -185087.690
# 3     0.636     0.686                   -186246.374
# 4     0.633     0.685                   -189912.775
# 5     0.625     0.676                   -179057.094
# 6     0.582     0.669                   -193265.064
# 7     0.585     0.671                   -187105.738
# 8     0.632     0.687                   -183778.296
# 9     0.632     0.674                   -186621.645
# 10    0.639     0.679                   -182989.499
#
#     train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 1                     -175969.523             -76762701608.006
# 2                     -170223.779             -72638721099.945
# 3                     -170639.064             -73807872643.857
# 4                     -170412.475             -75983471424.517
# 5                     -175251.612             -66754827710.422
# ...

# %%
df_scores.mean()[2:]
# Out:
# test_r2                                               0.621
# train_r2                                              0.678
# test_neg_mean_absolute_error                    -186484.447
# train_neg_mean_absolute_error                   -173172.341
# test_neg_mean_squared_error                -73425049196.085
# train_neg_mean_squared_error               -62523799586.539
# test_neg_root_mean_squared_error                -270909.851
# train_neg_root_mean_squared_error               -250025.592
# test_neg_mean_absolute_percentage_error              -0.193
# train_neg_mean_absolute_percentage_error             -0.180
# dtype: float64

# %% [markdown]
# <a id="part_5_fea_importance"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Feature Importance ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
operations = [("OneHot_Encoder", column_trans),
              ("scaler", scaler),
              ("DT_model", DecisionTreeRegressor(ccp_alpha=0.04,
                                                 criterion='friedman_mse',
                                                 random_state=42, 
                                                 max_depth =8 ))]
pipe_model = Pipeline(steps=operations)
pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
X_train.head(1)
# Out:
#           suburb  rooms type method seller_g  distance  bedroom_2  bathroom  \
# 13462  St Albans      3    h     PI      YPA    14.000      3.000     1.000
#
#         car  landsize  building_area           council_area  \
# 13462 2.000   563.000        171.000  Brimbank City Council
#
#                  regionname  propertycount  building_age  total_room_bathroom  \
# 13462  Western Metropolitan      14042.000        34.000                4.000
#
#        total_area
# 13462     734.000

# %%
features = pipe_model["OneHot_Encoder"].get_feature_names_out()

features
# Out:
# array(['type_h', 'type_t', 'type_u', 'suburb', 'method', 'seller_g',
#        'council_area', 'regionname', 'rooms', 'distance', 'bedroom_2',
#        'bathroom', 'car', 'landsize', 'building_area', 'propertycount',
#        'building_age', 'total_room_bathroom', 'total_area'], dtype=object)

# %%
pipe_model["OneHot_Encoder"].fit_transform(X_train).head()
# Out:
#        type_h  type_t  type_u  suburb  method  seller_g  council_area  \
# 13462   1.000   0.000   0.000 246.000   0.000   310.000         3.000
# 14632   0.000   1.000   0.000 225.000   0.000    16.000        14.000
# 123     0.000   0.000   1.000   2.000   2.000   169.000        18.000
# 1405    1.000   0.000   0.000  28.000   4.000   236.000         6.000
# 25786   1.000   0.000   0.000  31.000   2.000   197.000        23.000
#
#        regionname  rooms  distance  bedroom_2  bathroom   car  landsize  \
# 13462       6.000      3    14.000      3.000     1.000 2.000   563.000
# 14632       0.000      3    19.900      3.000     2.000 2.000   249.000
# 123         6.000      3    13.500      3.000     1.000 2.000   569.000
# 1405        5.000      4    13.900      4.000     2.000 2.000   572.000
# 25786       0.000      4    13.400      4.000     2.000 2.000   641.500
#
#        building_area  propertycount  building_age  total_room_bathroom  \
# ...

# %%
df_f_i = pd.DataFrame(data = pipe_model["DT_model"].feature_importances_,
                      index=features,
                      columns=["Feature Importance"])

df_f_i = df_f_i.sort_values("Feature Importance", ascending=False)

df_f_i
# Out:
#                      Feature Importance
# building_area                     0.463
# distance                          0.149
# type_u                            0.134
# regionname                        0.100
# building_age                      0.055
# total_area                        0.015
# type_h                            0.014
# council_area                      0.013
# landsize                          0.012
# propertycount                     0.009
# method                            0.009
# total_room_bathroom               0.008
# rooms                             0.007
# type_t                            0.005
# seller_g                          0.003
# bedroom_2                         0.002
# suburb                            0.002
# car                               0.001
# bathroom                          0.000

# %%
ax = sns.barplot(x = df_f_i.index, y = 'Feature Importance', data = df_f_i)
ax.bar_label(ax.containers[0],fmt="%.3f" ,rotation = 90)
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# <a id="part_5_compare"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Compare real and predicted result ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
y_pred = grid_model.predict(X_test)
my_dict = { 'Actual': y_test, 'Pred': y_pred, 'Residual': y_test-y_pred }
compare = pd.DataFrame(my_dict)

# %%
comp_sample = compare.sample(20)
comp_sample
# Out:
#            Actual        Pred    Residual
# 24512 1670000.000 2300000.000 -630000.000
# 1847  1405000.000 1400000.000    5000.000
# 28855 2280000.000 2625000.000 -345000.000
# 28580  928000.000  928000.000       0.000
# 1355   928000.000  900000.000   28000.000
# 20100  790000.000  745000.000   45000.000
# 15547 1130000.000 1140000.000  -10000.000
# 4877   928000.000  928000.000       0.000
# 2585   928000.000  928000.000       0.000
# 4026   435000.000  370000.000   65000.000
# 775    890000.000 1360000.000 -470000.000
# 25387  925000.000  825000.000  100000.000
# 23910  740000.000  557500.000  182500.000
# 18551  669250.000  615000.000   54250.000
# 24701  950000.000  988000.000  -38000.000
# 16228  800000.000 1205000.000 -405000.000
# 22697 1210000.000 1210000.000       0.000
# 30346  720000.000  611000.000  109000.000
# 14702 1205500.000 1200000.000    5500.000
# 29626  687000.000  595000.000   92000.000

# %%
comp_sample.plot(kind='bar',figsize=(9,5))
plt.show()

# %% [markdown]
# <a id="part_5_random_forest"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Random Forest ✨</p>

# %% [markdown]
# ## Train test split

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (22083, 17)
# Train target shape   :  (22083,)
# Test features shape  :  (9465, 17)
# Test target shape    :  (9465,)

# %% [markdown]
# <a id="part_5_decision_pipeline"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Pipeline ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# ## Modeling with Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

operations = [("OneHot_Encoder", column_trans), 
              ("RF_model", RandomForestRegressor(random_state=42))]

random_model = Pipeline(steps=operations)

random_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %%
train_val(random_model, X_train, y_train, X_test, y_test)
# Out:
#               train            test
# R2            0.962           0.727
# mae       56823.238      150785.908
# mse  7470234743.905 52356334400.297
# rmse      86430.520      228815.066
# mape          0.058           0.156

# %%
from sklearn.model_selection import cross_validate

operations = [("OneHot_Encoder", column_trans), 
              ("RF_model", RandomForestRegressor(random_state=42))]

model = Pipeline(steps=operations)

scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'],
                        cv =10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[203], line 8
#       3 operations = [("OneHot_Encoder", column_trans),
#       4               ("RF_model", RandomForestRegressor(random_state=42))]
#       6 model = Pipeline(steps=operations)
# ----> 8 scores = cross_validate(model,
#       9                         X_train,
#      10                         y_train,
#      11                         scoring=['r2',
#      12                                  'neg_mean_absolute_error',
#      13                                  'neg_mean_squared_error',
#      14                                  'neg_root_mean_squared_error',
#      15                                  'neg_mean_absolute_percentage_error'],
#      16                         cv =10,
#      17                         return_train_score=True)
#      18 df_scores = pd.DataFrame(scores)
# ...

# %% [markdown]
# <a id="part_5_decision_gridsearch"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ GridSearch ✨</p>

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("RF_model", RandomForestRegressor(random_state=42))]

model = Pipeline(steps=operations)

# %%
param_grid = {"RF_model__criterion":["squared_error", "absolute_error"], # "poisson"
              "RF_model__n_estimators":[50, 100],
              "RF_model__max_depth": [2,3],
              "RF_model__min_samples_leaf": [1, 2, 3],
              "RF_model__min_samples_split": [2, 3, 5],
              "RF_model__max_features":['auto', X.shape[1]/3, 6]} <a id="part_5_decision_gridsearch"></a>
# <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ GridSearch ✨</p>

# %%
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs=-1,
                          return_train_score=True)

# %%
grid_model.fit(X_train,y_train)

# %%
grid_model.best_estimator_

# %%
pd.DataFrame(grid_model.cv_results_).loc[grid_model.best_index_, ["mean_test_score", "mean_train_score"]]

# %%
train_val(grid_model, X_train, y_train, X_test, y_test)

# %%
operations = [("OrdinalEncoder", column_trans),
              ("RF_model", RandomForestRegressor(max_depth=2,
                                                 max_features=6,
                                                 min_samples_leaf=3,
                                                 n_estimators=500,
                                                 random_state=101))]

model = Pipeline(steps=operations)

scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                 'neg_mean_absolute_error',
                                 'neg_mean_squared_error',
                                 'neg_root_mean_squared_error',
                                 'neg_mean_absolute_percentage_error'],
                        cv = 10,
                        return_train_score=True)

df_scores = pd.DataFrame(scores, index=range(1,11))
df_scores.mean()[2:]

# %% [markdown]
# <a id="part_5_feature_importance"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Feature Importance/selection ✨</p>

# %%
operations = [("OrdinalEncoder", column_trans),
              ("RF_model", RandomForestRegressor(max_depth=2,
                                                 max_features=6,
                                                 min_samples_leaf=3,
                                                 n_estimators=500,
                                                 random_state=101))]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_train, y_train)

# %%
features = pipe_model["OrdinalEncoder"].get_feature_names_out()
features

# %%
pipe_model["RF_model"].feature_importances_

# %%
df_f_i = pd.DataFrame(data=pipe_model["RF_model"].feature_importances_,
                      index=features,
                      columns=["Feature Importance"])
df_f_i = df_f_i.sort_values("Feature Importance", ascending=False)
df_f_i

# %%
ax =sns.barplot(x = df_f_i.index,
                y = 'Feature Importance',
                data = df_f_i)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# <a id="part_5_final_model"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Final Model ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
X=df_full_new.drop("price", axis=1)
y=df_full_new.price

# %%
# from sklearn.pipeline import Pipeline
operations = [("OneHot_Encoder", column_trans),
              ("scaler", scaler),
              ("DT_model", DecisionTreeRegressor(ccp_alpha=0.04,
                                                 criterion='friedman_mse',
                                                 random_state=42, 
                                                 max_depth =8 ))]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X, y)

# re-build our final model for all data with the best hyper parameters.
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['type']),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['suburb', 'method',
#                                                    'seller_g', 'council_area',
#                                                    'regionname'])],
#                                    verbose_feature_names_out=False)),
# ...

# %% [markdown]
# <a id="Summary"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Summary ✨</p>

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Without performing a log transformation, it is evident that the data is not well-suited for linear regression, and this also indicates that the data is non-linear in nature.</p>
#     <p style="font-weight: bold; color: white;">The low R-squared score in linear models suggests that linear regression is not an appropriate choice. However, the improvement in other metrics, except for R-squared, after the log transformation demonstrates a substantial enhancement in model performance.</p>
#     <p style="font-weight: bold; color: white;">The increase in metrics in non-linear models, such as the Decision Tree model, further emphasizes the non-linear characteristics of the data. It is likely that you can achieve even better scores by using models like Random Forest or XGBoost.</p>
#     <p style="font-weight: bold; color: white;">To mitigate the effects of multicollinearity present in the data, regularization methods such as ridge and lasso were employed. As known, regularization adds an error term to the data to mitigate potential overfitting and achieve a balanced trade-off between variance and bias.</p>
#     <p style="font-weight: bold; color: white;">Due to the non-linear relationships in the data, superior results were obtained with tree-based models. The analysis included the application of various models, including linear, ridge, lasso, elastic net, and decision tree. Ultimately, the decision tree model yielded the best results.</p>
# </div>

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 100%;" aria-valuenow="100" aria-valuemin="100" aria-valuemax="100">100%</div>
# </div>

# %% [markdown]
# <a id="the_end"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ THE END ✨</p>

# %% [markdown]
# <a href="#part_1" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 1</a>
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#part_3" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 3</a>
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>You can access the entire study through the following links. Good luck with your work. </h6>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> 🏡Melbourne House Price Regression Exploration 📈
#  </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/machine_learning/tree/main/Project/melbourne_house_price_regression_exploration"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/huseyincenik/melbourne-house-price-regression-exploration"><b>Kaggle Notebook Link</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>
