# %% [markdown]
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED;font-size:220%; text-align:center; border-radius: 15px 55px;">📊💪 The Ultimate Guide to Multi-Class Classification for Predicting Race 📏📈</p>

# %% [markdown]
# <img src="https://cdn.kicksdigital.com/anthrotech.net/2017/12/anthrotech_blog_ANSUR-vs-ANSUR-2.jpg" alt="Melbourne" width="1000" height="1000">

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 0%;" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100">0%</div>
# </div>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> 🏡Melbourne House Price Regression Exploration 📈
#  </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/machine_learning/tree/main/Project/melbourne_house_price_regression_exploration"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/huseyincenik/melbourne-house-price-regression-exploration"><b>Kaggle Notebook Link</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>

# %% [markdown]
# <a id="toc"></a>
# <div style="border-radius: 10px;
#             border: black solid;
#             background-color: lightblue;
#             font-size: 100%;
#             text-align: left;
#             box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
# <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: white; background-color: red;"><center> ✍✍ Content ✍✍</center></h2>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#part_1">PART - 1 ( DATA CLEANING )</a></li>
#     <li><a href="#part_2">PART - 2 ( HANDLING WITH MISSING VALUES )</a></li>
#     <li><a href="#part_3">PART - 3 ( HANDLING WITH OUTLIERS )</a></li>
#     <li><a href="#part_4">PART - 4 ( FEATURE ENGINEERING )</a></li>
#     <li><a href="#part_5">PART - 5 (  ML PREDICTION )</a></li>
#     </ul>
# </div>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#part_5_final_model">FINAL MODEL</a></li>
#     <li><a href="#summary">SUMMARY</a></li>
#     <li><a href="#the_end">THE END </a></li>
#   </ul>
# </div>
# </div>

# %% [markdown]
# <a id="part_1"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 1 ( Data Cleaning ) ✨</p>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_dataset" role="tab" aria-controls="profile">
#     Dataset Explanation
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_importing" role="tab" aria-controls="messages">
#     Importing Libraries Needed in This Notebook
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_def" role="tab" aria-controls="settings">
#     User Defined Functions (DEFs)
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_reading" role="tab" aria-controls="settings">
#     Reading & Understanding Data
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
# </div>

# %% [markdown]
# <a id="part_1_dataset"></a>
# <div style="border-radius: 10px; border: 1px solid black; background-color:#3498DB ; font-size: 100%; text-align: left; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); padding: 10px; margin-bottom: 20px;">
#     <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">⚡️ Dataset Explanation ⚡️</h2>
#     <p>
#         <strong style="color: white;">Memorandum:</strong>
#         This memorandum outlines the contents of the ANSUR II Working Databases and provides a brief explanation of each variable contained in the databases. These databases and this memorandum have been reviewed and cleared for UNLIMITED PUBLIC RELEASE.
#     </p>
#     <p>
#         <strong style="color: white;">ANSUR II Survey:</strong>
#         The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#     </p>
#     <p>
#         <strong style="color: white;">Database Details:</strong>
#         The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects. The databases are reported in the associated spreadsheet files:
#     </p>
#     <ul>
#         <li>ANSUR II MALE Public.csv</li>
#         <li>ANSUR II FEMALE Public.csv</li>
#     </ul>
# </div>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="part_1_importing"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Importing Libraries Needed in This Notebook ✨</p>

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
# !pip install numpy
# !pip install scikit-learn==1.3.1 --user
# !pip install skimpy --user
# !pip install colorama
# !pip install termcolor
# !pip install yellowbrick
# !pip install scipy

# %%
# !pip install skimpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skimpy import clean_columns
import scipy.stats as stats

# !pip install termcolor
import colorama
from colorama import Fore, Style  # makes strings colored
from termcolor import colored
from termcolor import cprint

# ml algorithm
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, validation_curve
from yellowbrick.model_selection import ValidationCurve
from yellowbrick.regressor import PredictionError
from yellowbrick.features import RadViz
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import cross_validate
from sklearn.linear_model import ElasticNet
from yellowbrick.model_selection import FeatureImportances
from statsmodels.stats.outliers_influence import variance_inflation_factor


from sklearn.metrics import accuracy_score, f1_score, recall_score,\
                            precision_score, make_scorer,\
                            classification_report,confusion_matrix,\
                            ConfusionMatrixDisplay, average_precision_score,\
                            roc_curve, auc

from scipy.stats import skew


import warnings
warnings.filterwarnings('ignore')
# plt.rcParams["figure.figsize"] = (7,4)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.max_rows', 1000)

# %%
# version control
import pandas
import numpy
import matplotlib
import seaborn
import sklearn

print("Pandas Version: ", pandas.__version__)
print("NumPy Version: ", numpy.__version__)
print("Matplotlib Version: ", matplotlib.__version__)
print("Seaborn Version: ", seaborn.__version__)
print("Scikit-Learn Version: ", sklearn.__version__)
# Out:
# Pandas Version:  1.5.3
# NumPy Version:  1.23.5
# Matplotlib Version:  3.7.0
# Seaborn Version:  0.12.2
# Scikit-Learn Version:  1.3.1

# %%
# pip install skimpy

# %% [markdown]
# <a id="part_1_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ User Defined Functions (DEFs) ✨</p>

# %% [markdown]
# <a href="#part_1" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 1</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
## Some Useful User-Defined-Functions

###############################################################################

def missing_values(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values[missing_values['Missing_Number']>0]
###############################################################################
def first_looking(df):
    print(colored("Shape:", attrs=['bold']), df.shape,'\n',
          colored('*'*100, 'red', attrs=['bold']),
          colored("\nInfo:\n", attrs=['bold']), sep='')
    print(df.info(), '\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Number of Uniques:\n", attrs=['bold']), df.nunique(),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Missing Values:\n", attrs=['bold']), missing_values(df),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("All Columns:", attrs=['bold']), list(df.columns),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='')

#     df.columns= df.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')
#     print(colored("Columns after rename:", attrs=['bold']), list(df.columns),'\n',
#           colored('*'*100, 'red', attrs=['bold']), sep='')
    print(colored("Descriptive Statistics \n", attrs=['bold']), df.describe().round(2),'\n',
          colored('*'*100, 'red', attrs=['bold']), sep='') # Gives a statstical breakdown of the data.
#     print(colored("Descriptive Statistics (Categorical Columns) \n", attrs=['bold']), df.describe(include=object).T,'\n',
#           colored('*'*100, 'red', attrs=['bold']), sep='') # Gives a statstical breakdown of the data.

###############################################################################
def first_look(df, col):
    """
    Prints basic information about a column in a Pandas DataFrame.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame to analyze.
    col : str
        The name of the column to analyze.

    Returns:
    --------
    None.

    Prints:
    -------
    column name    : str
        The name of the column being analyzed.
    per_of_nulls   : float
        The percentage of null values in the column.
    num_of_nulls   : int
        The number of null values in the column.
    num_of_uniques : int
        The number of unique values in the column.
    shape_of_df    : tuple
        The shape of the DataFrame.
    The unique values in the column and their frequency of occurrence.
    """
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum() * 100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].astype(str).nunique())
    print("shape_of_df    : ", df.shape)
    print("--------------------------------")
    print(df[col].value_counts(dropna=False))
###############################################################################


def duplicate_values(df):
    print(colored("Duplicate check...", attrs=['bold']), sep='')
    duplicate_values = df.duplicated(subset=None, keep='first').sum()
    if duplicate_values > 0:
        df.drop_duplicates(keep='first', inplace=True)
        print(duplicate_values, colored(" Duplicates were dropped!"),'\n',
              colored('*'*100, 'red', attrs=['bold']), sep='')
    else:
        print(colored("There are no duplicates"),'\n',
              colored('*'*100, 'red', attrs=['bold']), sep='')

###############################################################################

# %%
def visualize_data(df, column, plot_type='histogram', iqr_multiplier=1.5, **kwargs):
    """
    Visualizes a column from a DataFrame using the specified plot type.

    Parameters:
        df (DataFrame): The DataFrame containing the data.
        column (str): The name of the column to visualize.
        plot_type (str): The type of plot to create ('histogram', 'box', 'qq', 'bar', 'pie', 'all').
        iqr_multiplier (float): The multiplier for determining whisker length in box plots (default is 1.5).
        **kwargs: Additional keyword arguments for customizing the plot.

    Returns:
        None
    """
    data = df[column]

    if plot_type == 'all':
        plot_types = ['histogram', 'box', 'qq']
        for plot_type in plot_types:
            visualize_data(df, column, plot_type=plot_type, iqr_multiplier=iqr_multiplier, **kwargs)
    else:
        if plot_type == 'histogram':
            plt.figure(figsize=(10, 6))
            sns.histplot(data, kde=True, **kwargs)
            
            skewness = data.skew()
            kurtosis = data.kurtosis()
            mean = data.mean()
            median = data.median()
            mode = data.mode().iloc[0]
            # Başlığı ve değerleri düzenleyelim
            title = f'Histogram of {column}\n\n'
            title += f'Skewness: {skewness:.2f}, '  
            title += f'Kurtosis: {kurtosis:.2f}\n'  
            title += f'Mean: {mean:.2f}, ' 
            title += f'Median: {median:.2f}, '
            title += f'Mode: {mode:.2f}' 
            plt.title(title, fontweight='bold') 
            plt.xlabel(column)
            plt.ylabel('Frequency')
            plt.show()
        elif plot_type == 'box':
            
            mean = np.mean(data)
            median = np.median(data)
            q1 = np.percentile(data, 25)
            q3 = np.percentile(data, 75)
            iqr = q3 - q1
            upper_whisker = q3 + iqr_multiplier * iqr
            lower_whisker = q1 - iqr_multiplier * iqr
            min_whisker = np.min(data[data >= lower_whisker])
            max_whisker = np.max(data[data <= upper_whisker])
           
            num_below_min_whisker = np.sum(data < lower_whisker)
            num_above_max_whisker = np.sum(data > upper_whisker)
            plt.figure(figsize=(10, 6))
            sns.boxplot(y=data, **kwargs)
            plt.title(f'Box Plot of {column}\n\nMean: {mean:.2f}, Median: {median:.2f}, Min Whisker: {min_whisker:.2f}, Max Whisker: {max_whisker:.2f}\nIQR Multiplier: {iqr_multiplier}\n\nNumber of Extreme Values in Below Min Whisker: {num_below_min_whisker}\n Number of Extreme Values in Above Max Whisker: {num_above_max_whisker}', fontweight="bold")
            plt.ylabel(column)
            plt.show()
        elif plot_type == 'qq':
     
            plt.figure(figsize=(10, 6))
            stats.probplot(data, dist="norm", plot=plt)
            plt.title(f'Q-Q Plot of {column}\nNormality Check',  fontweight='bold')
            plt.xlabel('Theoretical Quantiles')
            plt.ylabel('Sample Quantiles')
            plt.show()
        elif plot_type == 'bar':
            value_counts = data.value_counts()
            x = value_counts.index
            y = value_counts.values
            total_height = sum(y)  
            percentages = [(count / total_height) * 100 for count in y] 
            fig, ax = plt.subplots(figsize=(10, 6))
            bars = ax.barh(x, percentages, **kwargs)  # Horizontal bar chart
            plt.title(f'Bar Chart of {column}', fontweight='bold')
            plt.xlabel('Percentage')
            plt.ylabel(column)
            for bar, percentage in zip(bars, percentages):
                width = bar.get_width()
                ax.annotate(f'{percentage:.2f}%', xy=(width, bar.get_y() + bar.get_height() / 2),
                            xytext=(3, 0), textcoords='offset points', va='center')
            plt.show()
        elif plot_type == 'pie':
            value_counts = data.value_counts()
            labels = value_counts.index
            sizes = value_counts.values
            plt.figure(figsize=(8, 8))
            plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, **kwargs)
            plt.title(f'Pie Chart of {column}', fontweight='bold')
            plt.axis('equal')
            plt.show()

# %%
def scatter_or_joint_plot(data, x_col, y_col, title=None, x_label=None, y_label=None, kind='scatter', **kwargs):
    """
    Draws a scatter plot or joint plot on the given DataFrame.

    Parameters:
        data (DataFrame): The DataFrame containing the data.
        x_col (str): The column name for the x-axis.
        y_col (str): The column name for the y-axis.
        title (str, optional): The title of the plot. Defaults to None (uses column names).
        x_label (str, optional): The label for the x-axis. Defaults to None (uses column name).
        y_label (str, optional): The label for the y-axis. Defaults to None (uses column name).
        kind (str, optional): The type of the plot ('scatter' or 'joint'). Defaults to 'scatter'.
        **kwargs: Additional parameters for the scatter or joint plot.

    Returns:
        None
    """
    if title is None:
        title = f'Plot of {x_col} vs {y_col}'
    if x_label is None:
        x_label = x_col
    if y_label is None:
        y_label = y_col

    plt.figure(figsize=(10, 6))
    corr_coefficient = np.corrcoef(data[x_col], data[y_col])[0, 1]

    if kind == 'scatter':
        sns.scatterplot(data=data, x=x_col, y=y_col, **kwargs)
        title_with_corr = f'{title} (Scatter)\n\nCorrelation: {corr_coefficient:.2f}'
        plt.title(title_with_corr, fontweight='bold')
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        plt.grid(True)
    elif kind == 'joint':
        g = sns.jointplot(x=x_col, y=y_col, data=data, **kwargs)
        g.fig.suptitle(f'{title}', fontweight='bold', y=1.02)
        g.ax_joint.set_xlabel(x_label)
        g.ax_joint.set_ylabel(y_label)
        g.ax_marg_x.set_title(f'Correlation: {corr_coefficient:.2f}', fontweight='bold')
        plt.subplots_adjust(top=0.9)

    plt.show()

# scatter_or_joint_plot(df, 'Compressive Strength (28-day)(Mpa)', 'Cement', kind='scatter')
# scatter_or_joint_plot(df, 'Compressive Strength (28-day)(Mpa)', 'Cement', kind='joint')

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %% [markdown]
# <a id="part_1_reading"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Reading & Understanding Data ✨</p>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df_male = pd.read_csv("ANSUR II MALE Public.csv", encoding = "latin")
df_male
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0         10027                             266            1467
# 1         10032                             233            1395
# 2         10033                             287            1430
# 3         10092                             234            1347
# 4         10093                             250            1585
# ...         ...                             ...             ...
# 4077      29442                             235            1353
# 4078      29443                             247            1473
# 4079      29447                             264            1394
# 4080      29451                             203            1417
# 4081      29452                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       337                 222          1347
# 1                       326                 220          1293
# ...

# %%
df_male
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0         10027                             266            1467
# 1         10032                             233            1395
# 2         10033                             287            1430
# 3         10092                             234            1347
# 4         10093                             250            1585
# ...         ...                             ...             ...
# 4077      29442                             235            1353
# 4078      29443                             247            1473
# 4079      29447                             264            1394
# 4080      29451                             203            1417
# 4081      29452                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       337                 222          1347
# 1                       326                 220          1293
# ...

# %%
df_female = pd.read_csv("ANSUR II FEMALE Public.csv", encoding = "latin")
df_female
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0         10037                             231            1282
# 1         10038                             194            1379
# 2         10042                             183            1369
# 3         10043                             261            1356
# 4         10051                             309            1303
# ...         ...                             ...             ...
# 1981      29501                             285            1392
# 1982      29502                             262            1324
# 1983      29503                             260            1334
# 1984      29511                             205            1293
# 1985     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       301                 204          1180
# 1                       320                 207          1292
# ...

# %%
# df_female.info(verbose=True, show_counts=True)

# %%
columns1 = df_female.columns
columns2 = df_male.columns

if columns1.equals(columns2):
    print("Column names are the same.")
else:
    print("Column names are different.")
# Out:
# Column names are different.

# %%
columns1 = set(df_female.columns)
columns2 = set(df_male.columns)

different_columns = columns1.symmetric_difference(columns2)

print("Different Columns:", different_columns)
# Out:
# Different Columns: {'subjectid', 'SubjectId'}

# %% [raw]
# female datasinda Subjectid , male datasinda ise subjectid olarak giriş yapilmiş.Burada SubjectId yi subjectid ye donusturup Skimpy dan clean_columns ile sutunlarin isimlerinin daha iyi gozukmesini saglayabiliriz .

# %%
df_female.rename(columns={"SubjectId": "subjectid"}, inplace=True)

# %%
columns1 = df_female.columns
columns2 = df_male.columns

if columns1.equals(columns2):
    print("Column names are the same.")
else:
    print("Column names are different.")
# Out:
# Column names are the same.

# %%
columns1 = set(df_female.columns)
columns2 = set(df_male.columns)

different_columns = columns1.symmetric_difference(columns2)

print("Different Columns:", different_columns)
# Out:
# Different Columns: set()

# %%
df_female.sample(1).T
# Out:
#                                       1674
# subjectid                            28279
# abdominalextensiondepthsitting         188
# acromialheight                        1303
# acromionradialelength                  303
# anklecircumference                     183
# ...                                    ...
# DODRace                                  1
# Age                                     39
# Heightin                                61
# Weightlbs                              115
# WritingPreference               Right hand
#
# [108 rows x 1 columns]

# %%
df_male = clean_columns(df_male)
df_female = clean_columns(df_female)
# Out:
# 14 column names have been cleaned
# 14 column names have been cleaned

# %%
# dataframelerin sutun isimleri ayni oldugu icin alt alta birlestirildi .

# %%
df_full0 = pd.concat([df_male, df_female], ignore_index = True)
df_full = df_full0.copy()

# %%
df_full0
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0         10027                             266            1467
# 1         10032                             233            1395
# 2         10033                             287            1430
# 3         10092                             234            1347
# 4         10093                             250            1585
# ...         ...                             ...             ...
# 6063      29501                             285            1392
# 6064      29502                             262            1324
# 6065      29503                             260            1334
# 6066      29511                             205            1293
# 6067     920103                             238            1346
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       337                 222          1347
# 1                       326                 220          1293
# ...

# %% [markdown]
# ## Explore Data

# %%
first_looking(df_full)
duplicate_values(df_full)
# Out:
# Shape:(6068, 108)
# ****************************************************************************************************
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Columns: 108 entries, subjectid to writing_preference
# dtypes: int64(99), object(9)
# memory usage: 5.0+ MB
# None
# ****************************************************************************************************
# Number of Uniques:
# subjectid                         6068
# abdominalextensiondepthsitting     218
# acromialheight                     432
# acromionradialelength              133
# anklecircumference                 112
#                                   ...
# dod_race                             7
# age                                 42
# heightin                            29
# weightlbs                          188
# writing_preference                   3
# Length: 108, dtype: int64
# ...

# %%
# Checking Mixed Type of Data:
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''

    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df_full)
# Out:
# Column ethnicity has mixed object types.
# NO PROBLEM  with the data types of Columns in the DataFrame.

# %%
# # import warnings

# # Filtreleme yapmadan önce tüm uyarıları yakalayın
# warnings.filterwarnings("ignore")
# from dataprep.datasets import load_dataset
# from dataprep.eda import create_report
# create_report(df_full).show_browser()

# %%
for i in df_full.columns[:]:
    print("*" * 30)
    print("Column Name: ", i)
    print()
    print("Number of NaN values in the column: ", df_full[i].isnull().sum())
    print()
    print("What percentage of the column consists of NaN values?", (df_full[i].isnull().sum() / len(df_full)) * 100)
    print()
    print("Value counts for the column:\n", df_full[i].value_counts(dropna=False))
# Out:
# ******************************
# Column Name:  subjectid
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  10027     1
# 29341     1
# 29355     1
# 29353     1
# 29351     1
#          ..
# 17130     1
# 17129     1
# 17127     1
# 17126     1
# 920103    1
# Name: subjectid, Length: 6068, dtype: int64
# ******************************
# Column Name:  abdominalextensiondepthsitting
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  230    85
# 250    83
# 238    78
# 227    78
# 237    74
#        ..
# 365     1
# 382     1
# 331     1
# 404     1
# 169     1
# Name: abdominalextensiondepthsitting, Length: 218, dtype: int64
# ******************************
# Column Name:  acromialheight
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# ...

# %% [raw]
# # subjectnumericrace , targetfeature - dodrace ile ayni oldugu icin
# # Heightin, weigthlbs self-reported oldugu icin ve heightin yerine datada stature , weightlbs yerine ise datada weightkg oldugu icin
# # olusturulacak model api ile veya farkli bir entegrasyon ile kisilerin irklarini sormaksizin tahmin etmeyi amacladigi icin date, installation, component, branch, primarymos sutunlarida dusuldu .

# %%
df_full.subjects_birth_location.value_counts().plot(kind="bar", figsize=(20,10))
plt.title("Subjects Birth Location")
plt.xlabel("Birth Location")
plt.ylabel("Count")
plt.axhline(10, color='r', linestyle='--')  # Some research says 10 rows are enough for each category to be represented
plt.tight_layout();

# %%
# model 10 un altinda olanlari ogrenemeyecegi icin droplamak iyi olacaktir.

# %%
df_full["dod_race"] = df_full.dod_race.map({
    1: "White",
    2: "Black",
    3: "Hispanic",
    4: "Asian",
    5: "Native American",
    6: "Pacific Islander",
    8: "Other"
})

# Targetımdaki numeric verileri daha anlaşılır hala getirmek için dökümanda belirtilen etnik isimlerine göre yeniden
# isimlendiriyoruz.

# %%
df_full.groupby(["component"])["dod_race"].value_counts(normalize = True).plot(kind="barh", figsize=(7,7))
# Out:
# <Axes: ylabel='component,dod_race'>

# %% [raw]
# # componente gore dodrace e bakildiginda datadakine benzer dagilima sahip oldugu gorulur. Dolayisiyla buradan insight cikarmak zor olacak.Bu sutun dusulmeli.

# %%
df_full.groupby(["component", "branch"])["dod_race"].value_counts().plot(kind="barh", figsize=(7,10));

# %%
# yukarda elde ettiğimiz insightlra benzer insightlar elde ettik. Hispaniclerin baskın olduğu bir birlik veya branş yok.

# %%
df_full.subject_numeric_race.value_counts()
# targetimizla ayni bilgiyi iceriyor. bu sutunu alirsak data leakage a sebebiyet verecek. Droplanacak.
# Out:
# 1        3561
# 2        1026
# 3         541
# 31        160
# 51        126
# 8         116
# 4         109
# 21         60
# 6          59
# 41         46
# 61         35
# 23         34
# 28         26
# 251        20
# 5          18
# 18         18
# 25         14
# 351        10
# 38          9
# 64          8
# 62          8
# 35          8
# 42          7
# 63          7
# 231         6
# 43          5
# 235         4
# 218         3
# 651         2
# 2351        2
# 318         2
# 641         2
# 451         2
# 423         2
# 431         2
# 2518        2
# 48          1
# 631         1
# 4251        1
# 428         1
# 238         1
# 358         1
# 425         1
# 42351       1
# Name: subject_numeric_race, dtype: int64

# %%
df_full.drop(['subject_numeric_race', 'heightin', 
              'weightlbs', 'date', 'installation', 
              'component', 'branch', 'primary_mos', 'subjectid'],axis=1, inplace = True)

# %%
# df_full veri çerçevesinde "subject_birth_location" sütunundaki değerlerin sayısını kontrol et
print("First Shape:", df_full.shape)

# 10'dan küçük olanları atan
df_full = df_full[df_full['subjects_birth_location'].map(df_full['subjects_birth_location'].value_counts()) >= 10]

# Sonrası Shape'i göster
print("Last Shape:", df_full.shape)
# Out:
# First Shape: (6068, 100)
# Last Shape: (5819, 100)

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 1000)
df_full.describe().T
# Out:
#                                  count          mean           std      min  \
# subjectid                       5819.0  20809.739130  13378.264624  10027.0
# abdominalextensiondepthsitting  5819.0    246.759237     37.450712    155.0
# acromialheight                  5819.0   1406.994157     78.780809   1146.0
# acromionradialelength           5819.0    327.583777     20.603785    249.0
# anklecircumference              5819.0    225.048977     15.999039    156.0
# axillaheight                    5819.0   1300.279945     71.686993   1062.0
# balloffootcircumference         5819.0    244.211548     16.815545    186.0
# balloffootlength                5819.0    194.854442     13.491131    151.0
# biacromialbreadth               5819.0    399.485822     30.125022    296.0
# bicepscircumferenceflexed       5819.0    341.244200     41.423232    216.0
# bicristalbreadth                5819.0    274.933837     19.180385    197.0
# ...

# %% [markdown]
# <a id="part_2"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 2 ( Handling With Missing Values ) ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_2_def" role="tab" aria-controls="profile">
#     User Defined Functions (DEFs)
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_2_operation" role="tab" aria-controls="messages">
#     Operations on some columns
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_price" role="tab" aria-controls="settings">
#     Column Name : price
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_building_area" role="tab" aria-controls="settings">
#     Column Name : building_area
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_year_built" role="tab" aria-controls="settings">
#     Column Name : year_built
#     <span class="badge badge-primary badge-pill">5</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_land_size" role="tab" aria-controls="settings">
#     Column Name : land_size
#     <span class="badge badge-primary badge-pill">6</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_car" role="tab" aria-controls="settings">
#     Column Name : car
#     <span class="badge badge-primary badge-pill">7</span>
#   </a>
#  <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_bathroom" role="tab" aria-controls="settings">
#     Column Name : bathroom
#     <span class="badge badge-primary badge-pill">8</span>
#   </a>
#
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_bedroom_2" role="tab" aria-controls="settings">
#     Column Name : bedroom_2
#     <span class="badge badge-primary badge-pill">9</span>
#   </a>
#  <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_propertycount" role="tab" aria-controls="settings">
#     Column Name : propertycount
#     <span class="badge badge-primary badge-pill">10</span>
#   </a>
#
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_regionname" role="tab" aria-controls="settings">
#     Column Name : regionname
#     <span class="badge badge-primary badge-pill">11</span>
#   </a>
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_council_area" role="tab" aria-controls="settings">
#     Column Name : council_area
#     <span class="badge badge-primary badge-pill">12</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_distance" role="tab" aria-controls="settings">
#     Column Name : distance
#     <span class="badge badge-primary badge-pill">13</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_2_overview_missing" role="tab" aria-controls="settings">
#     General Overwiew to Missing Values
#     <span class="badge badge-primary badge-pill">14</span>
#   </a>
# </div>

# %% [markdown]
# <a href="#top" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>

# %% [markdown]
# <p><strong style="color:blue;">Some columns</strong>, as seen below, have missing values. The <em style="color:blue;">missing_values</em> function displays the number of missing values in each column.</p>
#
# <p>The column <em style="color:red;">ethnicity</em> contain missing values in the data set.</p>
#
# <p>When dealing with missing values, it is essential to address them effectively to ensure accurate analysis and modeling.</p>

# %% [markdown]
# <a id="part_2_no_basement"></a>
# <div class="alert alert-info" role="alert">
# <h1><span style="color:red"> General Overwiew to Missing Values </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b style="color: red;">Analysis:</b> As for the some columns mentioned above, they can be considered as part of <span style="color: red;"><b>data analysis practice</b></span>. As for the remaining columns, which are not used for predicting house prices, <span style="color: red;"><b>no specific actions were taken for handling missing values</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">The "Ethnicity" column contains NaN values. Since this is the column we intend to predict, the model will be constructed using the non-NaN values. Subsequently, the model will be utilized to predict the NaN values.</p>
# </div>

# %%
missing_values(df_full)
# Out:
#            Missing_Number  Missing_Percent
# ethnicity            4543        78.071834

# %%
df_full.drop("ethnicity", axis = 1 , inplace = True)

# %% [markdown]
# <a id="part_3"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 3 ( Handling With Outliers ) ✨</p>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_3_def" role="tab" aria-controls="profile">
#     User Defined Functions (DEFs)
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_3_price" role="tab" aria-controls="messages">
#     Column name : price
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_3_general_overview" role="tab" aria-controls="settings">
#     General Overview to Outlier Values
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
# </div>

# %%
df_full.reset_index(drop = True, inplace = True)

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819 entries, 0 to 5818
# Data columns (total 99 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   subjectid                       5819 non-null   int64
#  1   abdominalextensiondepthsitting  5819 non-null   int64
#  2   acromialheight                  5819 non-null   int64
#  3   acromionradialelength           5819 non-null   int64
#  4   anklecircumference              5819 non-null   int64
#  5   axillaheight                    5819 non-null   int64
#  6   balloffootcircumference         5819 non-null   int64
#  7   balloffootlength                5819 non-null   int64
#  8   biacromialbreadth               5819 non-null   int64
#  9   bicepscircumferenceflexed       5819 non-null   int64
#  10  bicristalbreadth                5819 non-null   int64
#  11  bideltoidbreadth                5819 non-null   int64
# ...

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ User Defined Functions (DEFs) ✨</p>

# %% [markdown]
# <a href="#part_3" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 3</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# Let's first explore if there has been any problem with data types of Columns in the DataFrame

class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''    
    
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + " " + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df_full)
# Out:
#  NO PROBLEM  with the data types of Columns in the DataFrame.

# %% [markdown]
# <a id="part_2_operation"></a>
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title" >Operations on some columns</button>

# %% [markdown]
# <a id="part_3_price"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> price </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> When examining the <b>Price</b> feature in depth, it was observed that the highest value is <span style="color:red"><b>12,200,000.000</b></span>, and the lowest value is <span style="color:red"><b>85,000.000</b></span>.
# </div>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# numeric_cols = df_full.select_dtypes(include=['int64', 'float64']).columns
# exclude_cols = ['subjectid', 'dod_race', 'subject_numeric_race']
# features = [col for col in numeric_cols if col not in exclude_cols]
# num_cols = 3
# num_features = len(features)

# # plt.figure() ve plt.subplot() işlemlerini daha verimli bir şekilde oluştur
# fig, axes = plt.subplots(num_features // num_cols + 1, num_cols, figsize=(15, 5 * num_features // num_cols))
# axes = axes.ravel()

# for i, feature in enumerate(features):
#     sns.boxplot(x="dod_race", y=feature, data=df_full, ax=axes[i])
#     axes[i].set_xlabel("dod_race")
#     axes[i].set_ylabel(feature)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# <a id="part_4"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Part - 4 ( Feature Engineering )✨</p>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_4_operation" role="tab" aria-controls="profile">
#     Operations on some columns
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_4_building_age" role="tab" aria-controls="messages">
#     Column name : building_age
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_4_total_room_bathroom" role="tab" aria-controls="settings">
#     Column name : total_room_bathroom
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_4_total_area" role="tab" aria-controls="settings">
#     Column name : total_area
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
# </div>

# %% [markdown]
# <a id="part_4_operation"></a>
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title" >Operations on some columns</button>

# %% [markdown]
# <a id="part_4_building_age"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> building_age</span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> A new feature named <span style="color:red"><b>"building_age"</b></span> was created by subtracting the construction year from 2023.
# </div>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="part_5"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Part - 5 ( Machine Learning )✨</p>

# %% [markdown]
# <a href="#part_4" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 4</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">
#     Content
#   </h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_5_multicol" role="tab" aria-controls="profile">
#     Multicollinearity Control
#     <span class="badge badge-primary badge-pill">1</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_5_vif" role="tab" aria-controls="messages">
#     VIF (Variance Inflation Factor) Score for Multicolliniearity
#     <span class="badge badge-primary badge-pill">2</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_train_test" role="tab" aria-controls="settings">
#     Train | Test Split
#     <span class="badge badge-primary badge-pill">3</span>
#   </a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#part_5_make_column" role="tab" aria-controls="settings">
#     Converting Object Features into Numerical Features Using Make Column Transformer
#     <span class="badge badge-primary badge-pill">4</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_scaling" role="tab" aria-controls="settings">
#     Scaling
#     <span class="badge badge-primary badge-pill">5</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_linear_reg" role="tab" aria-controls="settings">
#     Implement Linear Regression
#     <span class="badge badge-primary badge-pill">6</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_linear_cross" role="tab" aria-controls="settings">
#     Cross Validate
#     <span class="badge badge-primary badge-pill">7</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_pipeline_ridge" role="tab" aria-controls="settings">
#     Implement Ridge Regression - Pipeline
#     <span class="badge badge-primary badge-pill">8</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_ridge_cross" role="tab" aria-controls="settings">
#     Cross Validation
#     <span class="badge badge-primary badge-pill">9</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_ridge_best" role="tab" aria-controls="settings">
#     Finding best alpha for Ridge
#     <span class="badge badge-primary badge-pill">10</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_lasso_reg" role="tab" aria-controls="settings">
#     Implement Lasso Regression
#     <span class="badge badge-primary badge-pill">11</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_lasso_cross" role="tab" aria-controls="settings">
#     Cross Validation
#     <span class="badge badge-primary badge-pill">12</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_lasso_best" role="tab" aria-controls="settings">
#     Finding best alpha for Lasso
#     <span class="badge badge-primary badge-pill">13</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_elastic_reg" role="tab" aria-controls="settings">
#     Implement Elastic-Net
#     <span class="badge badge-primary badge-pill">14</span>
#   </a>
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_elastic_cross" role="tab" aria-controls="settings">
#     Cross Validation
#     <span class="badge badge-primary badge-pill">15</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_elastic_best" role="tab" aria-controls="settings">
#     Finding best alpha and l1_ratio for ElasticNet
#     <span class="badge badge-primary badge-pill">16</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_feature_importance" role="tab" aria-controls="settings">
#     Feature İmportance/selection
#     <span class="badge badge-primary badge-pill">17</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_decision_tree" role="tab" aria-controls="settings">
#     Decision Tree- Regression
#     <span class="badge badge-primary badge-pill">18</span>
#   </a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_decision_pipeline" role="tab" aria-controls="settings">
#     Pipeline
#     <span class="badge badge-primary badge-pill">19</span>
#   </a>
#    <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_decision_gridsearch" role="tab" aria-controls="settings">
#     GridSearch
#     <span class="badge badge-primary badge-pill">20</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_fea_importance" role="tab" aria-controls="settings">
#     Feature Importance
#     <span class="badge badge-primary badge-pill">21</span>
#   </a>
#     <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_compare" role="tab" aria-controls="settings">
#     Compare real and predicted result
#     <span class="badge badge-primary badge-pill">22</span>
#   </a>
#      <a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_final_model" role="tab" aria-controls="settings">
#     Final Model
#     <span class="badge badge-primary badge-pill">23</span>
#   </a>
# </div>

# %%
df_full = df_full[(df_full["dod_race"] == "White") | (df_full["dod_race"] == "Black") | (df_full["dod_race"] == "Hispanic")]
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5569 entries, 0 to 5818
# Data columns (total 99 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   subjectid                       5569 non-null   int64
#  1   abdominalextensiondepthsitting  5569 non-null   int64
#  2   acromialheight                  5569 non-null   int64
#  3   acromionradialelength           5569 non-null   int64
#  4   anklecircumference              5569 non-null   int64
#  5   axillaheight                    5569 non-null   int64
#  6   balloffootcircumference         5569 non-null   int64
#  7   balloffootlength                5569 non-null   int64
#  8   biacromialbreadth               5569 non-null   int64
#  9   bicepscircumferenceflexed       5569 non-null   int64
#  10  bicristalbreadth                5569 non-null   int64
#  11  bideltoidbreadth                5569 non-null   int64
# ...

# %%
df_full.reset_index(drop=True, inplace=True)

# %%
df_full.dod_race.value_counts()
# Out:
# White       3703
# Black       1228
# Hispanic     638
# Name: dod_race, dtype: int64

# %%
duplicate_values(df_full)
# Out:
# Duplicate check...
# There are no duplicates
# ****************************************************************************************************

# %%
df_full.describe().T
# Out:
#                                  count          mean           std      min  \
# subjectid                       5569.0  20792.231101  13610.930119  10027.0
# abdominalextensiondepthsitting  5569.0    247.401149     37.524082    155.0
# acromialheight                  5569.0   1409.065182     78.099553   1146.0
# acromionradialelength           5569.0    328.162686     20.367310    249.0
# anklecircumference              5569.0    225.285689     15.943036    156.0
# axillaheight                    5569.0   1302.211708     71.035118   1062.0
# balloffootcircumference         5569.0    244.388939     16.791046    186.0
# balloffootlength                5569.0    195.155863     13.366831    151.0
# biacromialbreadth               5569.0    399.870533     30.033661    311.0
# bicepscircumferenceflexed       5569.0    341.795834     41.268275    216.0
# bicristalbreadth                5569.0    275.070569     19.199971    197.0
# ...

# %%
# corr_matrix = df_full.corr(numeric_only = True)

# # 0.9'dan büyük veya -0.9'dan küçük korelasyonları kırmızı renkte gösterin
# def highlight_high_corr(val):
#     color = 'red' if (val > 0.9 and val < 1) or (val < -0.9 and val > -1) else 'black'
#     return f'color: {color}'

# styled_corr_matrix = corr_matrix.style.applymap(highlight_high_corr)

# # Korelasyon matrisini renklendirilmiş şekilde gösterin
# styled_corr_matrix

# %%
corr_matrix = df_full.corr(numeric_only = True)

high_corr_columns = []

threshold = 0.9  

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        corr_value = corr_matrix.iloc[i, j]
        if corr_value > threshold or corr_value < -threshold:
            col1 = corr_matrix.columns[i]
            col2 = corr_matrix.columns[j]
            high_corr_columns.append((col1, col2, corr_value))

print("Columns with High Correlation:")
for col1, col2, corr_value in high_corr_columns:
    print(f"{col1} and {col2} - Correlation Value: {corr_value:.2f}")
# Out:
# Columns with High Correlation:
# axillaheight and acromialheight - Correlation Value: 0.99
# buttockpopliteallength and buttockkneelength - Correlation Value: 0.95
# cervicaleheight and acromialheight - Correlation Value: 0.98
# cervicaleheight and axillaheight - Correlation Value: 0.98
# chestheight and acromialheight - Correlation Value: 0.96
# chestheight and axillaheight - Correlation Value: 0.96
# chestheight and cervicaleheight - Correlation Value: 0.97
# crotchheight and axillaheight - Correlation Value: 0.92
# crotchheight and buttockheight - Correlation Value: 0.93
# crotchheight and cervicaleheight - Correlation Value: 0.91
# crotchheight and chestheight - Correlation Value: 0.90
# footbreadthhorizontal and balloffootcircumference - Correlation Value: 0.92
# footlength and balloffootlength - Correlation Value: 0.96
# forearmcircumferenceflexed and bicepscircumferenceflexed - Correlation Value: 0.91
# forearmforearmbreadth and bideltoidbreadth - Correlation Value: 0.93
# ...

# %%
# buyukten kucuge
corr_matrix = df_full.corr(numeric_only = True)

high_corr_columns = []

threshold = 0.9  

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        corr_value = corr_matrix.iloc[i, j]
        if corr_value > threshold or corr_value < -threshold:
            col1 = corr_matrix.columns[i]
            col2 = corr_matrix.columns[j]
            high_corr_columns.append((col1, col2, corr_value))

high_corr_columns = sorted(high_corr_columns, key=lambda x: abs(x[2]), reverse=True)

print("Columns with High Correlation (Sorted by Absolute Correlation Value):")
for col1, col2, corr_value in high_corr_columns:
    print(f"{col1} and {col2} - Correlation Value: {corr_value:.2f}")
# Out:
# Columns with High Correlation (Sorted by Absolute Correlation Value):
# stature and cervicaleheight - Correlation Value: 0.99
# suprasternaleheight and stature - Correlation Value: 0.99
# suprasternaleheight and cervicaleheight - Correlation Value: 0.99
# axillaheight and acromialheight - Correlation Value: 0.99
# suprasternaleheight and acromialheight - Correlation Value: 0.98
# cervicaleheight and acromialheight - Correlation Value: 0.98
# sittingheight and eyeheightsitting - Correlation Value: 0.98
# suprasternaleheight and axillaheight - Correlation Value: 0.98
# stature and acromialheight - Correlation Value: 0.98
# cervicaleheight and axillaheight - Correlation Value: 0.98
# stature and axillaheight - Correlation Value: 0.98
# neckcircumferencebase and neckcircumference - Correlation Value: 0.97
# shoulderelbowlength and acromionradialelength - Correlation Value: 0.97
# chestheight and cervicaleheight - Correlation Value: 0.97
# ...

# %%
# conda install -c anaconda statsmodels
# !pip install statsmodels

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df_numeric = df_full.select_dtypes(include ="number")
X_vif = df_numeric
X_vif.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
df_vif = pd.DataFrame()
df_vif['features'] = X_vif.columns

# %%
df_vif
# Out:
#                           features
# 0                        subjectid
# 1   abdominalextensiondepthsitting
# 2                   acromialheight
# 3            acromionradialelength
# 4               anklecircumference
# 5                     axillaheight
# 6          balloffootcircumference
# 7                 balloffootlength
# 8                biacromialbreadth
# 9        bicepscircumferenceflexed
# 10                bicristalbreadth
# 11                bideltoidbreadth
# 12              bimalleolarbreadth
# 13                bitragionchinarc
# 14       bitragionsubmandibulararc
# 15              bizygomaticbreadth
# 16            buttockcircumference
# 17                    buttockdepth
# 18                   buttockheight
# 19               buttockkneelength
# 20          buttockpopliteallength
# 21               calfcircumference
# 22                 cervicaleheight
# 23                    chestbreadth
# 24              chestcircumference
# 25                      chestdepth
# ...

# %%
X_vif.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
variance_inflation_factor(X_vif.values, 0)

# Returns the VIF score of the relationship between the rooms feature at the 0th index of the "X_vif" and other features.
# Out:
# 4.11293433642659

# %%
df_vif["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(len(X_vif.columns))]

# %%
df_vif.sort_values("VIF", ascending = False)

#check the VIF scores:
# 1   -> no correlation
# 1-5 -> ok
# >5  -> Alert! Be cautious and inspect more. Consider removing.
# >10 -> Severe multicolliniearity!!!

# The features rooms, bedroom_2, bathroom, building_area, year_built have a serious multicollinearity 
# problem with other features. In this context, it is necessary to use one of the regularization models for accurate 
# feature selection.
# Out:
#                           features           VIF
# 75                         stature  94355.717182
# 22                 cervicaleheight  69796.762386
# 2                   acromialheight  57996.404592
# 76             suprasternaleheight  50398.265327
# 5                     axillaheight  28460.355114
# 71                   sittingheight  27198.581557
# 90            waistheightomphalion  19068.124620
# 57               kneeheightsitting  17418.106545
# 34                eyeheightsitting  14978.809816
# 19               buttockkneelength  14843.691621
# 40               forearmhandlength  12579.183172
# 77                  tenthribheight  11224.000226
# 74                            span  10240.211466
# 93                     wristheight   9228.457769
# 52              iliocristaleheight   8421.119643
# 69             shoulderelbowlength   8213.077825
# 16            buttockcircumference   8163.618001
# 81                    tibialheight   8153.903653
# ...

# %%
# kullanacagim modeller oto-reg yaptiklari icin burada herhangi bir dusum yapilmadi
# multicol logregg icin ve non-parametric algoritmalar icin sorun teski etmiyor

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Data Preprocessing ✨</p>

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [raw]
# # subjectnumericrace , targetfeature - dodrace ile ayni oldugu icin
# # Heightin, weigthlbs self-reported oldugu icin ve heightin yerine datada stature , weightlbs yerine ise datada weightkg oldugu icin
# # olusturulacak model api ile veya farkli bir entegrasyon ile kisilerin irklarini sormaksizin tahmin etmeyi amacladigi icin date, installation, component, branch, primarymos sutunlarida dusuldu .

# %%
X = df_full.drop(['dod_race'],axis=1)
y = df_full['dod_race']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=42)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4455, 98)
# Train target shape   :  (4455,)
# Test features shape  :  (1114, 98)
# Test target shape    :  (1114,)

# %%
print(y.value_counts(normalize=True))
print()
print(y_train.value_counts(normalize=True))
print()
print(y_test.value_counts(normalize=True))
# Out:
# White       0.664931
# Black       0.220506
# Hispanic    0.114563
# Name: dod_race, dtype: float64
#
# White       0.664871
# Black       0.220426
# Hispanic    0.114703
# Name: dod_race, dtype: float64
#
# White       0.665171
# Black       0.220826
# Hispanic    0.114004
# Name: dod_race, dtype: float64

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Modelling ✨</p>

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)

    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
df_object = X.select_dtypes(include ="object")
for col in df_object:
    print(f"{col:<30}:", df_full[col].nunique())
# we see how many unique observations each feature consists of.
# Out:
# gender                        : 2
# subjects_birth_location       : 62
# writing_preference            : 3

# %%
cat = X_train.select_dtypes("object").columns
cat
# Out:
# Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object')

# %%
scaler = MinMaxScaler()

# %%
column_trans = make_column_transformer(
                        (OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                         remainder=scaler, 
                         verbose_feature_names_out=False) # MinMaxScaler()

column_trans=column_trans.set_output(transform="pandas")

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Logistic Model ✨</p>

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Vanilla Logistic Model ✨</p>

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.linear_model import LogisticRegression
operations = [("OneHot_Encoder", column_trans), 
              ("logistic", LogisticRegression(class_weight = 'balanced',
                                              random_state = 42))]

logistic_model = Pipeline(steps=operations) #.set_output(transform="pandas")

logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('logistic',
#                  LogisticRegression(class_weight='balanced', random_state=42))])

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Vanilla Logistic Model ✨</p>

# %% [markdown]
# ### With Default Parameters

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(logistic_model, X_test, y_test);

# %%
eval_metric(logistic_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[226  12   8]
#  [  8  98  21]
#  [ 22  90 629]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.92      0.90       246
#     Hispanic       0.49      0.77      0.60       127
#        White       0.96      0.85      0.90       741
#
#     accuracy                           0.86      1114
#    macro avg       0.78      0.85      0.80      1114
# weighted avg       0.89      0.86      0.87      1114
#
#
# Train_Set
# [[ 919   31   32]
#  [  14  430   67]
#  [  60  344 2558]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93       982
#     Hispanic       0.53      0.84      0.65       511
#        White       0.96      0.86      0.91      2962
#
#     accuracy                           0.88      4455
#    macro avg       0.81      0.88      0.83      4455
# weighted avg       0.91      0.88      0.89      4455

# %%
scoring = {"precision_Hispanic" : make_scorer(precision_score, average = None, labels = ["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"]),
           "f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"])}

# %%
from sklearn.model_selection import cross_validate

operations = [("OneHot_Encoder", column_trans), 
              ("logistic", LogisticRegression(class_weight = 'balanced',
                                              random_state = 42))]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.497497
# train_precision_Hispanic    0.535528
# test_recall_Hispanic        0.778771
# train_recall_Hispanic       0.844749
# test_f1_Hispanic            0.605865
# train_f1_Hispanic           0.655489
# dtype: float64

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Vanilla Logistic Model ✨</p>

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
precision_hispanic =  make_scorer(precision_score, average=None, labels=["Hispanic"])

# %%
# operations = [("OneHot_Encoder", column_trans), 
#               ("logistic", LogisticRegression(class_weight = 'balanced', C = 0.4, solver = "liblinear",
#                                               random_state = 42))]

# model = Pipeline(steps=operations)

# scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10, return_train_score=True)
# df_scores = pd.DataFrame(scores, index = range(1, 11))
# df_scores.mean()[2:]

# %%
param_grid = {
    "logistic__C": [0.3, 0.4, 0.5], # c kuculdukce uyguladigi reg degeri artiyor
    'logistic__penalty': ["l1", "l2"],
    'logistic__solver': ['liblinear', 'lbfgs'],
}

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("logistic", LogisticRegression(class_weight = 'balanced',
                                              random_state = 42))]

model = Pipeline(steps=operations)


log_model_grid = GridSearchCV(model,
                              param_grid,
                              scoring=precision_hispanic,
                              cv=10,
                              n_jobs=-1,
                              return_train_score=True)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHot_Encoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                                                           verbose_feature_names_out=False)),
#                                        ('logistic',
#                                         LogisticRegression(class_weight='balanced',
#                                                            random_state=42))]),
#              n_jobs=-1,
# ...

# %%
log_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('logistic',
#                  LogisticRegression(C=0.4, class_weight='balanced',
#                                     penalty='l1', random_state=42,
#                                     solver='liblinear'))])

# %%
pd.DataFrame(log_model_grid.cv_results_).loc[log_model_grid.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score     0.694751
# mean_train_score    0.714577
# Name: 4, dtype: object

# %%
ConfusionMatrixDisplay.from_estimator(log_model_grid, X_test, y_test);

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[228   4  14]
#  [ 11  77  39]
#  [ 17  39 685]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.93      0.91       246
#     Hispanic       0.64      0.61      0.62       127
#        White       0.93      0.92      0.93       741
#
#     accuracy                           0.89      1114
#    macro avg       0.82      0.82      0.82      1114
# weighted avg       0.89      0.89      0.89      1114
#
#
# Train_Set
# [[ 910   19   53]
#  [  21  342  148]
#  [  53  119 2790]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93       982
#     Hispanic       0.71      0.67      0.69       511
#        White       0.93      0.94      0.94      2962
#
#     accuracy                           0.91      4455
#    macro avg       0.86      0.85      0.85      4455
# weighted avg       0.91      0.91      0.91      4455

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("logistic", LogisticRegression(class_weight = 'balanced', C = 0.4, solver = "liblinear",
                                              penalty = 'l1',
                                              random_state = 42))]

model = Pipeline(steps=operations)


scores = cross_validate(model,
                        X_train, 
                        y_train, 
                        scoring=scoring,
                        cv=10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.683329
# train_precision_Hispanic    0.699810
# test_recall_Hispanic        0.633861
# train_recall_Hispanic       0.664489
# test_f1_Hispanic            0.655932
# train_f1_Hispanic           0.681686
# dtype: float64

# %%
from scikitplot.metrics import plot_roc, plot_precision_recall

operations = [("OneHot_Encoder", column_trans), 
              ("logistic", LogisticRegression(class_weight = 'balanced', C = 0.4, solver = "liblinear",
                                              penalty = 'l1',
                                              random_state = 42))]

model = Pipeline(steps=operations)

model.fit(X_train, y_train)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
pd.get_dummies(y_test).values
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1],
#        ...,
#        [0, 1, 0],
#        [0, 0, 1],
#        [0, 1, 0]], dtype=uint8)

# %%
from sklearn.metrics import average_precision_score

y_test_dummies = pd.get_dummies(y_test).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1]) # icine vektor ister . matrisi yukarida vektore cevirdim
# Out:
# 0.6868000617187964

# %%
y_pred = log_model_grid.predict(X_test)

log_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
log_precision = precision_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ SVC ✨</p>

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Vanilla SVC model ✨</p>

# %%
from sklearn.svm import SVC
operations = [("OneHot_Encoder", column_trans), 
              ("svc", SVC(class_weight = 'balanced',
                                              random_state = 42))]

svc_model = Pipeline(steps=operations) #.set_output(transform="pandas")

svc_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('svc', SVC(class_weight='balanced', random_state=42))])

# %%
eval_metric(svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[225  11  10]
#  [  9  95  23]
#  [ 18  92 631]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.91      0.90       246
#     Hispanic       0.48      0.75      0.58       127
#        White       0.95      0.85      0.90       741
#
#     accuracy                           0.85      1114
#    macro avg       0.77      0.84      0.80      1114
# weighted avg       0.88      0.85      0.86      1114
#
#
# Train_Set
# [[ 909   32   41]
#  [  11  432   68]
#  [  47  369 2546]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.93      0.93       982
#     Hispanic       0.52      0.85      0.64       511
#        White       0.96      0.86      0.91      2962
#
#     accuracy                           0.87      4455
#    macro avg       0.81      0.88      0.83      4455
# weighted avg       0.90      0.87      0.88      4455

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("svc", SVC(class_weight = 'balanced',
                                              random_state = 42))]

model = Pipeline(steps=operations)

scores = cross_validate(model, 
                        X_train, 
                        y_train, 
                        scoring=scoring,
                        cv=10,
                        n_jobs = -1, 
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.470270
# train_precision_Hispanic    0.514517
# test_recall_Hispanic        0.755354
# train_recall_Hispanic       0.849099
# test_f1_Hispanic            0.578923
# train_f1_Hispanic           0.640719
# dtype: float64

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ SVC Model GridsearchCV ✨</p>

# %%
# operations = [("OneHot_Encoder", column_trans), 
#               ("svc", SVC(class_weight = 'balanced', kernel = "linear", C = 0.001 ,
#                                               random_state = 42))]

# model = Pipeline(steps=operations)

# scores = cross_validate(model, 
#                         X_train, 
#                         y_train, 
#                         scoring=scoring,
#                         cv=10,
#                         n_jobs = -1, 
#                         return_train_score=True)
# df_scores = pd.DataFrame(scores, index = range(1, 11))
# df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.220892
# train_precision_Hispanic    0.222727
# test_recall_Hispanic        0.493137
# train_recall_Hispanic       0.499454
# test_f1_Hispanic            0.304683
# train_f1_Hispanic           0.308011
# dtype: float64

# %%
precision_hispanic =  make_scorer(precision_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    'svc__C': [0.2, 0.3],
    'svc__gamma': ["scale", "auto", 0.01], #kernel linear disinda birsey cikarsa diye gamma da tanimladik.
    'svc__kernel':['linear', 'rbf'] # data linear ise poly recalleri artiriyor fakat predictionlari dusuruyor . 
}

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("svc", SVC(class_weight = 'balanced',
                                              random_state = 42))]

model = Pipeline(steps=operations)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              scoring=precision_hispanic,
                              cv=10,
                              n_jobs=-1,
                              return_train_score=True)

# %%
svc_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('OneHot_Encoder',
#    ColumnTransformer(remainder=MinMaxScaler(),
#                      transformers=[('onehotencoder',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                      verbose_feature_names_out=False)),
#   ('svc', SVC(class_weight='balanced', random_state=42))],
#  'verbose': False,
#  'OneHot_Encoder': ColumnTransformer(remainder=MinMaxScaler(),
#                    transformers=[('onehotencoder',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                    verbose_feature_names_out=False),
# ...

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHot_Encoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                                                           verbose_feature_names_out=False)),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=42))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [0.2, 0.3],
# ...

# %%
svm_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Encoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))],
#                                    verbose_feature_names_out=False)),
#                 ('svc',
#                  SVC(C=0.3, class_weight='balanced', kernel='linear',
#                      random_state=42))])

# %%
pd.DataFrame(svm_model_grid.cv_results_).loc[svm_model_grid.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score     0.476445
# mean_train_score    0.510327
# Name: 6, dtype: object

# %%
ConfusionMatrixDisplay.from_estimator(svm_model_grid, X_test, y_test);

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[227  11   8]
#  [ 10  97  20]
#  [ 23  89 629]]
#               precision    recall  f1-score   support
#
#        Black       0.87      0.92      0.90       246
#     Hispanic       0.49      0.76      0.60       127
#        White       0.96      0.85      0.90       741
#
#     accuracy                           0.86      1114
#    macro avg       0.77      0.85      0.80      1114
# weighted avg       0.89      0.86      0.86      1114
#
#
# Train_Set
# [[ 912   33   37]
#  [  18  426   67]
#  [  59  378 2525]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93       982
#     Hispanic       0.51      0.83      0.63       511
#        White       0.96      0.85      0.90      2962
#
#     accuracy                           0.87      4455
#    macro avg       0.80      0.87      0.82      4455
# weighted avg       0.90      0.87      0.88      4455

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("svc", SVC(class_weight = 'balanced', kernel = 'linear',
                                              C = 0.3,
                                              random_state = 42))]


model = Pipeline(steps=operations)

scores = cross_validate(model, 
                        X_train, 
                        y_train, 
                        scoring=scoring,
                        cv=10, 
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.470270
# train_precision_Hispanic    0.514517
# test_recall_Hispanic        0.755354
# train_recall_Hispanic       0.849099
# test_f1_Hispanic            0.578923
# train_f1_Hispanic           0.640719
# dtype: float64

# %%
# !pip install scikit-plot --user

# %%
operations = [("OneHot_Encoder", column_trans), 
              ("svc", SVC(class_weight = 'balanced', kernel = 'linear',
                                              C = 0.3,
                                              random_state = 42))]


model = Pipeline(steps=operations)

model.fit(X_train, y_train)

decision_function = model.decision_function(X_test)

#y_pred_proba = model.predict_proba(X_test) # predict_proba kullanamam . mutlaka decision func kullanmaliyim .
    
plot_precision_recall(y_test, decision_function)
plt.show();

# %%
decision_function
# Out:
# array([[ 2.27668395,  0.78571475, -0.25171717],
#        [-0.25464775,  2.25297879,  1.02695711],
#        [-0.24776949,  0.81882068,  2.26780025],
#        ...,
#        [-0.19251268,  2.1465662 ,  1.12267264],
#        [-0.23885288,  1.09763055,  2.22628493],
#        [-0.24240463,  2.25327867,  0.88919368]])

# %%
average_precision_score(y_test_dummies[:, 1], decision_function[:, 1])
# Out:
# 0.5717997690782601

# %%
y_pred = svm_model_grid.predict(X_test)

svc_AP = average_precision_score(y_test_dummies[:, 1], decision_function[:, 1])
svc_precision = precision_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ RF ✨</p>

# %%
cat
# Out:
# Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object')

# %%
# tree base mnodellerde ordinal encoder yapmaliyim .
ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', 
                         unknown_value=-1) # bu da onehotencoderdaki gibi egitilmedigi datada sonuc dondurur fakat hatyali olur icindekileri kaldirmak lazim

column_trans = make_column_transformer((ord_enc, cat), # neden ordinal encoder uyguladik. saat 12 : 25 e bak . 
                                       remainder='passthrough')

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Vanilla RF Model ✨</p>

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

operations_rf = [("OrdinalEncoder", column_trans), 
                 ("RF_model", RandomForestClassifier(class_weight="balanced", # datada inbalancelik var direk yazalim bunu
                                                     random_state=42))]

pipe_model_rf = Pipeline(steps=operations_rf)

pipe_model_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=42))])

# %%
eval_metric(pipe_model_rf, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[168   0  78]
#  [ 13   5 109]
#  [  9   0 732]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.68      0.77       246
#     Hispanic       1.00      0.04      0.08       127
#        White       0.80      0.99      0.88       741
#
#     accuracy                           0.81      1114
#    macro avg       0.89      0.57      0.58      1114
# weighted avg       0.84      0.81      0.77      1114
#
#
# Train_Set
# [[ 982    0    0]
#  [   0  511    0]
#  [   0    0 2962]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00       982
#     Hispanic       1.00      1.00      1.00       511
#        White       1.00      1.00      1.00      2962
#
#     accuracy                           1.00      4455
#    macro avg       1.00      1.00      1.00      4455
# weighted avg       1.00      1.00      1.00      4455

# %%
operations_rf = [("OrdinalEncoder", column_trans), 
                 ("RF_model", RandomForestClassifier(class_weight="balanced",
                                                     random_state=42))]

model = Pipeline(steps=operations_rf)

scores = cross_validate(model,
                        X_train, 
                        y_train,
                        scoring=scoring,
                        cv=10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# overfitting
# Out:
# test_precision_Hispanic     0.716667
# train_precision_Hispanic    1.000000
# test_recall_Hispanic        0.041063
# train_recall_Hispanic       1.000000
# test_f1_Hispanic            0.076960
# train_f1_Hispanic           1.000000
# dtype: float64

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ RF Model GridsearchCV ✨</p>

# %%
# operations_rf = [("OrdinalEncoder", column_trans), 
#                  ("RF_model", RandomForestClassifier(class_weight="balanced",
# #                                                      max_depth=2,
#                                                      n_estimators = 500,
# # #                                                      n_estimators = 300,
#                                                      min_samples_split=20,
#                                                      max_samples =0.2,
#                                                      min_samples_leaf = 100,
#                                                      random_state = 42
#                                                     ))]

# model = Pipeline(steps=operations_rf)

# scores = cross_validate(model,
#                         X_train, 
#                         y_train,
#                         scoring=scoring,
#                         cv=10,
#                         n_jobs =-1, 
#                         return_train_score=True)
# df_scores = pd.DataFrame(scores, index = range(1, 11))
# df_scores.mean()[2:]

# # overfitting

# %%
operations = [("OrdinalEncoder", column_trans), 
              ("RF_model", RandomForestClassifier(class_weight="balanced",
                                                     random_state=42))]
model = Pipeline(steps=operations)

# %%
# model.get_params()

# %%
param_grid = {'RF_model__n_estimators':[300 , 400, 500], # rf icinde birden cok decisiontree model calismaliydi . 
             'RF_model__max_depth':[2, None],
             'RF_model__min_samples_split':[10, 20],
             'RF_model__min_samples_leaf': [100],
             'RF_model__max_samples':[0.1, 0.2, 0.3]} # add 1
# hyperparametre eklemek icin optuna ve sklearn den ... de kullanilabilir

# %%
rf_grid_model = GridSearchCV(model,
                             param_grid,
                             scoring=precision_hispanic,
                             n_jobs=-1,
                             cv=10,
                             return_train_score=True)

# %%
rf_grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                                        ('RF_model',
#                                         RandomForestClassifier(class_weight='balanced',
#                                                                random_state=42))]),
#              n_jobs=-1,
#              param_grid={'RF_model__max_depth': [2, None],
# ...

# %%
rf_grid_model.best_params_
# Out:
# {'RF_model__max_depth': None,
#  'RF_model__max_samples': 0.3,
#  'RF_model__min_samples_leaf': 100,
#  'RF_model__min_samples_split': 10,
#  'RF_model__n_estimators': 300}

# %%
pd.DataFrame(rf_grid_model.cv_results_).loc[rf_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score     0.227111
# mean_train_score    0.244393
# Name: 30, dtype: object

# %%
rf_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         max_samples=0.3, min_samples_leaf=100,
#                                         min_samples_split=10, n_estimators=300,
#                                         random_state=42))])

# %%
rf_grid_model.best_score_
# Out:
# 0.22711083188809442

# %%
ConfusionMatrixDisplay.from_estimator(rf_grid_model, X_test, y_test);

# %%
eval_metric(rf_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[185  41  20]
#  [ 31  62  34]
#  [ 91 238 412]]
#               precision    recall  f1-score   support
#
#        Black       0.60      0.75      0.67       246
#     Hispanic       0.18      0.49      0.26       127
#        White       0.88      0.56      0.68       741
#
#     accuracy                           0.59      1114
#    macro avg       0.56      0.60      0.54      1114
# weighted avg       0.74      0.59      0.63      1114
#
#
# Train_Set
# [[ 760  135   87]
#  [  60  330  121]
#  [ 327  884 1751]]
#               precision    recall  f1-score   support
#
#        Black       0.66      0.77      0.71       982
#     Hispanic       0.24      0.65      0.35       511
#        White       0.89      0.59      0.71      2962
#
#     accuracy                           0.64      4455
#    macro avg       0.60      0.67      0.59      4455
# weighted avg       0.77      0.64      0.67      4455

# %%
operations_rf = [("OrdinalEncoder", column_trans), 
                 ("RF_model", RandomForestClassifier(class_weight="balanced",
                                                     max_samples = 0.3,
                                                     min_samples_leaf= 100,
                                                     min_samples_split= 10,
                                                     n_estimators=300, 
                                                     random_state=101))]

model = Pipeline(steps=operations_rf)

model.fit(X_train, y_train)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
# Out:
# 0.24128107615029887

# %%
y_pred = rf_grid_model.predict(X_test)

rf_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
rf_precision = precision_score(y_test, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ XGBoost ✨</p>

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Vanilla XGBoost Model ✨</p>

# %%
df_full.dod_race.value_counts()
# Out:
# White       3703
# Black       1228
# Hispanic     638
# Name: dod_race, dtype: int64

# %%
from xgboost import XGBClassifier
operations_xgb = [("OrdinalEncoder", column_trans), 
                 ("XGB_model", XGBClassifier(random_state=42))]

pipe_model_xgb = Pipeline(steps=operations_xgb)

y_train_xgb = y_train.map({"Black":0, "Hispanic":1, "White":2}) # sıralama classification_report ile aynı olacak.
y_test_xgb = y_test.map({"Black":0, "Hispanic":1, "White":2})
# xgb 1.6 ve üzeri versiyonlarda target numeric olmaz ise hata döndürüyor. Bu sebeple manuel olarak dönüşümü yapıyoruz.


pipe_model_xgb.fit(X_train, y_train_xgb)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=N...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
# ...

# %%
eval_metric(pipe_model_xgb, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[215   2  29]
#  [  9  46  72]
#  [  8   8 725]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       246
#            1       0.82      0.36      0.50       127
#            2       0.88      0.98      0.93       741
#
#     accuracy                           0.89      1114
#    macro avg       0.88      0.74      0.78      1114
# weighted avg       0.88      0.89      0.87      1114
#
#
# Train_Set
# [[ 982    0    0]
#  [   0  511    0]
#  [   0    0 2962]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       982
#            1       1.00      1.00      1.00       511
#            2       1.00      1.00      1.00      2962
#
#     accuracy                           1.00      4455
#    macro avg       1.00      1.00      1.00      4455
# weighted avg       1.00      1.00      1.00      4455

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', 
                                                     y=y_train_xgb)
classes_weights

# XGboost algortimasının multiclass datalar için weight_class hyper parametresi olmadığından. fit fonksiyonu içinde 
# sample_weight hyper paremetresini kullanabiliyoruz.
# Out:
# array([0.50135044, 0.50135044, 0.50135044, ..., 0.50135044, 0.50135044,
#        0.50135044])

# %%
my_dict = {"weights": classes_weights, "label":y_train_xgb}

comp = pd.DataFrame(my_dict)

comp.head()
# Out:
#       weights  label
# 1981  0.50135      2
# 201   0.50135      2
# 130   0.50135      2
# 5392  1.51222      0
# 3374  0.50135      2

# %%
comp.groupby("label").value_counts()

# weight x class_sayısı bize aynı sonuçları verecektir.
# Out:
# label  weights
# 0      1.512220     982
# 1      2.906067     511
# 2      0.501350    2962
# dtype: int64

# %%
pipe_model_xgb.fit(X_train,
                   y_train_xgb,  
                   XGB_model__sample_weight=classes_weights)

# weight parameter in XGBoost is per instance not per class. Therefore, we need to assign the weight of each class to its 
# instances, which is the same thing.
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=N...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
# ...

# %%
eval_metric(pipe_model_xgb, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[222   2  22]
#  [ 10  59  58]
#  [ 14  21 706]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       246
#            1       0.72      0.46      0.56       127
#            2       0.90      0.95      0.92       741
#
#     accuracy                           0.89      1114
#    macro avg       0.84      0.77      0.80      1114
# weighted avg       0.88      0.89      0.88      1114
#
#
# Train_Set
# [[ 982    0    0]
#  [   0  511    0]
#  [   0    0 2962]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       982
#            1       1.00      1.00      1.00       511
#            2       1.00      1.00      1.00      2962
#
#     accuracy                           1.00      4455
#    macro avg       1.00      1.00      1.00      4455
# weighted avg       1.00      1.00      1.00      4455

# %%
scoring_xgb = {"precision_Hispanic" : make_scorer(precision_score, average = None, labels =[1]),
               "recall_Hispanic" : make_scorer(recall_score, average = None, labels =[1]),
               "f1_Hispanic" : make_scorer(f1_score, average = None, labels =[1])}

# xgb categric target kabul etmediğinden hispaniclere karşılık gelen 1 numeric clasıına göre scoring_xgb'u düzenliyoruz.

# %%
operations_xgb = [("OrdinalEncoder", column_trans), 
                 ("XGB_model", XGBClassifier(random_state=42))]

model = Pipeline(steps=operations_xgb)

scores = cross_validate(model, 
                        X_train, 
                        y_train_xgb, 
                        scoring=scoring_xgb,
                        cv=5, 
                        return_train_score=True,
                        fit_params={"XGB_model__sample_weight":classes_weights}) # bu parametreyi bir dict seklinde vermemiz lazim
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.682903
# train_precision_Hispanic    1.000000
# test_recall_Hispanic        0.389549
# train_recall_Hispanic       1.000000
# test_f1_Hispanic            0.493709
# train_f1_Hispanic           1.000000
# dtype: float64

# %%
# operations_xgb = [("OrdinalEncoder", column_trans), 
#                  ("XGB_model", XGBClassifier(random_state=42,
#                                              max_depth = 2,
#                                             n_estimators = 70,
# #                                              subsample = 0.7,
#                                              colsample_bytree = 0.7,
# #                                              max_leaves  = 100,
#                                             learning_rate = 0.0001,
# #                                              sampling_method  = "uniform",
# #                                              reg_alpha = 0.001
#                                             ))]

# model = Pipeline(steps=operations_xgb)

# scores = cross_validate(model, 
#                         X_train, 
#                         y_train_xgb, 
#                         scoring=scoring_xgb,
#                         cv=5, 
#                         return_train_score=True,
#                         fit_params={"XGB_model__sample_weight":classes_weights}) # bu parametreyi bir dict seklinde vermemiz lazim
# df_scores = pd.DataFrame(scores, index = range(1, 6))
# df_scores.mean()[2:]

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ XGBoost Model GridsearchCV ✨</p>

# %%
param_grid = {"XGB_model__n_estimators":[70, 80],
              'XGB_model__max_depth':[1, 2],
              "XGB_model__learning_rate": [0.0001,0.001],
              "XGB_model__colsample_bytree":[0.5,0.7, 1]} # agaclari olustururken featurelarin ne kadarini dikkate alicam .

# %%
operations = [("OrdinalEncoder", column_trans), 
              ("XGB_model", XGBClassifier(random_state=42))]


model = Pipeline(steps=operations)

xgb_grid_model = GridSearchCV(model, 
                              param_grid, 
                              scoring=make_scorer(precision_score, average = None, labels =[1]),
                              cv=5,
                              n_jobs=-1,
                              return_train_score=True)

# %%
xgb_grid_model.fit(X_train,
                   y_train_xgb,
                   XGB_model__sample_weight=classes_weights)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                                        ('XGB_model',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callba...
#                                                       multi_strategy=None,
# ...

# %%
xgb_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=N...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.001, max_bin=None,
# ...

# %%
xgb_grid_model.best_params_
# Out:
# {'XGB_model__colsample_bytree': 0.5,
#  'XGB_model__learning_rate': 0.001,
#  'XGB_model__max_depth': 2,
#  'XGB_model__n_estimators': 80}

# %%
pd.DataFrame(xgb_grid_model.cv_results_).loc[xgb_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score     0.217762
# mean_train_score    0.233568
# Name: 7, dtype: object

# %%
xgb_grid_model.best_score_
# Out:
# 0.21776225779099892

# %%
eval_metric(xgb_grid_model, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[164  58  24]
#  [ 27  67  33]
#  [ 87 259 395]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.67      0.63       246
#            1       0.17      0.53      0.26       127
#            2       0.87      0.53      0.66       741
#
#     accuracy                           0.56      1114
#    macro avg       0.55      0.58      0.52      1114
# weighted avg       0.73      0.56      0.61      1114
#
#
# Train_Set
# [[ 697  196   89]
#  [  54  329  128]
#  [ 315  941 1706]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68       982
#            1       0.22      0.64      0.33       511
#            2       0.89      0.58      0.70      2962
#
#     accuracy                           0.61      4455
#    macro avg       0.59      0.64      0.57      4455
# weighted avg       0.76      0.61      0.65      4455

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_roc, plot_precision_recall

operations_xgb = [("OrdinalEncoder", column_trans), 
                 ("XGB_model", XGBClassifier(random_state=42,
                                             max_depth = 2,
                                             n_estimators = 80,
                                             colsample_bytree = 0.5,
                                             learning_rate = 0.0001
                                            ))]

model = Pipeline(steps=operations_xgb)

model.fit(X_train, 
          y_train_xgb, 
          XGB_model__sample_weight=classes_weights)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test_xgb, y_pred_proba)
plt.show()

# %%
y_test_xgb_dummies = pd.get_dummies(y_test_xgb).values

# %%
average_precision_score(y_test_xgb_dummies[:, 1], y_pred_proba[:, 1])
# Out:
# 0.24357122662599956

# %%
y_pred = xgb_grid_model.predict(X_test)

xgb_AP = average_precision_score(y_test_xgb_dummies[:, 1], y_pred_proba[:, 1])
xgb_precision = precision_score(y_test_xgb, y_pred, average=None, labels=[1])
xgb_recall = recall_score(y_test_xgb, y_pred, average=None, labels=[1])

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Comparing Models ✨</p>

# %%
compare= pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                       "Precision": [log_precision[0], svc_precision[0], rf_precision[0], xgb_precision[0]],
                       "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                       "AP": [log_AP, svc_AP, rf_AP, xgb_AP]})

compare
# Out:
#                  Model  Precision    Recall        AP
# 0  Logistic Regression   0.641667  0.606299  0.686800
# 1                  SVM   0.492386  0.763780  0.571800
# 2        Random Forest   0.181818  0.488189  0.241281
# 3              XGBoost   0.174479  0.527559  0.243571

# %%
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="Precision", ascending=False)
ax=sns.barplot(x="Precision", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)# modelin ayirma performansi
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.show();

# burada logistic reg tercih ediliyor

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Before the Deployment ✨</p>

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
column_trans_final = make_column_transformer((OneHotEncoder(handle_unknown="ignore", 
                                                            sparse=False), cat),
                                              remainder=MinMaxScaler())

operations_final = [("OneHotEncoder",column_trans_final), 
                    ("logistic", LogisticRegression(class_weight = 'balanced', C = 0.4, solver = "liblinear",
                                              penalty = 'l1',
                                              random_state = 42))]

final_model = Pipeline(steps=operations_final)
final_model.fit(X, y)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjects_birth_location', 'writing_preference'], dtype='object'))])),
#                 ('logistic',
#                  LogisticRegression(C=0.4, class_weight='balanced',
#                                     penalty='l1', random_state=42,
#                                     solver='liblinear'))])

# %%
X[X.gender=="Male"].describe()
# Out:
#           subjectid  abdominalextensiondepthsitting  acromialheight  \
# count   3772.000000                     3772.000000     3772.000000
# mean   20017.895811                      255.513521     1443.172587
# std     6572.613290                       37.417808       62.137265
# min    10027.000000                      163.000000     1194.000000
# 25%    14286.000000                      227.000000     1401.000000
# 50%    17207.500000                      252.000000     1441.500000
# 75%    27322.750000                      280.000000     1483.000000
# max    29452.000000                      451.000000     1683.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            3772.000000         3772.000000   3772.000000
# mean              335.817338          229.684252   1331.200954
# std                17.247209           14.557223     58.469464
# min               270.000000          156.000000   1106.000000
# ...

# %%
male_mean_human = X[X.gender=="Male"].describe(include="all").loc["mean"]
male_mean_human
# Out:
# subjectid                         20017.895811
# abdominalextensiondepthsitting      255.513521
# acromialheight                     1443.172587
# acromionradialelength               335.817338
# anklecircumference                  229.684252
# axillaheight                       1331.200954
# balloffootcircumference             252.113998
# balloffootlength                    201.227996
# biacromialbreadth                    416.04878
# bicepscircumferenceflexed           358.587487
# bicristalbreadth                    275.783934
# bideltoidbreadth                    511.063097
# bimalleolarbreadth                    74.83351
# bitragionchinarc                    331.502121
# bitragionsubmandibulararc           315.649523
# bizygomaticbreadth                   142.38123
# buttockcircumference               1021.823436
# buttockdepth                        246.436903
# buttockheight                       889.437964
# buttockkneelength                    619.28632
# ...

# %%
male_mean_human["gender"] = "Male"
male_mean_human["subjects_birth_location"] = "California"
male_mean_human["writing_preference"] = "Right hand"

# %%
pd.DataFrame(male_mean_human).T
# Out:
#          subjectid abdominalextensiondepthsitting acromialheight  \
# mean  20017.895811                     255.513521    1443.172587
#
#      acromionradialelength anklecircumference axillaheight  \
# mean            335.817338         229.684252  1331.200954
#
#      balloffootcircumference balloffootlength biacromialbreadth  \
# mean              252.113998       201.227996         416.04878
#
#      bicepscircumferenceflexed  ...  waistdepth waistfrontlengthsitting  \
# mean                358.587487  ...  238.714475              388.196182
#
#      waistheightomphalion  weightkg wristcircumference wristheight gender  \
# mean          1058.305938  859.3579         176.203606  848.996023   Male
#
#      subjects_birth_location        age writing_preference
# mean              California  30.094115         Right hand
#
# [1 rows x 98 columns]

# %%
final_model.predict(pd.DataFrame(male_mean_human).T)
# Out:
# array(['White'], dtype=object)

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %% [markdown]
# ---
# ---

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Other Evaluation Metrics for Multiclass Classification ✨</p>

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7973210607026598

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7971875309864123

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Methods of Resampling ✨</p>

# %% [markdown]
# ---
# ---

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ SMOTE ✨</p>

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Smote implement ✨</p>

# %%
conda install -c conda-forge imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE # azınlık olan classları çoğunluk classa eşitler veya yakınlaştırır.
from imblearn.under_sampling import RandomUnderSampler # çoğunluk olan classı azınlık olan classa eşitler veya yakınlaştırır
from imblearn.pipeline import Pipeline as imbpipeline

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", 
                                                      sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
X_train_ohe = column_trans.fit_transform(X_train)

# %%
over = SMOTE()
X_train_over, y_train_over = over.fit_resample(X_train_ohe, y_train)

# %%
X_train_over.shape

# %%
y_train_over.value_counts()

# %% [markdown]
# <a id="part_3_def"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Logistic Regression Over/ Under Sampling ✨</p>

# %%
#Kaynaklar

# %% [markdown]
# https://youtu.be/9haIOplEIGM
# https://youtu.be/4SivdTLIwHc
#
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/
#
# https://medium.com/analytics-vidhya/handling-imbalanced-data-by-oversampling-with-smote-and-its-variants-23a4bf188eaf
#
# https://www.svds.com/learning-imbalanced-classes/
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-72f0bea35f7c
#
# https://towardsdatascience.com/explain-any-models-with-the-shap-values-use-the-kernelexplainer-79de9464897a

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
